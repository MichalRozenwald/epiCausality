# %% [markdown]
# # Analyse K562 P2 MinION & R9 run from  20204/11/27, 20204/09/27

# %%
from dimelo import parse_bam, plot_enrichment_profile, plot_reads
import matplotlib.pyplot as plt
from pathlib import Path
# Out:
# modkit found with expected version 0.2.4

# %%
! ls "/home/michalula/data/cas9_nanopore/data/2024927_Cas9_R9_promethion_K562"
# Out:
# bams_pass_merged.bam	 to_hg19  to_k562_spr30588077  to_t2t_v1_1
# post_seq_basecall_align  to_hg38  to_t2t_v1_0	       trim_bam_pass_merged.bam

# %%
! ls "/home/michalula/data/cas9_nanopore/data/2024927_Cas9_R9_promethion_K562/to_t2t_v1_1"
# Out:
# aligned_T2Tv1_1_trim_bam_pass_merged.bam
# more_mismatches
# sort_aligned_T2Tv1_1_trim_bam_pass_merged.bam
# sort_aligned_T2Tv1_1_trim_bam_pass_merged.bam.bai
# sort_aligned_T2Tv1_1_trim_bam_pass_merged.updated.bam
# sort_aligned_T2Tv1_1_trim_bam_pass_merged.updated.bam.bai
# summary_aligned_T2Tv1_1_trim_bam_pass_merged.tsv

# %% [markdown]
# ### System Information
# Run this cell to list system information about your machine

# %%
import platform
print('System:',platform.system())
print('Release:',platform.release())
print('Version:',platform.version())
print('Processor:',platform.processor())

#  Pyton version
import sys
print(sys.version)
# Out:
# System: Linux
# Release: 6.8.0-49-generic
# Version: #49~22.04.1-Ubuntu SMP PREEMPT_DYNAMIC Wed Nov  6 17:42:15 UTC 2
# Processor: x86_64
# 3.11.9 | packaged by conda-forge | (main, Apr 19 2024, 18:36:13) [GCC 12.3.0]

# %%
from pathlib import Path
from matplotlib import pyplot as plt
import pysam
import pandas as pd
from dimelo import plot_enrichment_profile, load_processed, parse_bam, utils

import seaborn as sns
from matplotlib.axes import Axes
import matplotlib.pyplot as plt

import numpy as np

# %% [markdown]
# #### Download & Use the T2T v.1.1 -> for my Cas9 runs
#
# ! mkdir ./test/output/
# !wget https://s3-us-west-2.amazonaws.com/human-pangenomics/T2T/CHM13/assemblies/chm13.draft_v1.1.fasta.gz -O ./test/output/chm13.draft_v1.1.fasta.gz
# !gunzip ./test/output/chm13.draft_v1.1.fasta.gz
#
# --2024-04-17 15:37:02--  https://s3-us-west-2.amazonaws.com/human-pangenomics/T2T/CHM13/assemblies/chm13.draft_v1.1.fasta.gz
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.238.208, 52.218.235.48, 52.92.131.176, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.238.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 892637258 (851M) [binary/octet-stream]
# Saving to: ‘./test/output/chm13.draft_v1.1.fasta.gz’
#
# ./test/output/chm13 100%[===================>] 851.29M  39.5MB/s    in 22s
#
# 2024-04-17 15:37:24 (39.5 MB/s) - ‘./test/output/chm13.draft_v1.1.fasta.gz’ saved [892637258/892637258]
#
#
# !pwd
#
# /content/dimelo

# %%
from pathlib import Path
ref_genome_v1_1_file = Path('/home/michalula/data/ref_genomes/to_t2t_v1_1/chm13.draft_v1.1.fasta') #'./test/output/chm13.draft_v1.1.fasta')
ref_genome_v1_1_file
# Out:
# PosixPath('/home/michalula/data/ref_genomes/to_t2t_v1_1/chm13.draft_v1.1.fasta')

# %%
! head /home/michalula/data/ref_genomes/to_t2t_v1_1/chm13.draft_v1.1.fasta
# Out:
# >chr1
# CACCCTAAACCCTAACCCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCCTAAA
# CCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAA
# CCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCCTA
# ACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTA
# ACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCAACCCTAACCCTAA
# CCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAA
# CCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAA
# CCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAA
# CCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAA

# %%
# from matplotlib import pyplot as plt
# t2t_cd55 = 'chr1:206586162-206586192'
# # hg38_cd55 = 'chr1:207320867-207320897'

# # caspileup = '/Users/oberondixon-luinenburg/Documents/Ioannidis-Streets/dimelo_test_data/cd55_cas9/cd55_tss/pileup.sorted.bed.gz'
# # caspileup = '/content/drive/MyDrive/Michal Rozenwald/data/CD55/cas9_12ef_101923_misha/dimelo_new_package/cd55_tss_pileup_ws4000/pileup.sorted.bed.gz' # pileup
# # T_bedgz = Path('/content/drive/MyDrive/Michal Rozenwald/data/ENCODE/T_primary_ENCSR663MXB/ENCFF355UVU.m.sorted.bed.gz') #'/Users/oberondixon-luinenburg/Downloads/ENCFF279HCL.m.sorted.bed.gz')
# K562_bedgz = Path('/content/drive/MyDrive/Michal Rozenwald/data/ENCODE/T_primary_ENCSR663MXB/ENCFF355UVU.m.sorted.bed.gz') #'/Users/oberondixon-luinenburg/Downloads/ENCFF279HCL.m.sorted.bed.gz')

# from dimelo import plot_enrichment_profile
# from dimelo import load_processed
# import pysam

# fig, ax = plt.subplots()

# for file,region in zip([caspileup,T_bedgz],[t2t_cd55,hg38_cd55]):
#     mod_counts_vector,val_counts_vector = load_processed.pileup_vectors_from_bedmethyl(
#         bedmethyl_file = file,
#         motif = 'CG,0',
#         regions = region,
#         window_size = None
#     )
#     pileup_frac = mod_counts_vector / val_counts_vector
#     ax.plot(pileup_frac,'*',label=Path(file).name)

# plt.title(f'Region-of-interest near CD55 between bisulfite data and nanopore cas9 data\nT2T:{t2t_cd55}, hg38:{hg38_cd55}')
# plt.xlabel('relative genomic coordinate')
# # plt.legend()
# plt.subplots_adjust(bottom=0.5)  # Adjust the bottom
# # Placing the legend at the bottom outside of the figure
# plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), shadow=True, ncol=2)

# seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
# print(seq)
# seq_list =  [s for s in seq]
# plt.xticks(range(len(seq_list)), seq_list, size='small')

# %%
# from matplotlib import pyplot as plt
# t2t_cd55 = 'chr1:206586162-206586192'
# hg38_cd55 = 'chr1:207320867-207320897'

# # caspileup = '/Users/oberondixon-luinenburg/Documents/Ioannidis-Streets/dimelo_test_data/cd55_cas9/cd55_tss/pileup.sorted.bed.gz'
# caspileup = '/content/drive/MyDrive/Michal Rozenwald/data/CD55/cas9_12ef_101923_misha/dimelo_new_package/cd55_tss_pileup_ws4000/pileup.sorted.bed.gz' # pileup
# T_bedgz = Path('/content/drive/MyDrive/Michal Rozenwald/data/ENCODE/T_primary_ENCSR663MXB/ENCFF355UVU.m.sorted.bed.gz') #'/Users/oberondixon-luinenburg/Downloads/ENCFF279HCL.m.sorted.bed.gz')

# from dimelo import plot_enrichment_profile
# from dimelo import load_processed
# import pysam

# fig, ax = plt.subplots()

# for file,region in zip([caspileup,T_bedgz],[t2t_cd55,hg38_cd55]):
#     mod_counts_vector,val_counts_vector = load_processed.pileup_vectors_from_bedmethyl(
#         bedmethyl_file = file,
#         motif = 'CG,0',
#         regions = region,
#         window_size = None
#     )
#     pileup_frac = mod_counts_vector / val_counts_vector
#     ax.plot(pileup_frac,'*',label=Path(file).name)

# plt.title(f'Region-of-interest near CD55 between bisulfite data and nanopore cas9 data\nT2T:{t2t_cd55}, hg38:{hg38_cd55}')
# plt.xlabel('relative genomic coordinate')
# # plt.legend()
# plt.subplots_adjust(bottom=0.5)  # Adjust the bottom
# # Placing the legend at the bottom outside of the figure
# plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), shadow=True, ncol=2)

# seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
# print(seq)
# seq_list =  [s for s in seq]
# plt.xticks(range(len(seq_list)), seq_list, size='small')

# %% [markdown]
# # Update the .bam file format

# %%
# !modkit update-tags \
#  /home/michalula/data/cas9_nanopore/data/2024927_Cas9_R9_promethion_K562/to_t2t_v1_1/sort_aligned_T2Tv1_1_trim_bam_pass_merged.bam \
#     /home/michalula/data/cas9_nanopore/data/2024927_Cas9_R9_promethion_K562/to_t2t_v1_1/sort_aligned_T2Tv1_1_trim_bam_pass_merged.updated.bam \
#  --mode ambiguous

# %%
# ! samtools index /home/michalula/data/cas9_nanopore/data/2024927_Cas9_R9_promethion_K562/to_t2t_v1_1/sort_aligned_T2Tv1_1_trim_bam_pass_merged.updated.bam

# %%
bam_path = "/home/michalula/data/cas9_nanopore/data/20241127_Cas9_K562unedited_day2_R9_minion/post_seq_basecall/5mCG/to_t2t_v1_1/sort_align_t2t_v1_1_trim_20241127_MR_Cas9_K562unedited_day2_R9min_converted_fast5.dna_r9.4.1_e8_sup@v3.3.5mCG.bam"
# "/home/michalula/data/cas9_nanopore/data/2024927_Cas9_R9_promethion_K562/to_t2t_v1_1/sort_aligned_T2Tv1_1_trim_bam_pass_merged.updated.bam"


# "/home/michalula/data/cas9_nanopore/data/20231019_cas9_12ef_Jurkat/cas9_12ef_101923_misha_mod_mappings.sorted_mC_only.updated.bam"
# "/home/michalula/data/cas9_nanopore/data/20231019_cas9_12ef_Jurkat/cas9_12ef_101923_misha_mod_mappings.sorted_mC_only.bam"

# "/home/michalula/data/cas9_nanopore/data/2024927_Cas9_R9_promethion_K562/post_seq_basecall_align/sort_aligned_t2t_v1_1_trimmed_postrun_basecall_sup_20240927_cas9_R9_promethion.bam"
# "/home/michalula/data/cas9_nanopore/data/2024927_Cas9_R9_promethion_K562/to_t2t_v1_1/more_mismatches/aligned_k16_t2t_v1_1_trim_bam_pass_merged/sort_aligned_dorado_k16_t2t_v1_1_trim_bam_pass_merged.bam"
# "/home/michalula/data/cas9_nanopore/data/20231019_cas9_12ef_Jurkat/cas9_12ef_101923_misha_mod_mappings.sorted_mC_only.bam"
bam_path
# Out:
# '/home/michalula/data/cas9_nanopore/data/20241127_Cas9_K562unedited_day2_R9_minion/post_seq_basecall/5mCG/to_t2t_v1_1/sort_align_t2t_v1_1_trim_20241127_MR_Cas9_K562unedited_day2_R9min_converted_fast5.dna_r9.4.1_e8_sup@v3.3.5mCG.bam'

# %%
output_dir = Path("./dimelo_v2_output")
# Path('/content/drive/MyDrive/Michal Rozenwald/data/CD55/cas9_12ef_101923_misha/dimelo_new_package') # './test/output')

output_dir.mkdir(exist_ok=True)
output_dir
# Out:
# PosixPath('dimelo_v2_output')

# %%
output_dir,bam_path
# Out:
# (PosixPath('dimelo_v2_output'),
#  '/home/michalula/data/cas9_nanopore/data/20241127_Cas9_K562unedited_day2_R9_minion/post_seq_basecall/5mCG/to_t2t_v1_1/sort_align_t2t_v1_1_trim_20241127_MR_Cas9_K562unedited_day2_R9min_converted_fast5.dna_r9.4.1_e8_sup@v3.3.5mCG.bam')

# %% [markdown]
# # using domelo modkit_parsing_beta :

# %%
# using domelo modkit_parsing_beta :
t2t_v1_1_cd55_30bps = 'chr1:206586162-206586192'

extract_file, extract_regions = parse_bam.extract(
    input_file=bam_path, # ctcf_bam_file_updated
    output_name='cas9_12ef_101923_beta_extract_30bps_chr1_206586162_206586192_wsNone_thresh190', # _ws4000 'ctcf_demo_extract',
    ref_genome=ref_genome_v1_1_file, # ref_genome_file,
    output_directory=output_dir,
    regions=t2t_v1_1_cd55_30bps, # [cd55_interest_target_regions], # ctcf_target_regions,ctcf_off_target_regions],
    motifs=['CG,0'], # ['A,0','CG,0'],
    thresh=190,
    window_size=None,

    # cores = 1, # uncomment this line if your process appears to be terminating early (reduces memory usage)
    # quiet = True,
    # cleanup = False,
    # log=True,
)
# Out:
# No specified number of cores requested. 24 available on machine, allocating all.
# Modification threshold of 190 assumed to be for range 0-255. 190/255=0.7450980392156863 will be sent to modkit.
#           | Step 1: Identify motif locations in chm13.draft_v1.1.fasta   0% | 00:00
#           | Step 2: Parse regions in sort_align_t2t_v1_1_trim_20241127_MR_Cas9_K562unedited_day2_R9min_convert…
#           |    0%
#           | Transferring 338 from reads.CG,0.txt into reads.combined_basemods.h5, new size 338   0% | 00:00<?

# %%
read_data_list, datasets, _ = load_processed.read_vectors_from_hdf5(
    file=extract_file, # extract_file_no_thresh, # raw modification probabilities
    regions=t2t_v1_1_cd55_30bps, # cd55_30bps_interest_coords, # ctcf_target_regions,
    motifs=['CG,0'], # 'A,0'],
    window_size=None,
)
# Print out the data from the first read
for idx,dataset in enumerate(datasets):
    print(dataset)
    for read_data in read_data_list:
        print('\t',read_data[idx])
        break
# Out:
# chromosome
# 	 chr1
# mod_vector
# 	 [False False False ...  True False False]
# motif
# 	 CG,0
# read_end
# 	 206589905
# read_name
# 	 7fe89754-6dee-49f5-bd73-768e5ce91c0a
# read_start
# 	 206582599
# strand
# 	 -
# val_vector
# 	 [False False False ...  True False  True]
# region_start
# 	 206586162
# region_end
# 	 206586192
# region_strand
# 	 .
# CG,0_mod_fraction
# 	 0.625

# %%
read_data_list
# Out:
# [('chr1',
#   array([False, False, False, ...,  True, False, False]),
#   'CG,0',
#   np.int32(206589905),
#   '7fe89754-6dee-49f5-bd73-768e5ce91c0a',
#   np.int32(206582599),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.625)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590273),
#   'd6019a9a-d70f-4567-bc16-7808d01b17bc',
#   np.int32(206582921),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590164),
#   '1b21f22c-2e81-49ed-883f-c1e50c525d9d',
#   np.int32(206582940),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589902),
#   '87b77c7f-b1f5-45b5-829f-cc08c6a5313f',
#   np.int32(206583025),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589941),
#   'e7b77988-e4b4-48bb-b42b-fbbbc4b2f9b6',
#   np.int32(206583038),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589895),
#   '57dee68b-b812-41f1-8599-773c6d6f14b5',
#   np.int32(206583039),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589912),
#   '562bb8f6-c257-4f66-9ac6-8d402287060e',
#   np.int32(206583047),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590108),
#   '42d50ee8-c2d3-4e2f-bc42-7b2b90a7cd6a',
#   np.int32(206583055),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589909),
#   'db24102c-dada-4a7c-8c0a-c3faa0b5196d',
#   np.int32(206583059),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590105),
#   '4dda088d-9f01-4b88-88a9-cc98725f258a',
#   np.int32(206583061),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.1111111111111111)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590022),
#   '66b7fed8-98c8-4050-8007-b48219743a4b',
#   np.int32(206583062),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ...,  True, False,  True]),
#   'CG,0',
#   np.int32(206589908),
#   '6c8d8207-d900-456c-8e20-f53be7fe9c17',
#   np.int32(206583070),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.5)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589933),
#   '6e8c5ea8-580b-4fb5-b8fa-b5b1039c5fe8',
#   np.int32(206583072),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589944),
#   '61cf5859-bd11-4fb4-8e04-036d840c4b34',
#   np.int32(206583081),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589938),
#   '88cbd243-2c59-49aa-a9a2-80462c75bd96',
#   np.int32(206583085),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.25)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589848),
#   '5e4e14b2-c94e-4890-9015-8e882fc43b40',
#   np.int32(206583094),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589908),
#   'aa795279-ed40-4b80-9a7f-248f3163d8c6',
#   np.int32(206583100),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.3333333333333333)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589812),
#   '482993da-397a-4905-883d-3beb34d712e3',
#   np.int32(206583103),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ...,  True, False,  True]),
#   'CG,0',
#   np.int32(206589841),
#   '93b37cb7-1f53-4fc2-83a0-2b496cb6a8d2',
#   np.int32(206583112),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.25)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589913),
#   '960a4faa-034e-4b56-be12-fc5a1b259fa2',
#   np.int32(206583112),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589935),
#   '53779f75-ddd3-4c9d-b9a7-590b4b88b8ca',
#   np.int32(206583113),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.4)),
#  ('chr1',
#   array([False, False, False, ..., False, False,  True]),
#   'CG,0',
#   np.int32(206590107),
#   '100b0370-47c9-4cfd-8da3-1ee82b4d2ff1',
#   np.int32(206583114),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.2857142857142857)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590080),
#   '93b9674c-ef4f-4d8e-9f4a-8dbc4295ebb2',
#   np.int32(206583115),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590067),
#   'e9d977be-b1f9-489b-955f-70d0ed8c220c',
#   np.int32(206583119),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589918),
#   '7a45d1e4-db64-4e21-a9dc-c7dc309fa1ce',
#   np.int32(206583119),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.2222222222222222)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589938),
#   'c5f52962-cf7b-4122-acce-6e457e8093db',
#   np.int32(206583121),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.125)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589895),
#   'cfd25dd3-d940-4054-b762-347edc86beae',
#   np.int32(206583121),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589936),
#   'f1d616c0-b742-4c4e-8e34-13a1b7a2482c',
#   np.int32(206583123),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589932),
#   '9d816b0b-d7eb-41e9-a06b-444a8b7132d0',
#   np.int32(206583127),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.125)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589940),
#   'ef494583-f40c-408f-923d-1f8fc676ffd0',
#   np.int32(206583127),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590120),
#   '2db50f71-e8c5-485d-8ab1-39a69e250438',
#   np.int32(206583127),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.14285714285714285)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589912),
#   '9d1addbf-b4fa-461c-880e-775b1fe0c787',
#   np.int32(206583128),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589816),
#   '5037b40d-4cf4-48ef-8d71-f6e4450736bb',
#   np.int32(206583129),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589870),
#   '49415fa0-b144-412d-9311-26bd040ea500',
#   np.int32(206583129),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ...,  True, False, False]),
#   'CG,0',
#   np.int32(206589938),
#   '2452b0c6-64c3-4ce0-afee-2e44572a54b4',
#   np.int32(206583130),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.125)),
#  ('chr1',
#   array([False, False, False, ...,  True, False,  True]),
#   'CG,0',
#   np.int32(206589877),
#   'b77dbcee-bd77-4903-9068-575d486d7fad',
#   np.int32(206583131),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.75)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589922),
#   '7c12ebf6-6b5b-4fca-bf9a-4868525d43ec',
#   np.int32(206583131),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589911),
#   'fe5eb377-d56a-4aea-b5aa-a32305b53889',
#   np.int32(206583132),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ...,  True, False,  True]),
#   'CG,0',
#   np.int32(206589900),
#   '849e8314-c732-4843-a4f7-def87329d349',
#   np.int32(206583132),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.2857142857142857)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589904),
#   '967a016c-edac-4875-bd03-0d698ebe32be',
#   np.int32(206583132),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589937),
#   '92b323b3-93c6-4f88-a040-2aec3b0e6b34',
#   np.int32(206583133),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589913),
#   '9e4ca39e-835e-42c0-b4cb-cf404cf32df0',
#   np.int32(206583134),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589890),
#   '0942d14d-7b3f-48f6-8bff-ab65a7bd8d75',
#   np.int32(206583134),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.16666666666666666)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590088),
#   'c0fb48e9-8e75-4bc9-a9ce-f9dc94974075',
#   np.int32(206583135),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.25)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589930),
#   'f6073de6-656b-4dd2-9c7a-daddb37b02bb',
#   np.int32(206583135),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False,  True]),
#   'CG,0',
#   np.int32(206590054),
#   'bbc62b70-186a-4125-8be5-9cfe24283e38',
#   np.int32(206583136),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.3333333333333333)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589921),
#   '93745369-cd1c-4578-9838-575c2973c978',
#   np.int32(206583136),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589914),
#   'a9abcad8-a42c-44bf-9300-284e8b1a7823',
#   np.int32(206583136),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589895),
#   'c6afe8cd-57a2-441e-8b2c-88292baf19d2',
#   np.int32(206583137),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589934),
#   '5a5589aa-b9dc-4265-94d5-faa29ca2b452',
#   np.int32(206583137),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589911),
#   '2770d398-4158-4ed7-8f6b-a521fbb3d9c8',
#   np.int32(206583138),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589859),
#   '11e9e68a-33d1-4b42-935b-62bad61c9166',
#   np.int32(206583138),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ...,  True, False,  True]),
#   'CG,0',
#   np.int32(206589929),
#   '88c3aaf9-adb5-4b37-8104-2a83250b5ffd',
#   np.int32(206583138),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.25)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589903),
#   'c9b589b8-aeb2-428f-917e-7f698084b69c',
#   np.int32(206583139),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589929),
#   '76e62b98-8fc6-4758-9472-d4d211e31016',
#   np.int32(206583139),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.14285714285714285)),
#  ('chr1',
#   array([False, False, False, ..., False, False,  True]),
#   'CG,0',
#   np.int32(206589917),
#   '2f2e322f-e0f8-4507-892e-5dd97f98df29',
#   np.int32(206583140),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.16666666666666666)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589888),
#   '9a53e667-3598-438f-bc60-06fc326ca513',
#   np.int32(206583140),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.14285714285714285)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589924),
#   '0906889e-dc91-414f-874c-1b250b0fcd4f',
#   np.int32(206583140),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590107),
#   '950cb495-1f28-4b4e-8ee3-a4fb1e5bfd13',
#   np.int32(206583140),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589901),
#   '46a9cbc6-5495-4d45-86f7-0112611fa871',
#   np.int32(206583141),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589941),
#   '1656dc1c-d7df-478a-96c6-6fa33956d2c8',
#   np.int32(206583141),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589908),
#   '447a1dad-8e12-4df3-ab3f-03ce20273724',
#   np.int32(206583141),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ...,  True, False,  True]),
#   'CG,0',
#   np.int32(206589889),
#   '5c7b5af3-1bec-42c9-8068-2e9bad3f5937',
#   np.int32(206583142),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.25)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589962),
#   '59d00447-0a32-436b-bd48-28834a28a89b',
#   np.int32(206583142),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589867),
#   'd332a788-beca-4817-a809-51e362f51f73',
#   np.int32(206583142),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589107),
#   'c588246b-b5e1-4875-a510-459b75fc6961',
#   np.int32(206583143),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.125)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590081),
#   '496cc8ee-abbe-436a-b45c-2553612ee420',
#   np.int32(206583143),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589908),
#   'fc687320-d3c8-4db8-9d13-9d989e524bb7',
#   np.int32(206583143),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590075),
#   'dd963721-2e45-4415-9663-724ffd5ec5a3',
#   np.int32(206583143),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.2857142857142857)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589837),
#   '708ae5d2-d2ff-41e1-a8e2-1b594288d890',
#   np.int32(206583144),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589903),
#   'e15fcfb4-bbb5-4ba3-a252-78743f525ed0',
#   np.int32(206583144),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.625)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589895),
#   '3824fedd-5d95-4b38-8b93-546574a55942',
#   np.int32(206583144),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589881),
#   'd0d9efa8-3013-4c32-95cc-65f239a37bb3',
#   np.int32(206583144),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589953),
#   '03c8abf2-d631-4da4-bf21-cf7bb90f4eec',
#   np.int32(206583144),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589931),
#   'f2d66390-1352-4ce7-b4da-b436c3927185',
#   np.int32(206583145),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589924),
#   '126de7e4-805e-4247-96b3-31afc3c9462f',
#   np.int32(206583145),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589900),
#   'b775b91f-e717-4ead-a0d0-51563480230f',
#   np.int32(206583145),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589914),
#   '327b0292-8a52-4a4a-95b3-87b889728e03',
#   np.int32(206583145),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False,  True]),
#   'CG,0',
#   np.int32(206589909),
#   'fe854fc0-c893-4640-b9e3-a97a37358142',
#   np.int32(206583145),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.14285714285714285)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589869),
#   'f0526ff0-86f6-498b-817d-1060b22bd646',
#   np.int32(206583146),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589925),
#   '5f4638be-7d91-4a33-bbc9-a4eb4bebf5e7',
#   np.int32(206583147),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589889),
#   '799d6f26-c515-43d9-b392-5a80661cb857',
#   np.int32(206583147),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589894),
#   'ae247b71-8567-412f-a368-202ebb8dbe0b',
#   np.int32(206583148),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.16666666666666666)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589903),
#   'b41b7180-16c5-4797-837f-8ac1845630f7',
#   np.int32(206583148),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589909),
#   '4587425e-b5e7-4c38-b1b5-6cc8e93f8833',
#   np.int32(206583148),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590114),
#   '37540b37-b2a4-49c7-ad7b-76f82271475a',
#   np.int32(206583148),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590085),
#   '83815368-6871-42a1-8d3f-4bf95d7e703f',
#   np.int32(206583148),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589895),
#   'e9094921-3f1f-4880-b9d9-c231fc9a82cc',
#   np.int32(206583148),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589798),
#   '07cd4dcc-cec9-48d5-b9c2-9f9726268ed7',
#   np.int32(206583149),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.25)),
#  ('chr1',
#   array([False, False, False, ...,  True, False,  True]),
#   'CG,0',
#   np.int32(206590182),
#   '5c8dda3a-b6ef-4d45-92cb-b6b34c5aa5a0',
#   np.int32(206583149),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.25)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589842),
#   '9569d774-c440-4165-a7a2-cb713c3b5f7a',
#   np.int32(206583149),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.4)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589886),
#   '110e7066-770b-4099-8255-e791a488a099',
#   np.int32(206583149),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589913),
#   'a76deeb3-b535-47e0-82f0-5d38533cd422',
#   np.int32(206583149),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False,  True]),
#   'CG,0',
#   np.int32(206590092),
#   'b641d443-25a7-4e5c-9e15-e62a4f5c815b',
#   np.int32(206583150),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.2857142857142857)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589920),
#   '7d738343-cf95-40c7-b6e8-66061859106e',
#   np.int32(206583150),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589963),
#   'de819a7a-b33e-4097-ab4a-aa890de6c050',
#   np.int32(206583150),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590126),
#   'dec74ab0-eea9-446c-8aee-5e917fc3918e',
#   np.int32(206583150),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ...,  True, False,  True]),
#   'CG,0',
#   np.int32(206589823),
#   '57d7b894-6cef-40c8-8109-d48a7963c11b',
#   np.int32(206583150),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.3333333333333333)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589884),
#   'f4900a29-0de6-42a2-b23e-31e5035acbcc',
#   np.int32(206583150),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589914),
#   'e170e268-b1ef-4c94-8a02-098a30eab28c',
#   np.int32(206583151),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589955),
#   '62b9dd4d-3e82-4ba9-a082-afb1d425107f',
#   np.int32(206583151),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589902),
#   '5c985967-4693-48df-8364-0f936981a7d8',
#   np.int32(206583151),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589939),
#   'f288767e-9c35-456e-84b1-b20995475147',
#   np.int32(206583151),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589907),
#   '195a3868-a0c3-46f2-bccb-d37c74ca39ae',
#   np.int32(206583151),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.5714285714285714)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589946),
#   '4f3c09b9-3722-4bfe-b194-ba5013105c24',
#   np.int32(206583151),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ...,  True, False, False]),
#   'CG,0',
#   np.int32(206589936),
#   'a8963252-ffca-45e8-a1af-080b8ec506f5',
#   np.int32(206583151),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.16666666666666666)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589941),
#   '432dee1c-86e4-4eb4-a2cf-1873a4116918',
#   np.int32(206583151),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589919),
#   '45377606-0164-4bd8-a482-dbbf0f583293',
#   np.int32(206583152),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589926),
#   '5f774ddc-120c-4089-ac40-e3aa8edb0d60',
#   np.int32(206583152),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589907),
#   'd67cbdb2-bd39-4d9e-a4e9-29be90fd71f3',
#   np.int32(206583152),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589951),
#   'c6308572-1674-4e1d-b484-8c7acc818f8a',
#   np.int32(206583152),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589889),
#   'b59fd145-4a60-4ed9-9554-79f8c1d3ae21',
#   np.int32(206583152),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ...,  True, False, False]),
#   'CG,0',
#   np.int32(206590110),
#   '22c5d749-48e3-453a-b0b5-2692dbf521ad',
#   np.int32(206583152),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.14285714285714285)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589923),
#   'ca7d853c-9454-47ab-b726-eef09f9336c8',
#   np.int32(206583152),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589944),
#   '8b780f8d-dd3b-46a4-bbf6-ea154304470a',
#   np.int32(206583152),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589892),
#   '7b8581a9-4451-4312-81a7-ad8cd9a64eb7',
#   np.int32(206583152),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590139),
#   '8d2b32d8-3093-42e7-84e7-99fc1ec06dd3',
#   np.int32(206583152),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.14285714285714285)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590123),
#   '9639699f-5092-4988-8419-774e5c7a0f24',
#   np.int32(206583152),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589789),
#   '082ec985-0252-4452-95b0-95edc096930e',
#   np.int32(206583153),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.3333333333333333)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589923),
#   'd64cb43c-ebbe-4267-afb9-0589f21b16d2',
#   np.int32(206583153),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589910),
#   'cef19f3a-7cd6-43d4-be99-94ddb5987237',
#   np.int32(206583153),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589754),
#   'a95b6ade-7044-4226-a21c-d319c5fd35f1',
#   np.int32(206583154),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589874),
#   '85d37f77-5d75-470b-acb3-fe80de6bd19d',
#   np.int32(206583154),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589942),
#   '94ba1cdf-ee79-46cc-8cf4-2eee2a8d349b',
#   np.int32(206583154),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ...,  True, False,  True]),
#   'CG,0',
#   np.int32(206589923),
#   '216ffc07-8ef6-4fc6-898b-c913e166d1f0',
#   np.int32(206583154),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.875)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589924),
#   'bfd58b40-7095-4c2a-aa5b-ae16f07c4280',
#   np.int32(206583154),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589912),
#   '462e20c2-4147-4a7d-a366-967b983f70ac',
#   np.int32(206583154),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589914),
#   'd4562c61-eb5c-4f02-8da1-8d4998903d4b',
#   np.int32(206583155),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589900),
#   '374743dd-d463-435e-912c-9f3d44ee59f0',
#   np.int32(206583155),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589963),
#   '52648902-3a58-4992-a702-b909c5c58b00',
#   np.int32(206583156),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589907),
#   'a270d36a-ebfb-4ec0-8a60-e5cfcf4b550a',
#   np.int32(206583156),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589955),
#   '82b39417-ffd8-4539-ab93-0e3dd7a78dd7',
#   np.int32(206583156),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589878),
#   '756947df-42b2-476a-a2b5-2621bc2baaba',
#   np.int32(206583156),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.14285714285714285)),
#  ('chr1',
#   array([False, False, False, ..., False, False,  True]),
#   'CG,0',
#   np.int32(206589929),
#   '705e95ca-8a37-4b15-a6de-e4bf2c169cc2',
#   np.int32(206583156),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.2222222222222222)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589938),
#   '78b64497-a89f-4911-9774-4a9be8160503',
#   np.int32(206583156),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589939),
#   'f7834458-948a-4686-9987-8d08f6b818de',
#   np.int32(206583156),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590010),
#   'cc06076a-51f0-4a44-96fe-e9b147860c38',
#   np.int32(206583157),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589876),
#   '291e9f37-0249-4c32-8410-dadaa6d39fa3',
#   np.int32(206583157),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589926),
#   'd4348023-f8bc-4685-9b1d-e6164462fead',
#   np.int32(206583157),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589922),
#   'e0b115f5-2699-464b-b448-f6f13fbd1613',
#   np.int32(206583157),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589915),
#   'cf405ff1-f32f-410a-950f-9a9644f2fb55',
#   np.int32(206583157),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589909),
#   '3d51be38-320a-4c93-8066-22793903ada0',
#   np.int32(206583158),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589937),
#   '3f678c9c-edfe-4c89-8e25-80a8f4fcab30',
#   np.int32(206583158),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589932),
#   '70c914c4-5d38-45c2-8150-460ae57c74a2',
#   np.int32(206583158),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589943),
#   'a6c71fe0-ceb6-4006-9b2f-2a2439e2bae1',
#   np.int32(206583158),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589932),
#   '8a540752-a6ce-46ef-bca2-25d1f2a4d9dc',
#   np.int32(206583158),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False,  True]),
#   'CG,0',
#   np.int32(206589971),
#   '70c3a514-e36b-4dc1-936a-23a9d88475f5',
#   np.int32(206583159),
#   '+',
#   array([False, False, False, ..., False, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(1.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589937),
#   '005f1394-3c31-440d-b193-989ac3086787',
#   np.int32(206583159),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589908),
#   'a139b82e-f1d5-42a3-a800-71daf91d39ec',
#   np.int32(206583159),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589922),
#   '0f2e6fa1-516a-423d-9a03-8392d262cee7',
#   np.int32(206583159),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589914),
#   'd049d095-0d7d-4fda-bbfb-823c35d7f157',
#   np.int32(206583159),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590135),
#   '59f97973-b907-422a-a62c-f593f1d315d5',
#   np.int32(206583159),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589901),
#   'afca4bab-e452-4533-bf45-21578d572ad8',
#   np.int32(206583159),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589921),
#   'f0d78814-2516-45ca-9334-85287ddda8db',
#   np.int32(206583159),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589897),
#   '7f8c9999-30a9-47b9-b4a1-2358fc6fc32a',
#   np.int32(206583159),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589894),
#   'f19e4fae-165b-4cdc-aa46-12ee9e8ed1cd',
#   np.int32(206583160),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589901),
#   '5b4dda82-4399-4854-9549-342fa0ac658b',
#   np.int32(206583160),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589907),
#   '7452d09e-36a1-45a3-bc92-1c2e4becdc7d',
#   np.int32(206583160),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ...,  True, False,  True]),
#   'CG,0',
#   np.int32(206589918),
#   '843931c6-349c-4d0e-a6cf-3a21edb27217',
#   np.int32(206583160),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.375)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589933),
#   'a2278448-523d-4edf-b5ae-0ba8b6d335f7',
#   np.int32(206583160),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589862),
#   'd9e2011a-e2ce-4c71-9d30-a09d4aa39a49',
#   np.int32(206583161),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.125)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589933),
#   '4df4cf8b-ee8d-42a4-9328-67f812aa6e57',
#   np.int32(206583161),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589908),
#   '639335fa-0f93-45d1-8300-bea9f065c54a',
#   np.int32(206583161),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589929),
#   'f0c83d4f-ab3b-4150-b597-0d956b297bed',
#   np.int32(206583161),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.14285714285714285)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589920),
#   'feddc036-0245-4961-b331-53d962d2fc20',
#   np.int32(206583161),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590093),
#   '5c9aeced-19e2-46c7-ae71-868916391649',
#   np.int32(206583161),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590117),
#   'ddfa493b-59fe-4d1c-9afa-4f997d271c2c',
#   np.int32(206583161),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False,  True]),
#   'CG,0',
#   np.int32(206589892),
#   '2631e1ad-07de-4bf8-907d-804a3ddf764b',
#   np.int32(206583161),
#   '+',
# ...
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False,  True, False,  True, False,  True,
#          False,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False]),
#   'CG,0',
#   np.int32(206589825),
#   '55a74c9a-ad86-4bb1-8cb8-84eed104d3b1',
#   np.int32(206585706),
#   '+',
#   array([False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False,  True, False,
#          False, False, False,  True, False, False, False, False,  True,
#          False,  True, False,  True, False,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False]),
#   'CG,0',
#   np.int32(206589904),
#   'fb2ac790-273d-4e19-80c2-f11ad92ccfbb',
#   np.int32(206585807),
#   '-',
#   array([False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False,  True, False, False,
#          False, False,  True, False, False, False, False, False, False,
#          False, False,  True, False,  True, False,  True, False,  True,
#          False,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0))]

# %%
read_data_list[0][1] #['mod_vector']
# Out:
# array([False, False, False, ...,  True, False, False])

# %%
from matplotlib import pyplot as plt
from dimelo import plot_reads

plot_reads.plot_reads(
    extract_file, # extracted_h5,
    regions = 'chr1:206582520-206585020',
    motifs = ['CG,0'],
    thresh = 0.75,
    sort_by = ['shuffle','strand'],
    relative = False,
    window_size = None, # 5000,
    s=5,
)
# Out:
# <Axes: xlabel='pos', ylabel='read_name'>

# %%
from matplotlib import pyplot as plt
from dimelo import plot_reads

plot_reads.plot_reads(
    extract_file, # extracted_h5,
    regions = 'chr1:206582520-206585020',
    motifs = ['CG,0'],
    thresh = 0.75,
    sort_by = ['shuffle','strand'],
    relative = False,
    window_size =  5000, # None, #
    s=5,
)
# Out:
# <Axes: xlabel='pos', ylabel='read_name'>

# %%
# chr1_
206586162-206586192
# Out:
# -30

# %%
# ref_genome_v1_1_file
window_size = 4000
outname = f'cd55_window{window_size}'
num_cores = 32

# cas9 = parse_bam.extract(
#     input_file=bam_cas9_12ef_101923_updated, # cd55_filepath,
#     output_name=outname,
#     ref_genome=ref_genome_v1_1_file, # '/clusterfs/nilah/oberon/genomes/chm13.draft_v1.1.fasta',
#     regions=t2t_cd55_30bps, # bed_files="chr1:206586162-206586192", # [bed_region],
#     basemods=['CG,0'],
#     cores=num_cores,
#     thresh=0.75,
#     window_size=window_size,
# )
t2t_v1_1_cd55_30bps = 'chr1:206586162-206586192'

# = extract_file, extract_regions
cas9  = parse_bam.extract(
    input_file=bam_path, # ctcf_bam_file_updated
    output_name='cas9_12ef_101923_extract_chr1_206586162_206586192_ws4000_thresh075', # _ws4000 'ctcf_demo_extract',
    ref_genome=ref_genome_v1_1_file, # ref_genome_file,
    output_directory=output_dir,
    regions=t2t_v1_1_cd55_30bps, # [cd55_interest_target_regions], # ctcf_target_regions,ctcf_off_target_regions],
    motifs=['CG,0'], # ['A,0','CG,0'],
    thresh=0.75, # 190,
    window_size=window_size, # None,
    # cores = 1, # uncomment this line if your process appears to be terminating early (reduces memory usage)
    # quiet = True,
    # cleanup = False,
    # log=True,
)
# Out:
# No specified number of cores requested. 24 available on machine, allocating all.
# Modification threshold of 0.75 will be treated as coming from range 0-1.
#           | Step 1: Identify motif locations in chm13.draft_v1.1.fasta   0% | 00:00
#           | Step 2: Parse regions in sort_align_t2t_v1_1_trim_20241127_MR_Cas9_K562unedited_day2_R9min_convert…
#           |    0%
#           | Transferring 366 from reads.CG,0.txt into reads.combined_basemods.h5, new size 366   0% | 00:00<?

# %%
extract_file_ws4000, extract_regions_ws4000 = cas9
extract_file_ws4000
# Out:
# PosixPath('dimelo_v2_output/cas9_12ef_101923_extract_chr1_206586162_206586192_ws4000_thresh075/reads.combined_basemods.h5')

# %%
plot_reads.plot_reads(
    extract_file_ws4000, # cas9,
    "chr1:206586162-206586192", # bed_region,
    ['CG,0'],
    window_size = 4000,
    s=1)
plt.xlabel('bp relative to CD55 differential methylated region (t2t v1.1 chr1:206586177)')
plt.title('cas9_12ef_101923_misha_mod_mappings.retagged.sorted_mC_only.bam CpG extraction')
# Out:
# Text(0.5, 1.0, 'cas9_12ef_101923_misha_mod_mappings.retagged.sorted_mC_only.bam CpG extraction')

# %%
plot_reads.plot_reads(
    extract_file_ws4000, # cas9,
    "chr1:206586162-206586192", # bed_region,
    ['CG,0'],
    window_size = 4000,
    sort_by = ['strand'], # ['shuffle','strand'],
    # sort_by = ['shuffle', 'strand', 'region_start'], # ['shuffle','strand'],
    s=1)
plt.xlabel('bp relative to CD55 differential methylated region (t2t v1.1 chr1:206586177)')
# plt.title('cas9_12ef_101923_misha_mod_mappings.retagged.sorted_mC_only.bam CpG extraction')
# Out:
# Text(0.5, 0, 'bp relative to CD55 differential methylated region (t2t v1.1 chr1:206586177)')

# %% [markdown]
# # Sort reads by the region start

# %%
# Sort reads by the region start

plot_reads.plot_reads(
    extract_file_ws4000, # cas9,
    "chr1:206586162-206586192", # bed_region,
    ['CG,0'],
    window_size = 4000,
    sort_by = ['region_start'], # ['shuffle','strand'],
    # sort_by = ['shuffle', 'strand', 'region_start'], # ['shuffle','strand'],
    s=1)
# plt.xlabel('bp relative to CD55 differential methylated region (t2t v1.1 chr1:206586177)')
# plt.title('cas9_12ef_101923_misha_mod_mappings.retagged.sorted_mC_only.bam CpG extraction')
# Out:
# <Axes: xlabel='pos', ylabel='read_name'>

# %%
ax=plot_reads.plot_reads(
    extract_file_ws4000, # cas9,
    "chr1:206586162-206586192", # bed_region,
    ['CG,0'],
    window_size = 4000,
    sort_by = ['region_start', 'shuffle'], # ['shuffle','strand'],
    # sort_by = ['shuffle', 'strand', 'region_start'], # ['shuffle','strand'],
    s=1)
ax.get_legend() 
#only works after the legend was created. Try
leg = ax.legend()

plt.xlabel('bp relative to CD55 differential methylated region (t2t v1.1 chr1:206586177)')
plt.title('cas9_12ef_101923_misha_mod_mappings.retagged.sorted_mC_only.bam CpG extraction')
# Out:
# Text(0.5, 1.0, 'cas9_12ef_101923_misha_mod_mappings.retagged.sorted_mC_only.bam CpG extraction')

# %%
ax = plot_reads.plot_reads(
    extract_file_ws4000, # cas9,
    "chr1:206586162-206586192", # bed_region,
    ['CG,0'],
    window_size = 4000,
    sort_by = ['region_start', 'strand'], # ['shuffle','strand'],
    # sort_by = ['shuffle', 'strand', 'region_start'], # ['shuffle','strand'],
    s=1)
plt.xlabel('bp relative to CD55 differential methylated region (t2t v1.1 chr1:206586177)')
plt.title('cas9_12ef_101923_misha_mod_mappings.retagged.sorted_mC_only.bam CpG extraction')
# Out:
# Text(0.5, 1.0, 'cas9_12ef_101923_misha_mod_mappings.retagged.sorted_mC_only.bam CpG extraction')

# %%
ax = plot_reads.plot_reads(
    extract_file_ws4000, # cas9,
    "chr1:206586162-206586192", # bed_region,
    ['CG,0'],
    window_size = 4000,
    sort_by = ['shuffle','strand'], # ['region_start', 'strand'], #
    # sort_by = ['shuffle', 'strand', 'region_start'], # ['shuffle','strand'],
    s=1)
plt.xlabel('bp relative to CD55 differential methylated region (t2t v1.1 chr1:206586177)')
plt.title('cas9_12ef_101923_misha_mod_mappings.retagged.sorted_mC_only.bam CpG extraction')
# Out:
# Text(0.5, 1.0, 'cas9_12ef_101923_misha_mod_mappings.retagged.sorted_mC_only.bam CpG extraction')

# %%
from matplotlib import pyplot as plt
from dimelo import plot_reads

fig, ax = plt.subplots()

ax = plot_reads.plot_reads(
    extract_file, # extracted_h5,
    regions = t2t_v1_1_cd55_30bps, #'chr1:206582520-206585020',
    motifs = ['CG,0'],
    thresh = 0.75,
    sort_by = ['shuffle','strand'],
    # relative = False,
    relative = True,
    window_size = None, # 5000,
    s=5,
)
# plt.xlim(206582520,206585020)


seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
print(seq)
seq_list =  [s for s in seq]
plt.xticks(np.arange(len(seq_list)) - 15, seq_list, size='small')
# Out:
# CCGCCCCGAGGCGCGCGCGCGCGCGCGCAC
# ([<matplotlib.axis.XTick at 0x7c615e4e6850>,
#   <matplotlib.axis.XTick at 0x7c615ef1c410>,
#   <matplotlib.axis.XTick at 0x7c615e4ecdd0>,
#   <matplotlib.axis.XTick at 0x7c615e4dd050>,
#   <matplotlib.axis.XTick at 0x7c615e4dec50>,
#   <matplotlib.axis.XTick at 0x7c615e4c0750>,
#   <matplotlib.axis.XTick at 0x7c615e4c2950>,
#   <matplotlib.axis.XTick at 0x7c615e4c3a90>,
#   <matplotlib.axis.XTick at 0x7c615e378990>,
#   <matplotlib.axis.XTick at 0x7c615e310150>,
#   <matplotlib.axis.XTick at 0x7c615e312250>,
#   <matplotlib.axis.XTick at 0x7c615e4c37d0>,
#   <matplotlib.axis.XTick at 0x7c615e3e32d0>,
#   <matplotlib.axis.XTick at 0x7c615e3689d0>,
#   <matplotlib.axis.XTick at 0x7c615e36ab50>,
#   <matplotlib.axis.XTick at 0x7c615e31ccd0>,
#   <matplotlib.axis.XTick at 0x7c615e31ee90>,
#   <matplotlib.axis.XTick at 0x7c615e31c450>,
#   <matplotlib.axis.XTick at 0x7c615e3c5150>,
#   <matplotlib.axis.XTick at 0x7c615e3c7150>,
#   <matplotlib.axis.XTick at 0x7c615e3bd110>,
#   <matplotlib.axis.XTick at 0x7c615e3bf190>,
#   <matplotlib.axis.XTick at 0x7c615e3f1190>,
#   <matplotlib.axis.XTick at 0x7c615e3c7b50>,
#   <matplotlib.axis.XTick at 0x7c615e3f3510>,
#   <matplotlib.axis.XTick at 0x7c615e3f55d0>,
#   <matplotlib.axis.XTick at 0x7c615e3f76d0>,
#   <matplotlib.axis.XTick at 0x7c615e3fd410>,
#   <matplotlib.axis.XTick at 0x7c615e3fcdd0>,
#   <matplotlib.axis.XTick at 0x7c615e3fcd10>],
#  [Text(-15, 0, 'C'),
#   Text(-14, 0, 'C'),
#   Text(-13, 0, 'G'),
#   Text(-12, 0, 'C'),
#   Text(-11, 0, 'C'),
#   Text(-10, 0, 'C'),
#   Text(-9, 0, 'C'),
#   Text(-8, 0, 'G'),
#   Text(-7, 0, 'A'),
#   Text(-6, 0, 'G'),
#   Text(-5, 0, 'G'),
#   Text(-4, 0, 'C'),
#   Text(-3, 0, 'G'),
#   Text(-2, 0, 'C'),
#   Text(-1, 0, 'G'),
#   Text(0, 0, 'C'),
#   Text(1, 0, 'G'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'G'),
#   Text(4, 0, 'C'),
#   Text(5, 0, 'G'),
#   Text(6, 0, 'C'),
#   Text(7, 0, 'G'),
#   Text(8, 0, 'C'),
#   Text(9, 0, 'G'),
#   Text(10, 0, 'C'),
#   Text(11, 0, 'G'),
#   Text(12, 0, 'C'),
#   Text(13, 0, 'A'),
#   Text(14, 0, 'C')])

# %%
from matplotlib import pyplot as plt
from dimelo import plot_reads

fig, ax = plt.subplots()

ax = plot_reads.plot_reads(
    extract_file, # extracted_h5,
    regions = t2t_v1_1_cd55_30bps, #'chr1:206582520-206585020',
    motifs = ['CG,0'],
    thresh = 0.75,
    sort_by = ['shuffle','strand'],
    # relative = False,
    relative = True,
    window_size = None, # 5000,
    s=5,
)
# plt.xlim(206582520,206585020)


seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
print(seq)
seq_list =  [s for s in seq]
plt.xticks(np.arange(len(seq_list)) - 15, seq_list, size='small')
# Out:
# CCGCCCCGAGGCGCGCGCGCGCGCGCGCAC
# ([<matplotlib.axis.XTick at 0x7c615e270590>,
#   <matplotlib.axis.XTick at 0x7c615e3e3490>,
#   <matplotlib.axis.XTick at 0x7c615e3714d0>,
#   <matplotlib.axis.XTick at 0x7c615e28e2d0>,
#   <matplotlib.axis.XTick at 0x7c615e28d610>,
#   <matplotlib.axis.XTick at 0x7c615e291e90>,
#   <matplotlib.axis.XTick at 0x7c615e293e90>,
#   <matplotlib.axis.XTick at 0x7c615e241c90>,
#   <matplotlib.axis.XTick at 0x7c615e3bc9d0>,
#   <matplotlib.axis.XTick at 0x7c615e29b0d0>,
#   <matplotlib.axis.XTick at 0x7c615e2a10d0>,
#   <matplotlib.axis.XTick at 0x7c615e2a3190>,
#   <matplotlib.axis.XTick at 0x7c615e2a1f90>,
#   <matplotlib.axis.XTick at 0x7c615e2a9890>,
#   <matplotlib.axis.XTick at 0x7c615e2abd90>,
#   <matplotlib.axis.XTick at 0x7c615e29dfd0>,
#   <matplotlib.axis.XTick at 0x7c615e25c150>,
#   <matplotlib.axis.XTick at 0x7c615e25dfd0>,
#   <matplotlib.axis.XTick at 0x7c615e24c910>,
#   <matplotlib.axis.XTick at 0x7c615e2c4790>,
#   <matplotlib.axis.XTick at 0x7c615e2c6850>,
#   <matplotlib.axis.XTick at 0x7c615e2c83d0>,
#   <matplotlib.axis.XTick at 0x7c615e2ca850>,
#   <matplotlib.axis.XTick at 0x7c615e2d03d0>,
#   <matplotlib.axis.XTick at 0x7c615e2a0ed0>,
#   <matplotlib.axis.XTick at 0x7c615e2d2a50>,
#   <matplotlib.axis.XTick at 0x7c615e2d8a10>,
#   <matplotlib.axis.XTick at 0x7c615e2dab10>,
#   <matplotlib.axis.XTick at 0x7c615e2e0bd0>,
#   <matplotlib.axis.XTick at 0x7c615e2d9b50>],
#  [Text(-15, 0, 'C'),
#   Text(-14, 0, 'C'),
#   Text(-13, 0, 'G'),
#   Text(-12, 0, 'C'),
#   Text(-11, 0, 'C'),
#   Text(-10, 0, 'C'),
#   Text(-9, 0, 'C'),
#   Text(-8, 0, 'G'),
#   Text(-7, 0, 'A'),
#   Text(-6, 0, 'G'),
#   Text(-5, 0, 'G'),
#   Text(-4, 0, 'C'),
#   Text(-3, 0, 'G'),
#   Text(-2, 0, 'C'),
#   Text(-1, 0, 'G'),
#   Text(0, 0, 'C'),
#   Text(1, 0, 'G'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'G'),
#   Text(4, 0, 'C'),
#   Text(5, 0, 'G'),
#   Text(6, 0, 'C'),
#   Text(7, 0, 'G'),
#   Text(8, 0, 'C'),
#   Text(9, 0, 'G'),
#   Text(10, 0, 'C'),
#   Text(11, 0, 'G'),
#   Text(12, 0, 'C'),
#   Text(13, 0, 'A'),
#   Text(14, 0, 'C')])

# %%
from matplotlib import pyplot as plt
from dimelo import plot_reads

fig, ax = plt.subplots()

ax = plot_reads.plot_reads(
    extract_file, # extracted_h5,
    regions = t2t_v1_1_cd55_30bps, #'chr1:206582520-206585020',
    motifs = ['CG,0'],
    thresh = 0.75,
    sort_by = ['shuffle', 'strand'], # 'region_start'], # 'strand'], # 'shuffle',
    # relative = False,
    relative = True,
    window_size = None, # 5000,
    s=5,
)
# plt.xlim(206582520,206585020)


seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
print(seq)
seq_list =  [s for s in seq]
plt.xticks(np.arange(len(seq_list)) - 15, seq_list, size='small')
# Out:
# CCGCCCCGAGGCGCGCGCGCGCGCGCGCAC
# ([<matplotlib.axis.XTick at 0x7c615e224d90>,
#   <matplotlib.axis.XTick at 0x7c615e2d3490>,
#   <matplotlib.axis.XTick at 0x7c615e2ba210>,
#   <matplotlib.axis.XTick at 0x7c615e321a10>,
#   <matplotlib.axis.XTick at 0x7c615e143950>,
#   <matplotlib.axis.XTick at 0x7c615e160f10>,
#   <matplotlib.axis.XTick at 0x7c615e161cd0>,
#   <matplotlib.axis.XTick at 0x7c615e12d150>,
#   <matplotlib.axis.XTick at 0x7c615e2e3ad0>,
#   <matplotlib.axis.XTick at 0x7c615e157e50>,
#   <matplotlib.axis.XTick at 0x7c615e171950>,
#   <matplotlib.axis.XTick at 0x7c615e161550>,
#   <matplotlib.axis.XTick at 0x7c615e239c10>,
#   <matplotlib.axis.XTick at 0x7c615e301950>,
#   <matplotlib.axis.XTick at 0x7c615e169890>,
#   <matplotlib.axis.XTick at 0x7c615e14c950>,
#   <matplotlib.axis.XTick at 0x7c615e14e9d0>,
#   <matplotlib.axis.XTick at 0x7c615e2d3dd0>,
#   <matplotlib.axis.XTick at 0x7c615e191090>,
#   <matplotlib.axis.XTick at 0x7c615e191890>,
#   <matplotlib.axis.XTick at 0x7c615e193a90>,
#   <matplotlib.axis.XTick at 0x7c615e197190>,
#   <matplotlib.axis.XTick at 0x7c615e19d0d0>,
#   <matplotlib.axis.XTick at 0x7c615e191750>,
#   <matplotlib.axis.XTick at 0x7c615e2e31d0>,
#   <matplotlib.axis.XTick at 0x7c615e126790>,
#   <matplotlib.axis.XTick at 0x7c615e2b8650>,
#   <matplotlib.axis.XTick at 0x7c615e19f850>,
#   <matplotlib.axis.XTick at 0x7c615e1a5950>,
#   <matplotlib.axis.XTick at 0x7c615e126f50>],
#  [Text(-15, 0, 'C'),
#   Text(-14, 0, 'C'),
#   Text(-13, 0, 'G'),
#   Text(-12, 0, 'C'),
#   Text(-11, 0, 'C'),
#   Text(-10, 0, 'C'),
#   Text(-9, 0, 'C'),
#   Text(-8, 0, 'G'),
#   Text(-7, 0, 'A'),
#   Text(-6, 0, 'G'),
#   Text(-5, 0, 'G'),
#   Text(-4, 0, 'C'),
#   Text(-3, 0, 'G'),
#   Text(-2, 0, 'C'),
#   Text(-1, 0, 'G'),
#   Text(0, 0, 'C'),
#   Text(1, 0, 'G'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'G'),
#   Text(4, 0, 'C'),
#   Text(5, 0, 'G'),
#   Text(6, 0, 'C'),
#   Text(7, 0, 'G'),
#   Text(8, 0, 'C'),
#   Text(9, 0, 'G'),
#   Text(10, 0, 'C'),
#   Text(11, 0, 'G'),
#   Text(12, 0, 'C'),
#   Text(13, 0, 'A'),
#   Text(14, 0, 'C')])

# %%
from matplotlib import pyplot as plt
from dimelo import plot_reads

fig, ax = plt.subplots()

ax = plot_reads.plot_reads(
    extract_file, # extracted_h5,
    regions = t2t_v1_1_cd55_30bps, #'chr1:206582520-206585020',
    motifs = ['CG,0'],
    thresh = 0.75,
    sort_by = ['shuffle', 'strand', 'region_start'], # 'strand'], # 'shuffle',
    # relative = False,
    relative = True,
    window_size = None, # 5000,
    s=5,
)
# plt.xlim(206582520,206585020)


seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
print(seq)
seq_list =  [s for s in seq]
plt.xticks(np.arange(len(seq_list)) - 15, seq_list, size='small')
# Out:
# CCGCCCCGAGGCGCGCGCGCGCGCGCGCAC
# ([<matplotlib.axis.XTick at 0x7c615e1d6c50>,
#   <matplotlib.axis.XTick at 0x7c615e1bb490>,
#   <matplotlib.axis.XTick at 0x7c615e204150>,
#   <matplotlib.axis.XTick at 0x7c615e207510>,
#   <matplotlib.axis.XTick at 0x7c615e181590>,
#   <matplotlib.axis.XTick at 0x7c615e182a90>,
#   <matplotlib.axis.XTick at 0x7c615e0283d0>,
#   <matplotlib.axis.XTick at 0x7c615e02aa50>,
#   <matplotlib.axis.XTick at 0x7c615e02cdd0>,
#   <matplotlib.axis.XTick at 0x7c615e018310>,
#   <matplotlib.axis.XTick at 0x7c615e01a410>,
#   <matplotlib.axis.XTick at 0x7c615e038550>,
#   <matplotlib.axis.XTick at 0x7c615e01aa10>,
#   <matplotlib.axis.XTick at 0x7c615e03b2d0>,
#   <matplotlib.axis.XTick at 0x7c615e0103d0>,
#   <matplotlib.axis.XTick at 0x7c615e013450>,
#   <matplotlib.axis.XTick at 0x7c615e065510>,
#   <matplotlib.axis.XTick at 0x7c615e067590>,
#   <matplotlib.axis.XTick at 0x7c615e011e50>,
#   <matplotlib.axis.XTick at 0x7c615e00c590>,
#   <matplotlib.axis.XTick at 0x7c615e0348d0>,
#   <matplotlib.axis.XTick at 0x7c615e1b8590>,
#   <matplotlib.axis.XTick at 0x7c615e1ed550>,
#   <matplotlib.axis.XTick at 0x7c615e069750>,
#   <matplotlib.axis.XTick at 0x7c615ed4e890>,
#   <matplotlib.axis.XTick at 0x7c615ee07f90>,
#   <matplotlib.axis.XTick at 0x7c615ee05810>,
#   <matplotlib.axis.XTick at 0x7c615edb3590>,
#   <matplotlib.axis.XTick at 0x7c615edb10d0>,
#   <matplotlib.axis.XTick at 0x7c615e035290>],
#  [Text(-15, 0, 'C'),
#   Text(-14, 0, 'C'),
#   Text(-13, 0, 'G'),
#   Text(-12, 0, 'C'),
#   Text(-11, 0, 'C'),
#   Text(-10, 0, 'C'),
#   Text(-9, 0, 'C'),
#   Text(-8, 0, 'G'),
#   Text(-7, 0, 'A'),
#   Text(-6, 0, 'G'),
#   Text(-5, 0, 'G'),
#   Text(-4, 0, 'C'),
#   Text(-3, 0, 'G'),
#   Text(-2, 0, 'C'),
#   Text(-1, 0, 'G'),
#   Text(0, 0, 'C'),
#   Text(1, 0, 'G'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'G'),
#   Text(4, 0, 'C'),
#   Text(5, 0, 'G'),
#   Text(6, 0, 'C'),
#   Text(7, 0, 'G'),
#   Text(8, 0, 'C'),
#   Text(9, 0, 'G'),
#   Text(10, 0, 'C'),
#   Text(11, 0, 'G'),
#   Text(12, 0, 'C'),
#   Text(13, 0, 'A'),
#   Text(14, 0, 'C')])

# %%
from matplotlib import pyplot as plt
from dimelo import plot_reads

fig, ax = plt.subplots()

ax = plot_reads.plot_reads(
    extract_file, # extracted_h5,
    regions = t2t_v1_1_cd55_30bps, #'chr1:206582520-206585020',
    motifs = ['CG,0'],
    thresh = 0.75,
    sort_by = ['region_start'], # 'strand'], # 'shuffle',
    # relative = False,
    relative = True,
    window_size = None, # 5000,
    s=5,
)
# plt.xlim(206582520,206585020)


seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
print(seq)
seq_list =  [s for s in seq]
plt.xticks(np.arange(len(seq_list)) - 15, seq_list, size='small')
# Out:
# CCGCCCCGAGGCGCGCGCGCGCGCGCGCAC
# ([<matplotlib.axis.XTick at 0x7c615e3a4a50>,
#   <matplotlib.axis.XTick at 0x7c615e01b490>,
#   <matplotlib.axis.XTick at 0x7c615ef7a9d0>,
#   <matplotlib.axis.XTick at 0x7c611bb8e5d0>,
#   <matplotlib.axis.XTick at 0x7c615e55ced0>,
#   <matplotlib.axis.XTick at 0x7c611bb86350>,
#   <matplotlib.axis.XTick at 0x7c615ebaa690>,
#   <matplotlib.axis.XTick at 0x7c615e06b4d0>,
#   <matplotlib.axis.XTick at 0x7c615ed4d8d0>,
#   <matplotlib.axis.XTick at 0x7c615ed90910>,
#   <matplotlib.axis.XTick at 0x7c615ed928d0>,
#   <matplotlib.axis.XTick at 0x7c615ed90f10>,
#   <matplotlib.axis.XTick at 0x7c615e4708d0>,
#   <matplotlib.axis.XTick at 0x7c615ed3d110>,
#   <matplotlib.axis.XTick at 0x7c615ed3ec50>,
#   <matplotlib.axis.XTick at 0x7c615edf2d90>,
#   <matplotlib.axis.XTick at 0x7c615edf0d90>,
#   <matplotlib.axis.XTick at 0x7c615ed93650>,
#   <matplotlib.axis.XTick at 0x7c615ed466d0>,
#   <matplotlib.axis.XTick at 0x7c615ed44910>,
#   <matplotlib.axis.XTick at 0x7c615ed1a850>,
#   <matplotlib.axis.XTick at 0x7c615ed18950>,
#   <matplotlib.axis.XTick at 0x7c615ed1b110>,
#   <matplotlib.axis.XTick at 0x7c615e5de310>,
#   <matplotlib.axis.XTick at 0x7c615e5dd610>,
#   <matplotlib.axis.XTick at 0x7c615e51e3d0>,
#   <matplotlib.axis.XTick at 0x7c615e51c350>,
#   <matplotlib.axis.XTick at 0x7c615ed3ecd0>,
#   <matplotlib.axis.XTick at 0x7c615e5ee9d0>,
#   <matplotlib.axis.XTick at 0x7c615e59bc50>],
#  [Text(-15, 0, 'C'),
#   Text(-14, 0, 'C'),
#   Text(-13, 0, 'G'),
#   Text(-12, 0, 'C'),
#   Text(-11, 0, 'C'),
#   Text(-10, 0, 'C'),
#   Text(-9, 0, 'C'),
#   Text(-8, 0, 'G'),
#   Text(-7, 0, 'A'),
#   Text(-6, 0, 'G'),
#   Text(-5, 0, 'G'),
#   Text(-4, 0, 'C'),
#   Text(-3, 0, 'G'),
#   Text(-2, 0, 'C'),
#   Text(-1, 0, 'G'),
#   Text(0, 0, 'C'),
#   Text(1, 0, 'G'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'G'),
#   Text(4, 0, 'C'),
#   Text(5, 0, 'G'),
#   Text(6, 0, 'C'),
#   Text(7, 0, 'G'),
#   Text(8, 0, 'C'),
#   Text(9, 0, 'G'),
#   Text(10, 0, 'C'),
#   Text(11, 0, 'G'),
#   Text(12, 0, 'C'),
#   Text(13, 0, 'A'),
#   Text(14, 0, 'C')])

# %%
seq_list
# Out:
# ['C',
#  'C',
#  'G',
#  'C',
#  'C',
#  'C',
#  'C',
#  'G',
#  'A',
#  'G',
#  'G',
#  'C',
#  'G',
#  'C',
#  'G',
#  'C',
#  'G',
#  'C',
#  'G',
#  'C',
#  'G',
#  'C',
#  'G',
#  'C',
#  'G',
#  'C',
#  'G',
#  'C',
#  'A',
#  'C']

# %%
from matplotlib import pyplot as plt
from dimelo import plot_reads

fig, ax = plt.subplots()

ax = plot_reads.plot_reads(
    extract_file, # extracted_h5,
    regions = t2t_v1_1_cd55_30bps, #'chr1:206582520-206585020',
    motifs = ['CG,0'],
    thresh = 0.75,
    sort_by = ['shuffle','strand'],
    # relative = False,
    relative = True,
    window_size = None, # 5000,
    s=5,
)
# plt.xlim(206582520,206585020)


seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
print(seq)
seq_list =  [s for s in seq]
plt.xticks(np.arange(len(seq_list)) - 15, seq_list, size='small')
# Out:
# CCGCCCCGAGGCGCGCGCGCGCGCGCGCAC
# ([<matplotlib.axis.XTick at 0x7c615e56ebd0>,
#   <matplotlib.axis.XTick at 0x7c615e563490>,
#   <matplotlib.axis.XTick at 0x7c615e55ff50>,
#   <matplotlib.axis.XTick at 0x7c615e084f50>,
#   <matplotlib.axis.XTick at 0x7c615e087350>,
#   <matplotlib.axis.XTick at 0x7c615ed3e9d0>,
#   <matplotlib.axis.XTick at 0x7c615e079ad0>,
#   <matplotlib.axis.XTick at 0x7c615e07bc90>,
#   <matplotlib.axis.XTick at 0x7c615e04cdd0>,
#   <matplotlib.axis.XTick at 0x7c615e0983d0>,
#   <matplotlib.axis.XTick at 0x7c615e09b410>,
#   <matplotlib.axis.XTick at 0x7c615e091590>,
#   <matplotlib.axis.XTick at 0x7c615e099c10>,
#   <matplotlib.axis.XTick at 0x7c615e090cd0>,
#   <matplotlib.axis.XTick at 0x7c615e093b50>,
#   <matplotlib.axis.XTick at 0x7c615e075610>,
#   <matplotlib.axis.XTick at 0x7c615e077b50>,
#   <matplotlib.axis.XTick at 0x7c615e0753d0>,
#   <matplotlib.axis.XTick at 0x7c615e0c9c10>,
#   <matplotlib.axis.XTick at 0x7c615e0cc2d0>,
#   <matplotlib.axis.XTick at 0x7c615e0ce250>,
#   <matplotlib.axis.XTick at 0x7c615e0d0350>,
#   <matplotlib.axis.XTick at 0x7c615e0d2390>,
#   <matplotlib.axis.XTick at 0x7c615e0c81d0>,
#   <matplotlib.axis.XTick at 0x7c615e0d1950>,
#   <matplotlib.axis.XTick at 0x7c615e0da990>,
#   <matplotlib.axis.XTick at 0x7c615e0dcad0>,
#   <matplotlib.axis.XTick at 0x7c615e0dd610>,
#   <matplotlib.axis.XTick at 0x7c615e0e0c50>,
#   <matplotlib.axis.XTick at 0x7c615e0cab50>],
#  [Text(-15, 0, 'C'),
#   Text(-14, 0, 'C'),
#   Text(-13, 0, 'G'),
#   Text(-12, 0, 'C'),
#   Text(-11, 0, 'C'),
#   Text(-10, 0, 'C'),
#   Text(-9, 0, 'C'),
#   Text(-8, 0, 'G'),
#   Text(-7, 0, 'A'),
#   Text(-6, 0, 'G'),
#   Text(-5, 0, 'G'),
#   Text(-4, 0, 'C'),
#   Text(-3, 0, 'G'),
#   Text(-2, 0, 'C'),
#   Text(-1, 0, 'G'),
#   Text(0, 0, 'C'),
#   Text(1, 0, 'G'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'G'),
#   Text(4, 0, 'C'),
#   Text(5, 0, 'G'),
#   Text(6, 0, 'C'),
#   Text(7, 0, 'G'),
#   Text(8, 0, 'C'),
#   Text(9, 0, 'G'),
#   Text(10, 0, 'C'),
#   Text(11, 0, 'G'),
#   Text(12, 0, 'C'),
#   Text(13, 0, 'A'),
#   Text(14, 0, 'C')])

# %%
from matplotlib import pyplot as plt
from dimelo import plot_reads

fig, ax = plt.subplots()

ax = plot_reads.plot_reads(
    extract_file, # extracted_h5,
    regions = t2t_v1_1_cd55_30bps, #'chr1:206582520-206585020',
    motifs = ['CG,0'],
    thresh = 0.75,
    sort_by = ['region_end','region_start' ], # 'strand'], # 'shuffle',
    # relative = False,
    relative = True,
    window_size = None, # 5000,
    s=5,
)
# plt.xlim(206582520,206585020)


seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
print(seq)
seq_list =  [s for s in seq]
plt.xticks(np.arange(len(seq_list)) - 15, seq_list, size='small')
# Out:
# CCGCCCCGAGGCGCGCGCGCGCGCGCGCAC
# ([<matplotlib.axis.XTick at 0x7c615df1a210>,
#   <matplotlib.axis.XTick at 0x7c615e0cb490>,
#   <matplotlib.axis.XTick at 0x7c615e0ffd10>,
#   <matplotlib.axis.XTick at 0x7c615df760d0>,
#   <matplotlib.axis.XTick at 0x7c615df60210>,
#   <matplotlib.axis.XTick at 0x7c615df61690>,
#   <matplotlib.axis.XTick at 0x7c615df63790>,
#   <matplotlib.axis.XTick at 0x7c615df59890>,
#   <matplotlib.axis.XTick at 0x7c615e5129d0>,
#   <matplotlib.axis.XTick at 0x7c615df92fd0>,
#   <matplotlib.axis.XTick at 0x7c615df89010>,
#   <matplotlib.axis.XTick at 0x7c615df89950>,
#   <matplotlib.axis.XTick at 0x7c615df89c10>,
#   <matplotlib.axis.XTick at 0x7c615df55c50>,
#   <matplotlib.axis.XTick at 0x7c615df57e10>,
#   <matplotlib.axis.XTick at 0x7c615df51890>,
#   <matplotlib.axis.XTick at 0x7c615df53e10>,
#   <matplotlib.axis.XTick at 0x7c615dfacdd0>,
#   <matplotlib.axis.XTick at 0x7c615df54bd0>,
#   <matplotlib.axis.XTick at 0x7c615dfb4350>,
#   <matplotlib.axis.XTick at 0x7c615dfb6350>,
#   <matplotlib.axis.XTick at 0x7c615dfb8390>,
#   <matplotlib.axis.XTick at 0x7c615dfba410>,
#   <matplotlib.axis.XTick at 0x7c615dfbc4d0>,
#   <matplotlib.axis.XTick at 0x7c615dfad3d0>,
#   <matplotlib.axis.XTick at 0x7c615dfbd610>,
#   <matplotlib.axis.XTick at 0x7c615dfc4710>,
#   <matplotlib.axis.XTick at 0x7c615dfc6790>,
#   <matplotlib.axis.XTick at 0x7c615dfcc750>,
#   <matplotlib.axis.XTick at 0x7c615dfbff50>],
#  [Text(-15, 0, 'C'),
#   Text(-14, 0, 'C'),
#   Text(-13, 0, 'G'),
#   Text(-12, 0, 'C'),
#   Text(-11, 0, 'C'),
#   Text(-10, 0, 'C'),
#   Text(-9, 0, 'C'),
#   Text(-8, 0, 'G'),
#   Text(-7, 0, 'A'),
#   Text(-6, 0, 'G'),
#   Text(-5, 0, 'G'),
#   Text(-4, 0, 'C'),
#   Text(-3, 0, 'G'),
#   Text(-2, 0, 'C'),
#   Text(-1, 0, 'G'),
#   Text(0, 0, 'C'),
#   Text(1, 0, 'G'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'G'),
#   Text(4, 0, 'C'),
#   Text(5, 0, 'G'),
#   Text(6, 0, 'C'),
#   Text(7, 0, 'G'),
#   Text(8, 0, 'C'),
#   Text(9, 0, 'G'),
#   Text(10, 0, 'C'),
#   Text(11, 0, 'G'),
#   Text(12, 0, 'C'),
#   Text(13, 0, 'A'),
#   Text(14, 0, 'C')])

# %%
extract_file
# Out:
# PosixPath('dimelo_v2_output/cas9_12ef_101923_beta_extract_30bps_chr1_206586162_206586192_wsNone_thresh190/reads.combined_basemods.h5')

# %% [markdown]
# # Extract structured on target reads

# %%
import numpy as np
import pandas as pd

from pathlib import Path

import seaborn as sns
from matplotlib.axes import Axes
import matplotlib.pyplot as plt

from dimelo import parse_bam, plot_enrichment_profile, plot_reads, load_processed

# %%
t2t_v1_1_cd55_30bps
# Out:
# 'chr1:206586162-206586192'

# %%
from pathlib import Path

import pandas as pd
import seaborn as sns
from matplotlib.axes import Axes
import matplotlib.pyplot as plt

# from . import load_processed
# from . import utils

reads,read_names,mods,regions_dict = load_processed.readwise_binary_modification_arrays(
    extract_file, # extract_file_no_thresh, # raw modification probabilities
    regions=t2t_v1_1_cd55_30bps, # cd55_30bps_interest_coords, # ctcf_target_regions,
    motifs=['CG,0'], # 'A,0'],
    sort_by = ['strand'], # 'shuffle',
    window_size=None,
    thresh = 0.001, # vs.  0.00196,
    relative = True, # False, #

)
      # file = mod_file_name,
      # regions = regions,
      # motifs = motifs,
      # window_size = window_size,
      # thresh = thresh,
      # relative = relative,
      # sort_by = sort_by,
    # )
  # match mod_file_name.suffix:
  #     case _:
  #         reads, read_names, mods = load_processed.reads_from_hdf5(
  #             file=mod_file_name,
#             bed_file=bed_file_name,
  #             mod_names=mod_names,
  #             window_size=window_size,
  #         )

# Convert data frame where each row represents a read to a data frame where each row represents a single modified position in a read
df = pd.DataFrame({
    'read_name': read_names,
    'mod': mods,
    'pos': reads
}).explode('pos')

# %%
df
# Out:
#      read_name   mod  pos
# 0            0  CG,0   -4
# 1            0  CG,0    0
# 2            0  CG,0    8
# 3            0  CG,0   10
# 4            3  CG,0    0
# ..         ...   ...  ...
# 187        330  CG,0    3
# 188        330  CG,0    5
# 189        330  CG,0    7
# 190        330  CG,0    9
# 191        331  CG,0    3
#
# [192 rows x 3 columns]

# %%
# @title read_name vs count()

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  counted = (series['read_name']
                .value_counts()
              .reset_index(name='counts')
              .rename({'index': 'read_name'}, axis=1)
              .sort_values('read_name', ascending=True))
  xs = counted['read_name']
  ys = counted['counts']
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('read_name', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('read_name')
_ = plt.ylabel('count()')

# %%
# @title read_name vs count()

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  counted = (series['read_name']
                .value_counts()
              .reset_index(name='counts')
              .rename({'index': 'read_name'}, axis=1)
              .sort_values('read_name', ascending=True))
  xs = counted['read_name']
  ys = counted['counts']
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)], marker='o' )

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('read_name', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('read_name')
_ = plt.ylabel('count()')

# %%
# @title read_name

from matplotlib import pyplot as plt
df['read_name'].plot(kind='hist', bins=20, title='read_name')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
len(np.unique(df['read_name']))
# Out:
# 100

# %%
reads,read_names,mods,regions_dict = load_processed.readwise_binary_modification_arrays(
    extract_file, # extract_file_no_thresh, # raw modification probabilities
    regions=t2t_v1_1_cd55_30bps, # cd55_30bps_interest_coords, # ctcf_target_regions,
    motifs=['CG,0'], # 'A,0'],
    relative = False,
    thresh=0.001,
    # window_size = None, # window_size,
)
      # file = mod_file_name,
      # regions = regions,
      # motifs = motifs,
      # window_size = window_size,
      # thresh = thresh,
      # relative = relative,
      # sort_by = sort_by,
  # )
  # match mod_file_name.suffix:
  #     case _:
  #         reads, read_names, mods = load_processed.reads_from_hdf5(
  #             file=mod_file_name,
#             bed_file=bed_file_name,
  #             mod_names=mod_names,
  #             window_size=window_size,
  #         )

# Convert data frame where each row represents a read to a data frame where each row represents a single modified position in a read
df_with_coords = pd.DataFrame({
    'read_name': read_names,
    'mod': mods,
    'pos': reads
}).explode('pos')
     

len(np.unique(df_with_coords.read_name))
     
30

df_with_coords
# Out:
#      read_name   mod        pos
# 0            0  CG,0  206586178
# 1            0  CG,0  206586180
# 2            0  CG,0  206586182
# 3            0  CG,0  206586184
# 4            0  CG,0  206586186
# ..         ...   ...        ...
# 187        324  CG,0  206586180
# 188        327  CG,0  206586163
# 189        328  CG,0  206586181
# 190        329  CG,0  206586176
# 191        329  CG,0  206586178
#
# [192 rows x 3 columns]

# %%
df_with_coords.shape
# Out:
# (192, 3)

# %%
# @title read_name vs pos

from matplotlib import pyplot as plt
df_with_coords.plot(kind='scatter', x='read_name', y='pos', s=32, alpha=.8)
df_with_coords.plot(kind='scatter', x='read_name', y='pos', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# # Pile up reads

# %%
# pileup_file, pileup_regions = parse_bam.pileup(
#     input_file=ctcf_bam_file_updated,
#     output_name='ctcf_demo_pileup_on_target',
#     ref_genome=ref_genome_file,
#     output_directory=output_dir,
#     regions=[ctcf_target_regions,ctcf_off_target_regions],
#     motifs=['A,0','CG,0'],
#     # parsing can optionally specify mod codes. 
#     # The default is Y or a for adenine and m or Z for cytosine, corresponding to methylation
#     # motifs = ['A,0,Y','CG,0,Z'], 
#     thresh=190,
#     window_size=1000,
#     # cores = 1, # uncomment this line if your process appears to be terminating early (reduces memory usage)
#     # quiet = True,
#     # cleanup = False,
#     # log=True,
# )

# %%
bam_path
# Out:
# '/home/michalula/data/cas9_nanopore/data/20241127_Cas9_K562unedited_day2_R9_minion/post_seq_basecall/5mCG/to_t2t_v1_1/sort_align_t2t_v1_1_trim_20241127_MR_Cas9_K562unedited_day2_R9min_converted_fast5.dna_r9.4.1_e8_sup@v3.3.5mCG.bam'

# %%
output_dir
# Out:
# PosixPath('dimelo_v2_output')

# %%
pileup_file, pileup_regions = parse_bam.pileup(
    input_file=bam_path, # ctcf_bam_file_updated,
    output_name= "pileup_extract_K562_P2_30bps_chr1_206586162_206586192_wsNone_thresh190", # 'ctcf_demo_pileup_on_target',
    ref_genome=ref_genome_v1_1_file, #ref_genome_file,
    output_directory=output_dir,
    regions=t2t_v1_1_cd55_30bps, #[ctcf_target_regions,ctcf_off_target_regions],
    motifs=['CG,0'], # ['A,0','CG,0'],
    # parsing can optionally specify mod codes. 
    # The default is Y or a for adenine and m or Z for cytosine, corresponding to methylation
    # motifs = ['A,0,Y','CG,0,Z'], 
    thresh=190,
    window_size=None,
    # window_size=4000,
    # cores = 1, # uncomment this line if your process appears to be terminating early (reduces memory usage)
    # quiet = True,
    # cleanup = False,
    # log=True,
)
# Out:
# No specified number of cores requested. 24 available on machine, allocating all.
# Modification threshold of 190 assumed to be for range 0-255. 190/255=0.7450980392156863 will be sent to modkit.
#           | Step 1: Identify motif locations in chm13.draft_v1.1.fasta   0% | 00:00
#           | Step 2: Parse regions in sort_align_t2t_v1_1_trim_20241127_MR_Cas9_K562unedited_day2_R9min_convert…
#           |    0%

# %%
pileup_file, pileup_regions = parse_bam.pileup(
    input_file=bam_path, # ctcf_bam_file_updated,
    output_name= "pileup_extract_K562_P2_ws4000_around_chr1_206586162_206586192_thresh190", # 'ctcf_demo_pileup_on_target',
    ref_genome=ref_genome_v1_1_file, #ref_genome_file,
    output_directory=output_dir,
    regions=t2t_v1_1_cd55_30bps, #[ctcf_target_regions,ctcf_off_target_regions],
    motifs=['CG,0'], # ['A,0','CG,0'],
    # parsing can optionally specify mod codes. 
    # The default is Y or a for adenine and m or Z for cytosine, corresponding to methylation
    # motifs = ['A,0,Y','CG,0,Z'], 
    thresh=190,
    # window_size=None,
    window_size=4000,
    # cores = 1, # uncomment this line if your process appears to be terminating early (reduces memory usage)
    # quiet = True,
    # cleanup = False,
    # log=True,
)
# Out:
# No specified number of cores requested. 24 available on machine, allocating all.
# Modification threshold of 190 assumed to be for range 0-255. 190/255=0.7450980392156863 will be sent to modkit.
#           | Step 1: Identify motif locations in chm13.draft_v1.1.fasta   0% | 00:00
#           | Step 2: Parse regions in sort_align_t2t_v1_1_trim_20241127_MR_Cas9_K562unedited_day2_R9min_convert…
#           |    0%

# %%
# # using domelo modkit_parsing_main :
# t2t_v1_1_cd55_30bps = 'chr1:206586162-206586192'
# # t2t_v1_1_cd55_30bps = 'chr1:206586162-206586192'

# # using domelo modkit_parsing_main:
# pileup_file = parse_bam.pileup(
#     input_file=bam_path, #ctcf_bam_file,
#     output_name='pileup_extract_K562_P2_30bps_chr1_206586162_206586192_wsNone_thresh190', #'ctcf_demo_pileup',
#     ref_genome=ref_genome_v1_1_file, # ref_genome_file,
#     output_directory=output_dir,
#     region_str=t2t_v1_1_cd55_30bps, # bed_files= [ctcf_target_regions],
#     basemods=['CG,0'],
#     thresh=190,
#     window_size=None,
#     # window_size=1000,
#     # cores=None,
#     # cleanup=False
# )

# %%
plt.figure(figsize=(4, 2)) # If you want a different sized plot, you can us matplotlib commands
plot_enrichment_profile.by_modification(
    mod_file_name=pileup_file,
    regions=t2t_v1_1_cd55_30bps, #ctcf_target_regions,
    window_size=None, #1000,
    motifs=['CG,0'], # ['A,0','CG,0'],
    single_strand=False, # if set to True, regions that specify the strand will only pull from reads on the strand (as opposed to both strands)
    regions_5to3prime=False, # if set to True, regions on the reverse (-) strand will be flipped so everything is 5 prime to 3 prime
    smooth_window=50,
    palette = { # you can pass down kwargs to sns barplot if you want to
        # 'A,0':'blue',
        'CG,0':'orange'
    }
)
# Out:
# <Axes: xlabel='pos', ylabel='fraction modified bases'>

# %%
fig, ax = plt.subplots()

mod_counts_vector,val_counts_vector = load_processed.pileup_vectors_from_bedmethyl(
        bedmethyl_file = pileup_file, # file,
        motif = 'CG,0',
        regions = t2t_v1_1_cd55_30bps, # region,
        window_size = None
    )
pileup_frac = mod_counts_vector / val_counts_vector
ax.plot(pileup_frac,'*',label=Path(pileup_file).name)

plt.title(f'Region-of-interest near CD55 between bisulfite data and nanopore cas9 data\nT2T:{t2t_v1_1_cd55_30bps}, hg38:{"hg38_cd55"}')
plt.xlabel('relative genomic coordinate')
# plt.legend()
plt.subplots_adjust(bottom=0.5)  # Adjust the bottom
# Placing the legend at the bottom outside of the figure
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), shadow=True, ncol=2)

seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
print(seq)
seq_list =  [s for s in seq]
plt.xticks(range(len(seq_list)), seq_list, size='small')
# Out:
# CCGCCCCGAGGCGCGCGCGCGCGCGCGCAC
# /tmp/ipykernel_2056175/2540628470.py:9: RuntimeWarning: invalid value encountered in divide
#   pileup_frac = mod_counts_vector / val_counts_vector
# ([<matplotlib.axis.XTick at 0x7c615db46ad0>,
#   <matplotlib.axis.XTick at 0x7c615dbdf110>,
#   <matplotlib.axis.XTick at 0x7c615da9c1d0>,
#   <matplotlib.axis.XTick at 0x7c615da5ba90>,
#   <matplotlib.axis.XTick at 0x7c615dba9490>,
#   <matplotlib.axis.XTick at 0x7c615db3eb10>,
#   <matplotlib.axis.XTick at 0x7c615d12b3d0>,
#   <matplotlib.axis.XTick at 0x7c615d129290>,
#   <matplotlib.axis.XTick at 0x7c615db3f790>,
#   <matplotlib.axis.XTick at 0x7c615da4a7d0>,
#   <matplotlib.axis.XTick at 0x7c615d1bcfd0>,
#   <matplotlib.axis.XTick at 0x7c615d1bf0d0>,
#   <matplotlib.axis.XTick at 0x7c615d1eced0>,
#   <matplotlib.axis.XTick at 0x7c615d1ef090>,
#   <matplotlib.axis.XTick at 0x7c615d1ed8d0>,
#   <matplotlib.axis.XTick at 0x7c615da78bd0>,
#   <matplotlib.axis.XTick at 0x7c615da7ab50>,
#   <matplotlib.axis.XTick at 0x7c615dae4c10>,
#   <matplotlib.axis.XTick at 0x7c615dae4dd0>,
#   <matplotlib.axis.XTick at 0x7c615dad0d50>,
#   <matplotlib.axis.XTick at 0x7c615da7a510>,
#   <matplotlib.axis.XTick at 0x7c615dad3290>,
#   <matplotlib.axis.XTick at 0x7c615da94dd0>,
#   <matplotlib.axis.XTick at 0x7c615da97450>,
#   <matplotlib.axis.XTick at 0x7c615da69450>,
#   <matplotlib.axis.XTick at 0x7c615da6b4d0>,
#   <matplotlib.axis.XTick at 0x7c615da6ac90>,
#   <matplotlib.axis.XTick at 0x7c615da995d0>,
#   <matplotlib.axis.XTick at 0x7c615da9b590>,
#   <matplotlib.axis.XTick at 0x7c615da45690>],
#  [Text(0, 0, 'C'),
#   Text(1, 0, 'C'),
#   Text(2, 0, 'G'),
#   Text(3, 0, 'C'),
#   Text(4, 0, 'C'),
#   Text(5, 0, 'C'),
#   Text(6, 0, 'C'),
#   Text(7, 0, 'G'),
#   Text(8, 0, 'A'),
#   Text(9, 0, 'G'),
#   Text(10, 0, 'G'),
#   Text(11, 0, 'C'),
#   Text(12, 0, 'G'),
#   Text(13, 0, 'C'),
#   Text(14, 0, 'G'),
#   Text(15, 0, 'C'),
#   Text(16, 0, 'G'),
#   Text(17, 0, 'C'),
#   Text(18, 0, 'G'),
#   Text(19, 0, 'C'),
#   Text(20, 0, 'G'),
#   Text(21, 0, 'C'),
#   Text(22, 0, 'G'),
#   Text(23, 0, 'C'),
#   Text(24, 0, 'G'),
#   Text(25, 0, 'C'),
#   Text(26, 0, 'G'),
#   Text(27, 0, 'C'),
#   Text(28, 0, 'A'),
#   Text(29, 0, 'C')])

# %%
pileup_frac
# Out:
# array([       nan, 0.12195122, 0.01980198,        nan,        nan,
#               nan, 0.0952381 , 0.05263158,        nan,        nan,
#               nan, 0.07692308, 0.05714286, 0.04137931, 0.03658537,
#        0.04848485, 0.04464286, 0.10795455, 0.03100775, 0.17977528,
#        0.05109489, 0.1509434 , 0.03076923, 0.1       , 0.07216495,
#        0.13793103, 0.07692308,        nan,        nan,        nan])

# %%
# from matplotlib import pyplot as plt
# t2t_cd55 = 'chr1:206586162-206586192'
# # hg38_cd55 = 'chr1:207320867-207320897'

# # caspileup = '/Users/oberondixon-luinenburg/Documents/Ioannidis-Streets/dimelo_test_data/cd55_cas9/cd55_tss/pileup.sorted.bed.gz'
# # caspileup = '/content/drive/MyDrive/Michal Rozenwald/data/CD55/cas9_12ef_101923_misha/dimelo_new_package/cd55_tss_pileup_ws4000/pileup.sorted.bed.gz' # pileup
# # T_bedgz = Path('/content/drive/MyDrive/Michal Rozenwald/data/ENCODE/T_primary_ENCSR663MXB/ENCFF355UVU.m.sorted.bed.gz') #'/Users/oberondixon-luinenburg/Downloads/ENCFF279HCL.m.sorted.bed.gz')
# K562_bedgz = Path('/content/drive/MyDrive/Michal Rozenwald/data/ENCODE/T_primary_ENCSR663MXB/ENCFF355UVU.m.sorted.bed.gz') #'/Users/oberondixon-luinenburg/Downloads/ENCFF279HCL.m.sorted.bed.gz')

from dimelo import plot_enrichment_profile
from dimelo import load_processed
import pysam

fig, ax = plt.subplots()

for file,region in zip([caspileup,T_bedgz],
                       [t2t_cd55,hg38_cd55]):
    mod_counts_vector,val_counts_vector = load_processed.pileup_vectors_from_bedmethyl(
        bedmethyl_file = file,
        motif = 'CG,0',
        regions = region,
        window_size = None
    )
    pileup_frac = mod_counts_vector / val_counts_vector
    ax.plot(pileup_frac,'*',label=Path(file).name)

plt.title(f'Region-of-interest near CD55 between bisulfite data and nanopore cas9 data\nT2T:{t2t_cd55}, hg38:{hg38_cd55}')
plt.xlabel('relative genomic coordinate')
# plt.legend()
plt.subplots_adjust(bottom=0.5)  # Adjust the bottom
# Placing the legend at the bottom outside of the figure
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), shadow=True, ncol=2)

seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
print(seq)
seq_list =  [s for s in seq]
plt.xticks(range(len(seq_list)), seq_list, size='small')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 16
#      12 import pysam
#      14 fig, ax = plt.subplots()
# ---> 16 for file,region in zip([caspileup,T_bedgz],
#      17                        [t2t_cd55,hg38_cd55]):
#      18     mod_counts_vector,val_counts_vector = load_processed.pileup_vectors_from_bedmethyl(
#      19         bedmethyl_file = file,
#      20         motif = 'CG,0',
#      21         regions = region,
#      22         window_size = None
#      23     )
#      24     pileup_frac = mod_counts_vector / val_counts_vector
#
# NameError: name 'caspileup' is not defined

# %%
# from matplotlib import pyplot as plt
# t2t_cd55 = 'chr1:206586162-206586192'
# # hg38_cd55 = 'chr1:207320867-207320897'

# # caspileup = '/Users/oberondixon-luinenburg/Documents/Ioannidis-Streets/dimelo_test_data/cd55_cas9/cd55_tss/pileup.sorted.bed.gz'
# # caspileup = '/content/drive/MyDrive/Michal Rozenwald/data/CD55/cas9_12ef_101923_misha/dimelo_new_package/cd55_tss_pileup_ws4000/pileup.sorted.bed.gz' # pileup
# # T_bedgz = Path('/content/drive/MyDrive/Michal Rozenwald/data/ENCODE/T_primary_ENCSR663MXB/ENCFF355UVU.m.sorted.bed.gz') #'/Users/oberondixon-luinenburg/Downloads/ENCFF279HCL.m.sorted.bed.gz')
# K562_bedgz = Path('/content/drive/MyDrive/Michal Rozenwald/data/ENCODE/T_primary_ENCSR663MXB/ENCFF355UVU.m.sorted.bed.gz') #'/Users/oberondixon-luinenburg/Downloads/ENCFF279HCL.m.sorted.bed.gz')

# from dimelo import plot_enrichment_profile
# from dimelo import load_processed
# import pysam

# fig, ax = plt.subplots()

# for file,region in zip([caspileup,T_bedgz],[t2t_cd55,hg38_cd55]):
#     mod_counts_vector,val_counts_vector = load_processed.pileup_vectors_from_bedmethyl(
#         bedmethyl_file = file,
#         motif = 'CG,0',
#         regions = region,
#         window_size = None
#     )
#     pileup_frac = mod_counts_vector / val_counts_vector
#     ax.plot(pileup_frac,'*',label=Path(file).name)

# plt.title(f'Region-of-interest near CD55 between bisulfite data and nanopore cas9 data\nT2T:{t2t_cd55}, hg38:{hg38_cd55}')
# plt.xlabel('relative genomic coordinate')
# # plt.legend()
# plt.subplots_adjust(bottom=0.5)  # Adjust the bottom
# # Placing the legend at the bottom outside of the figure
# plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), shadow=True, ncol=2)

# seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
# print(seq)
# seq_list =  [s for s in seq]
# plt.xticks(range(len(seq_list)), seq_list, size='small')
