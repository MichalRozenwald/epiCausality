# %%
import pandas as pd
from matplotlib import pyplot as plt 
import plotly.express as px
import numpy as np 
import os
from datetime import datetime

# %% [markdown]
# # Load T cells CRISPRoff vs Unedited
# ## Day 6:

# %%
dmr_dir_path = '/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_6/modkit_dmr/mc_07/filtered/new_dmr_output/'
dmr_T_CRoff_vs_Unedit_D6_filtered_mC07_path = dmr_dir_path + '20251121_dmr_filtered_day6_CRoff_vs_Unedit.csv'

dmr_T_CRoff_vs_Unedit_D6_filtered_mC07 = pd.read_csv(dmr_T_CRoff_vs_Unedit_D6_filtered_mC07_path, index_col=0)
dmr_T_CRoff_vs_Unedit_D6_filtered_mC07
# Out:
#     chrom      start        end name     score strand samplea_counts  \
# 0    chr1  206583089  206583090    .  0.248211      +           m:18
# 1    chr1  206583090  206583091    .  2.099589      -           m:19
# 2    chr1  206583173  206583174    .  0.335606      +          m:786
# 3    chr1  206583174  206583175    . -0.323633      -          m:853
# 4    chr1  206583387  206583388    .  0.249057      +          m:660
# ..    ...        ...        ...  ...       ...    ...            ...
# 281  chr1  206589931  206589932    . -0.342004      -           m:27
# 282  chr1  206589955  206589956    . -0.123888      +           m:71
# 283  chr1  206589956  206589957    .  0.152322      -           m:23
# 284  chr1  206590032  206590033    .  2.661270      +           m:55
# 285  chr1  206590033  206590034    .  0.746352      -           m:17
#
#      samplea_total sampleb_counts  sampleb_total  ... cg_unit_pair_id  \
# 0               23            m:4              7  ...         CG_-1.+
# 1               19            m:7              9  ...         CG_-1.-
# 2              876          m:358            390  ...          CG_0.+
# 3              869          m:465            473  ...          CG_0.-
# 4             1004          m:315            459  ...          CG_1.+
# ..             ...            ...            ...  ...             ...
# 281             27           m:17             17  ...        CG_139.-
# 282             75           m:35             36  ...        CG_140.+
# 283             24           m:15             15  ...        CG_140.-
# 284             68           m:32             33  ...        CG_141.+
# 285             25           m:14             16  ...        CG_141.-
#
#     efsize-score  score-efsize  score_scaled  efsize-score_scaled  start_hg38  \
# 0      -0.037031      0.037031      0.000610             0.210570   207317793
# 1      -1.877366      1.877366      0.002512             0.219710   207317794
# 2      -0.355606      0.355606      0.000700            -0.020700   207317877
# 3       0.323633     -0.323633      0.000023            -0.000023   207317878
# 4      -0.279057      0.279057      0.000611            -0.030611   207318091
# ..           ...           ...           ...                  ...         ...
# 281     0.342004     -0.342004      0.000004            -0.000004   207324635
# 282     0.098332     -0.098332      0.000228            -0.025783   207324659
# 283    -0.193989      0.193989      0.000512            -0.042178   207324660
# 284    -2.822143      2.822143      0.003090            -0.163963   207324736
# 285    -0.941352      0.941352      0.001122            -0.196122   207324737
#
#       end_hg38  start_t2tv2  end_t2tv2  score_norm
# 0    207317794    206583089  206583090    0.000610
# 1    207317795    206583090  206583091    0.002512
# 2    207317878    206583173  206583174    0.000700
# 3    207317879    206583174  206583175    0.000023
# 4    207318092    206583387  206583388    0.000611
# ..         ...          ...        ...         ...
# 281  207324636    206589931  206589932    0.000004
# 282  207324660    206589955  206589956    0.000228
# 283  207324661    206589956  206589957    0.000512
# 284  207324737    206590032  206590033    0.003090
# 285  207324738    206590033  206590034    0.001122
#
# [286 rows x 32 columns]

# %% [markdown]
# # Day 35:

# %%
dmr_dir_path = '/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/modkit_dmr/mc_07_filtered/new_dmr_output/'
dmr_T_CRoff_vs_Unedit_D35_filtered_mC07_path = dmr_dir_path + '20251128_dmr_day35_CRoff_vs_Unedit.csv'

dmr_T_CRoff_vs_Unedit_D35_filtered_mC07 = pd.read_csv(dmr_T_CRoff_vs_Unedit_D35_filtered_mC07_path, index_col=0)
dmr_T_CRoff_vs_Unedit_D35_filtered_mC07
# Out:
#     chrom      start        end name     score strand samplea_counts  \
# 0    chr1  206583090  206583091    . -0.277632      -            m:2
# 1    chr1  206583173  206583174    .  0.618367      +          m:130
# 2    chr1  206583174  206583175    . -0.202477      -          m:112
# 3    chr1  206583387  206583388    .  0.017219      +          m:131
# 4    chr1  206583388  206583389    . -0.262716      -           m:82
# ..    ...        ...        ...  ...       ...    ...            ...
# 280  chr1  206589931  206589932    . -0.327891      -            m:5
# 281  chr1  206589955  206589956    . -0.326868      +            m:6
# 282  chr1  206589956  206589957    . -0.319263      -            m:4
# 283  chr1  206590032  206590033    .  1.323236      +            m:2
# 284  chr1  206590033  206590034    .  0.310155      -            m:2
#
#      samplea_total sampleb_counts  sampleb_total  ... cg_unit_pair_id  \
# 0                2            m:1              1  ...         CG_-1.-
# 1              143           m:66             78  ...          CG_0.+
# 2              118           m:81             84  ...          CG_0.-
# 3              171           m:58             81  ...          CG_1.+
# 4               98           m:61             71  ...          CG_1.-
# ..             ...            ...            ...  ...             ...
# 280              5            m:5              5  ...        CG_139.-
# 281              6            m:4              4  ...        CG_140.+
# 282              4            m:3              3  ...        CG_140.-
# 283              6            m:5              6  ...        CG_141.+
# 284              4            m:1              1  ...        CG_141.-
#
#     efsize-score  score-efsize  score_scaled  efsize-score_scaled  start_hg38  \
# 0       0.277632     -0.277632      0.000371            -0.000371   207317794
# 1      -0.554521      0.554521      0.005752             0.058094   207317877
# 2       0.188191     -0.188191      0.000823            -0.015108   207317878
# 3       0.036732     -0.036732      0.002142             0.051809   207318091
# 4       0.240295     -0.240295      0.000461            -0.022881   207318092
# ..           ...           ...           ...                  ...         ...
# 280     0.327891     -0.327891      0.000069            -0.000069   207324635
# 281     0.326868     -0.326868      0.000076            -0.000076   207324659
# 282     0.319263     -0.319263      0.000121            -0.000121   207324660
# 283    -1.823236      1.823236      0.009985            -0.509985   207324736
# 284    -0.810155      0.810155      0.003901            -0.503901   207324737
#
#       end_hg38  start_t2tv2  end_t2tv2  score_norm
# 0    207317795    206583090  206583091    0.000371
# 1    207317878    206583173  206583174    0.005752
# 2    207317879    206583174  206583175    0.000823
# 3    207318092    206583387  206583388    0.002142
# 4    207318093    206583388  206583389    0.000461
# ..         ...          ...        ...         ...
# 280  207324636    206589931  206589932    0.000069
# 281  207324660    206589955  206589956    0.000076
# 282  207324661    206589956  206589957    0.000121
# 283  207324737    206590032  206590033    0.009985
# 284  207324738    206590033  206590034    0.003901
#
# [285 rows x 32 columns]

# %% [markdown]
# Add extra raw 0 of the CpG #-1 to the table so all the values are in sync across conditions

# %%
# duplicate the first row and insert it as index 0 (renumbering indices)
first_row = dmr_T_CRoff_vs_Unedit_D35_filtered_mC07.iloc[[0]].copy()
dmr_T_CRoff_vs_Unedit_D35_filtered_mC07 = pd.concat(
    [first_row, dmr_T_CRoff_vs_Unedit_D35_filtered_mC07],
    ignore_index=True
)

# show the top rows to confirm
dmr_T_CRoff_vs_Unedit_D35_filtered_mC07.head()
# Out:
#   chrom      start        end name     score strand samplea_counts  \
# 0  chr1  206583090  206583091    . -0.277632      -            m:2
# 1  chr1  206583090  206583091    . -0.277632      -            m:2
# 2  chr1  206583173  206583174    .  0.618367      +          m:130
# 3  chr1  206583174  206583175    . -0.202477      -          m:112
# 4  chr1  206583387  206583388    .  0.017219      +          m:131
#
#    samplea_total sampleb_counts  sampleb_total  ... cg_unit_pair_id  \
# 0              2            m:1              1  ...         CG_-1.-
# 1              2            m:1              1  ...         CG_-1.-
# 2            143           m:66             78  ...          CG_0.+
# 3            118           m:81             84  ...          CG_0.-
# 4            171           m:58             81  ...          CG_1.+
#
#   efsize-score  score-efsize  score_scaled  efsize-score_scaled  start_hg38  \
# 0     0.277632     -0.277632      0.000371            -0.000371   207317794
# 1     0.277632     -0.277632      0.000371            -0.000371   207317794
# 2    -0.554521      0.554521      0.005752             0.058094   207317877
# 3     0.188191     -0.188191      0.000823            -0.015108   207317878
# 4     0.036732     -0.036732      0.002142             0.051809   207318091
#
#     end_hg38  start_t2tv2  end_t2tv2  score_norm
# 0  207317795    206583090  206583091    0.000371
# 1  207317795    206583090  206583091    0.000371
# 2  207317878    206583173  206583174    0.005752
# 3  207317879    206583174  206583175    0.000823
# 4  207318092    206583387  206583388    0.002142
#
# [5 rows x 32 columns]

# %%
dmr_T_CRoff_vs_Unedit_D35_filtered_mC07.shape
# Out:
# (286, 32)

# %% [markdown]
# # Load K562 ZFPoff vs Unedited dmr

# %%
dmr_dir_path = '/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/K562/compare/modkit_dmr/mc_07/filtered/'
dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07 = dmr_dir_path + '20251124_dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07.csv'
dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07
# Out:
# '/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/K562/compare/modkit_dmr/mc_07/filtered/20251124_dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07.csv'

# %%
# pd load csv
dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07 = pd.read_csv(dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07)
dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07
# Out:
#      Unnamed: 0 chrom      start        end name     score strand  \
# 0             0  chr1  206583089  206583090    . -0.334175      +
# 1             1  chr1  206583090  206583091    . -0.140460      -
# 2             2  chr1  206583173  206583174    .  2.267680      +
# 3             3  chr1  206583174  206583175    . -0.186045      -
# 4             4  chr1  206583387  206583388    .  0.170182      +
# ..          ...   ...        ...        ...  ...       ...    ...
# 281         281  chr1  206589931  206589932    . -0.309418      -
# 282         282  chr1  206589955  206589956    . -0.213918      +
# 283         283  chr1  206589956  206589957    . -0.219006      -
# 284         284  chr1  206590032  206590033    .  3.092622      +
# 285         285  chr1  206590033  206590034    . -0.158638      -
#
#     samplea_counts  samplea_total sampleb_counts  ...  cg_unit_pair_id  \
# 0              m:0             11            m:0  ...          CG_-1.+
# 1              m:1             11            m:0  ...          CG_-1.-
# 2            m:445            506           m:69  ...           CG_0.+
# 3            m:540            592           m:66  ...           CG_0.-
# 4             m:44            627            m:4  ...           CG_1.+
# ..             ...            ...            ...  ...              ...
# 281           m:22             27            m:5  ...         CG_139.-
# 282           m:36             39           m:15  ...         CG_140.+
# 283           m:18             20            m:5  ...         CG_140.-
# 284           m:19             30           m:17  ...         CG_141.+
# 285            m:7             20            m:2  ...         CG_141.-
#
#     efsize-score score-efsize  score_scaled  efsize-score_scaled  start_hg38  \
# 0       0.334175    -0.334175      0.000044            -0.000044   207317793
# 1       0.231369    -0.231369      0.001057             0.089852   207317794
# 2      -2.171771     2.171771      0.013655             0.082254   207317877
# 3       0.204153    -0.204153      0.000819             0.017289   207317878
# 4      -0.143660     0.143660      0.002682             0.023839   207318091
# ..           ...          ...           ...                  ...         ...
# 281     0.290900    -0.290900      0.000174            -0.018692   207324635
# 282     0.254642    -0.254642      0.000673             0.040051   207324659
# 283     0.285673    -0.285673      0.000647             0.066020   207324660
# 284    -3.403733     3.403733      0.017970            -0.329081   207324736
# 285     0.008638    -0.008638      0.000962            -0.150962   207324737
#
#       end_hg38  start_t2tv2  end_t2tv2  score_norm
# 0    207317794    206583089  206583090    0.000044
# 1    207317795    206583090  206583091    0.001057
# 2    207317878    206583173  206583174    0.013655
# 3    207317879    206583174  206583175    0.000819
# 4    207318092    206583387  206583388    0.002682
# ..         ...          ...        ...         ...
# 281  207324636    206589931  206589932    0.000174
# 282  207324660    206589955  206589956    0.000673
# 283  207324661    206589956  206589957    0.000647
# 284  207324737    206590032  206590033    0.017970
# 285  207324738    206590033  206590034    0.000962
#
# [286 rows x 33 columns]

# %%
dmr_df = dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07 
experiment_codition="K562_ZFPoffHigh_vs_Unedit_filtered_mC07"
out_dir=dmr_dir_path
pvalue_thresh=0.005

# def plot_dmr_effect_size_bar(dmr_df, experiment_codition, out_dir, pvalue_thresh=0.005):
# Ensure output directory exists
os.makedirs(out_dir, exist_ok=True)
# Bar: effect size per position (without sorting) with effect size colors 
# dmr_df['label'] = dmr_df['pos'] + ":" + dmr_df['strand'].astype(str)

fig_bar_unsorted = px.bar(
    dmr_df,
    x=dmr_df.index, 
    y='effect_size',        
    color='map_pval_less005',
    title=f"Effect size & p-vals<0.005 for all CGs (n={len(dmr_df)}) <br>{experiment_codition}",
    labels={'effect_size':'Effect size (A - B)','label':'position:strand'}
)
        # hover_data=['map_pvalue','a_perc','b_perc','total_reads'],
        # x='label',

fig_bar_unsorted.update_layout(xaxis_tickangle=45, height=520)
bar_unsorted_path = os.path.join(out_dir, f"dmr_sig_effectsize_unsorted_p{pvalue_thresh:.3f}.html")
# fig_bar_unsorted.write_html(bar_unsorted_path, include_plotlyjs='cdn')
fig_bar_unsorted.show()
# print("Saved unsorted effect-size bar plot:", bar_unsorted_path)    
    
    
# Bar: effect size per position (without sorting) with effect size colors 
# dmr_df['label'] = dmr_df['pos'] + ":" + dmr_df['strand'].astype(str)
fig_bar_unsorted = px.bar(
    dmr_df,
    x=dmr_df.index, 
    y='score',        
    color='map_pval_less005',
    title=f"log marginal Likelihood(LML) score & p-vals<0.005 for all CGs (n={len(dmr_df)}) <br>{experiment_codition}",
    labels={'score':'LML','label':'position:strand'}
)
        # hover_data=['map_pvalue','a_perc','b_perc','total_reads'],
        # x='label',

fig_bar_unsorted.update_layout(xaxis_tickangle=45, height=520)
bar_unsorted_path = os.path.join(out_dir, f"dmr_sig_effectsize_unsorted_p{pvalue_thresh:.3f}.html")
# fig_bar_unsorted.write_html(bar_unsorted_path, include_plotlyjs='cdn')
fig_bar_unsorted.show()
# print("Saved unsorted effect-size bar plot:", bar_unsorted_path)    
    
# plot_dmr_effect_size_bar(
#     dmr_df=dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07, 
#                          experiment_codition="K562_ZFPoffHigh_vs_Unedit_filtered_mC07", 
#                          out_dir=dmr_dir_path, 
#                          pvalue_thresh=0.005)

# %%
plt.figure(figsize=(16, 5))

plt.bar(np.arange(len(dmr_df['effect_size'])), dmr_df['effect_size'], 
        snap=False, alpha=0.5, label='effect_size', color='green') #, color=dmr_df['map_pval_less005'])

plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='score_norm', color='red') #, color=dmr_df['map_pval_less005'])

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Score') 
plt.title('Effect size & Normalized LML Score per CpG \n' + experiment_codition)
plt.legend()
plt.show()

# %%
dmr_df = dmr_T_CRoff_vs_Unedit_D6_filtered_mC07
experiment_codition = "dmr_T_CRoff_vs_Unedit_D6_filtered_mC07"

plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(dmr_df['effect_size'])), dmr_df['effect_size'], 
        snap=False, alpha=0.5, label='effect_size', color='green') 

plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='score_norm', color='red')
plt.xlabel('CpG units')
plt.ylabel('Score') 
plt.title('Effect size & Normalized LML Score per CpG \n' + experiment_codition)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16, 5))

dmr_df = dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07 
experiment_codition="K562_ZFPoffHigh_vs_Unedit_filtered_mC07"
plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='K562_ZFPoffHigh_vs_Unedit', color='red')

dmr_df = dmr_T_CRoff_vs_Unedit_D6_filtered_mC07
experiment_codition = "dmr_T_CRoff_vs_Unedit_D6_filtered_mC07"
plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='T_CRoff_vs_Unedit', color='green')
 
plt.xlabel('CpG units')
plt.ylabel('Score') 
plt.title('Normalized LML Score per CpG \n' + experiment_codition)

plt.legend()
plt.show()

# %%
plt.figure(figsize=(16, 5))

dmr_df = dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07 
experiment_codition="K562_ZFPoffHigh_vs_Unedit_filtered_mC07"
plt.bar(np.arange(len(dmr_df['effect_size'])), dmr_df['effect_size'], 
        snap=False, alpha=0.5, label='K562_ZFPoffHigh_vs_Unedit', color='red')

dmr_df = dmr_T_CRoff_vs_Unedit_D6_filtered_mC07
experiment_codition = "T_CRoff_vs_Unedit_D6_filtered_mC07"
plt.bar(np.arange(len(dmr_df['effect_size'])), dmr_df['effect_size'], 
        snap=False, alpha=0.5, label='T_CRoff_vs_Unedit', color='green')
 
plt.xlabel('CpG units')
plt.ylabel('Score') 
plt.title('Effect size per CpG \n' + experiment_codition)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16, 5))

dmr_df = dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07 
experiment_codition="K562_ZFPoffHigh_vs_Unedit_filtered_mC07"
plt.bar(np.arange(len(dmr_df['effect_size'])), dmr_df['effect_size'], 
        snap=False, alpha=0.5, label='K562_ZFPoffHigh_vs_Unedit', color='red')

dmr_df = dmr_T_CRoff_vs_Unedit_D6_filtered_mC07
experiment_codition = "T_CRoff_vs_Unedit_D6_filtered_mC07"
plt.bar(np.arange(len(dmr_df['effect_size'])), dmr_df['effect_size'], 
        snap=False, alpha=0.5, label='T_CRoff_vs_Unedit', color='green')


dmr_df = dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07 
experiment_codition="K562_ZFPoffHigh_vs_Unedit_filtered_mC07"
plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='K562_ZFPoffHigh_vs_Unedit') #, color='red')

dmr_df = dmr_T_CRoff_vs_Unedit_D6_filtered_mC07
experiment_codition = "dmr_T_CRoff_vs_Unedit_D6_filtered_mC07"
plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='T_CRoff_vs_Unedit') #, color='green')
 
 
plt.xlabel('CpG units')
plt.ylabel('Score') 
plt.title('Effect size per CpG \n' + experiment_codition)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16, 5))

dmr_df = dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07 
experiment_codition="K562_ZFPoffHigh_vs_Unedit_filtered_mC07"
plt.bar(np.arange(len(dmr_df['effect_size'])), dmr_df['effect_size'], 
        snap=False, alpha=0.5, label='K562_ZFPoffHigh_vs_Unedit', color='red')

# dmr_df = dmr_T_CRoff_vs_Unedit_D6_filtered_mC07
# experiment_codition = "T_CRoff_vs_Unedit_D6_filtered_mC07"
# plt.bar(np.arange(len(dmr_df['effect_size'])), dmr_df['effect_size'], 
#         snap=False, alpha=0.5, label='T_CRoff_vs_Unedit', color='green')


dmr_df = dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07 
experiment_codition="K562_ZFPoffHigh_vs_Unedit_filtered_mC07"
plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='K562_ZFPoffHigh_vs_Unedit') #, color='red')

# dmr_df = dmr_T_CRoff_vs_Unedit_D6_filtered_mC07
# experiment_codition = "dmr_T_CRoff_vs_Unedit_D6_filtered_mC07"
# plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
#         snap=False, alpha=0.5, label='T_CRoff_vs_Unedit') #, color='green')
 
 
plt.xlabel('CpG units')
plt.ylabel('Score') 
plt.title('Effect size per CpG \n') #+ experiment_codition)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16, 5))

# dmr_df = dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07 
# experiment_codition="K562_ZFPoffHigh_vs_Unedit_filtered_mC07"
# plt.bar(np.arange(len(dmr_df['effect_size'])), dmr_df['effect_size'], 
#         snap=False, alpha=0.5, label='K562_ZFPoffHigh_vs_Unedit', color='red')

dmr_df = dmr_T_CRoff_vs_Unedit_D6_filtered_mC07
experiment_codition = "T_CRoff_vs_Unedit_D6_filtered_mC07"
plt.bar(np.arange(len(dmr_df['effect_size'])), dmr_df['effect_size'], 
        snap=False, alpha=0.5, label='T_CRoff_vs_Unedit', color='green')


# dmr_df = dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07 
# experiment_codition="K562_ZFPoffHigh_vs_Unedit_filtered_mC07"
# plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
#         snap=False, alpha=0.5, label='K562_ZFPoffHigh_vs_Unedit') #, color='red')

dmr_df = dmr_T_CRoff_vs_Unedit_D6_filtered_mC07
experiment_codition = "dmr_T_CRoff_vs_Unedit_D6_filtered_mC07"
plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='T_CRoff_vs_Unedit') #, color='green')
 
 
plt.xlabel('CpG units')
plt.ylabel('Score') 
plt.title('Effect size per CpG \n') #+ experiment_codition)
plt.legend()
plt.show()

# %% [markdown]
# # Day 35 T CRoff - unedited

# %%
dmr_T_CRoff_vs_Unedit_D35_filtered_mC07
# Out:
#     chrom      start        end name     score strand samplea_counts  \
# 0    chr1  206583090  206583091    . -0.277632      -            m:2
# 1    chr1  206583090  206583091    . -0.277632      -            m:2
# 2    chr1  206583173  206583174    .  0.618367      +          m:130
# 3    chr1  206583174  206583175    . -0.202477      -          m:112
# 4    chr1  206583387  206583388    .  0.017219      +          m:131
# ..    ...        ...        ...  ...       ...    ...            ...
# 281  chr1  206589931  206589932    . -0.327891      -            m:5
# 282  chr1  206589955  206589956    . -0.326868      +            m:6
# 283  chr1  206589956  206589957    . -0.319263      -            m:4
# 284  chr1  206590032  206590033    .  1.323236      +            m:2
# 285  chr1  206590033  206590034    .  0.310155      -            m:2
#
#      samplea_total sampleb_counts  sampleb_total  ... cg_unit_pair_id  \
# 0                2            m:1              1  ...         CG_-1.-
# 1                2            m:1              1  ...         CG_-1.-
# 2              143           m:66             78  ...          CG_0.+
# 3              118           m:81             84  ...          CG_0.-
# 4              171           m:58             81  ...          CG_1.+
# ..             ...            ...            ...  ...             ...
# 281              5            m:5              5  ...        CG_139.-
# 282              6            m:4              4  ...        CG_140.+
# 283              4            m:3              3  ...        CG_140.-
# 284              6            m:5              6  ...        CG_141.+
# 285              4            m:1              1  ...        CG_141.-
#
#     efsize-score  score-efsize  score_scaled  efsize-score_scaled  start_hg38  \
# 0       0.277632     -0.277632      0.000371            -0.000371   207317794
# 1       0.277632     -0.277632      0.000371            -0.000371   207317794
# 2      -0.554521      0.554521      0.005752             0.058094   207317877
# 3       0.188191     -0.188191      0.000823            -0.015108   207317878
# 4       0.036732     -0.036732      0.002142             0.051809   207318091
# ..           ...           ...           ...                  ...         ...
# 281     0.327891     -0.327891      0.000069            -0.000069   207324635
# 282     0.326868     -0.326868      0.000076            -0.000076   207324659
# 283     0.319263     -0.319263      0.000121            -0.000121   207324660
# 284    -1.823236      1.823236      0.009985            -0.509985   207324736
# 285    -0.810155      0.810155      0.003901            -0.503901   207324737
#
#       end_hg38  start_t2tv2  end_t2tv2  score_norm
# 0    207317795    206583090  206583091    0.000371
# 1    207317795    206583090  206583091    0.000371
# 2    207317878    206583173  206583174    0.005752
# 3    207317879    206583174  206583175    0.000823
# 4    207318092    206583387  206583388    0.002142
# ..         ...          ...        ...         ...
# 281  207324636    206589931  206589932    0.000069
# 282  207324660    206589955  206589956    0.000076
# 283  207324661    206589956  206589957    0.000121
# 284  207324737    206590032  206590033    0.009985
# 285  207324738    206590033  206590034    0.003901
#
# [286 rows x 32 columns]

# %%
plt.figure(figsize=(16, 5))

dmr_df = dmr_T_CRoff_vs_Unedit_D35_filtered_mC07 
experiment_codition="T_CRoff_vs_Unedit_D35_filtered_mC07"
plt.bar(np.arange(len(dmr_df['effect_size'])), dmr_df['effect_size'], 
        snap=False, alpha=0.5, label='T_CRoff_vs_Unedit_D35_effect_size', color='red')

dmr_df = dmr_T_CRoff_vs_Unedit_D35_filtered_mC07 
experiment_codition="T_CRoff_vs_Unedit_D35_filtered_mC07"
plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='T_CRoff_vs_Unedit_D35_score_norm', color='red')

# dmr_df = dmr_T_CRoff_vs_Unedit_D6_filtered_mC07
# experiment_codition = "T_CRoff_vs_Unedit_D6_filtered_mC07"
# plt.bar(np.arange(len(dmr_df['effect_size'])), dmr_df['effect_size'], 
#         snap=False, alpha=0.5, label='T_CRoff_vs_Unedit_D6', color='green')


# # dmr_df = dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07 
# # experiment_codition="K562_ZFPoffHigh_vs_Unedit_filtered_mC07"
# # plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
# #         snap=False, alpha=0.5, label='K562_ZFPoffHigh_vs_Unedit') #, color='red')

# dmr_df = dmr_T_CRoff_vs_Unedit_D6_filtered_mC07
# experiment_codition = "dmr_T_CRoff_vs_Unedit_D6_filtered_mC07"
# plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
#         snap=False, alpha=0.5, label='T_CRoff_vs_Unedit_D6') #, color='green')
 
 
plt.xlabel('CpG units')
plt.ylabel('Score') 
plt.title('Effect size per CpG \n') #+ experiment_codition)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16, 5)) 
dmr_df = dmr_T_CRoff_vs_Unedit_D35_filtered_mC07 
experiment_codition="T_CRoff_vs_Unedit_D35_filtered_mC07"
plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='T_CRoff_vs_Unedit_D35_score_norm', color='red')
 
plt.xlabel('CpG units')
plt.ylabel('Score') 
plt.title('Effect size per CpG \n') #+ experiment_codition)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16, 5))

# dmr_df = dmr_T_CRoff_vs_Unedit_D35_filtered_mC07 
# experiment_codition="T_CRoff_vs_Unedit_D35_filtered_mC07"
# plt.bar(np.arange(len(dmr_df['effect_size'])), dmr_df['effect_size'], 
#         snap=False, alpha=0.5, label='T_CRoff_vs_Unedit_D35_effect_size', color='red')

dmr_df = dmr_T_CRoff_vs_Unedit_D35_filtered_mC07 
experiment_codition="T_CRoff_vs_Unedit_D35_filtered_mC07"
plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='T_CRoff_vs_Unedit_D35_score_norm', color='red')

dmr_df = dmr_T_CRoff_vs_Unedit_D6_filtered_mC07
experiment_codition = "T_CRoff_vs_Unedit_D6_filtered_mC07"
plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='T_CRoff_vs_Unedit_D6', color='green')

dmr_df = dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07 
experiment_codition="K562_ZFPoffHigh_vs_Unedit_filtered_mC07"
plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='K562_ZFPoffHigh_vs_Unedit') #, color='red')

# dmr_df = dmr_T_CRoff_vs_Unedit_D6_filtered_mC07
# experiment_codition = "dmr_T_CRoff_vs_Unedit_D6_filtered_mC07"
# plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
#         snap=False, alpha=0.5, label='T_CRoff_vs_Unedit_D6') #, color='green')
 
 
plt.xlabel('CpG units')
plt.ylabel('Score') 
plt.title('Effect size per CpG \n Score_norm') #+ experiment_codition)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16, 5))

# dmr_df = dmr_T_CRoff_vs_Unedit_D35_filtered_mC07 
# experiment_codition="T_CRoff_vs_Unedit_D35_filtered_mC07"
# plt.bar(np.arange(len(dmr_df['effect_size'])), dmr_df['effect_size'], 
#         snap=False, alpha=0.5, label='T_CRoff_vs_Unedit_D35_effect_size', color='red')

dmr_df = dmr_T_CRoff_vs_Unedit_D35_filtered_mC07 
experiment_codition="T_CRoff_vs_Unedit_D35_filtered_mC07"
plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='T_CRoff_vs_Unedit_D35_score_norm', color='red')

dmr_df = dmr_T_CRoff_vs_Unedit_D6_filtered_mC07
experiment_codition = "T_CRoff_vs_Unedit_D6_filtered_mC07"
plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='T_CRoff_vs_Unedit_D6', color='green')

# dmr_df = dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07 
# experiment_codition="K562_ZFPoffHigh_vs_Unedit_filtered_mC07"
# plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
#         snap=False, alpha=0.5, label='K562_ZFPoffHigh_vs_Unedit') #, color='red')

# dmr_df = dmr_T_CRoff_vs_Unedit_D6_filtered_mC07
# experiment_codition = "dmr_T_CRoff_vs_Unedit_D6_filtered_mC07"
# plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
#         snap=False, alpha=0.5, label='T_CRoff_vs_Unedit_D6') #, color='green')
 
 
plt.xlabel('CpG units')
plt.ylabel('Score') 
plt.title('Effect size per CpG \n Score_norm') #+ experiment_codition)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16, 5))

dmr_df = dmr_T_CRoff_vs_Unedit_D35_filtered_mC07 
experiment_codition="T_CRoff_vs_Unedit_D35_filtered_mC07"
plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='T_CRoff_vs_Unedit_D35_score_norm', color='red')

dmr_df = dmr_T_CRoff_vs_Unedit_D6_filtered_mC07
experiment_codition = "T_CRoff_vs_Unedit_D6_filtered_mC07"
plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='T_CRoff_vs_Unedit_D6', color='green')

dmr_df = dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07 
experiment_codition="K562_ZFPoffHigh_vs_Unedit_filtered_mC07"
plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='K562_ZFPoffHigh_vs_Unedit') #, color='red')

 
plt.xlabel('CpG units')
plt.ylabel('Score') 
plt.title('Effect size per CpG \n Score_norm') #+ experiment_codition)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16, 5))

dmr_df = dmr_T_CRoff_vs_Unedit_D35_filtered_mC07 
experiment_codition="T_CRoff_vs_Unedit_D35_filtered_mC07"
plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='T_CRoff_vs_Unedit_D35_score_norm', color='red')

# dmr_df = dmr_T_CRoff_vs_Unedit_D6_filtered_mC07
# experiment_codition = "T_CRoff_vs_Unedit_D6_filtered_mC07"
# plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
#         snap=False, alpha=0.5, label='T_CRoff_vs_Unedit_D6', color='green')

dmr_df = dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07 
experiment_codition="K562_ZFPoffHigh_vs_Unedit_filtered_mC07"
plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='K562_ZFPoffHigh_vs_Unedit') #, color='red')

 
plt.xlabel('CpG units')
plt.ylabel('Score') 
plt.title('Effect size per CpG \n Score_norm') #+ experiment_codition)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16, 5))

# dmr_df = dmr_T_CRoff_vs_Unedit_D35_filtered_mC07 
# experiment_codition="T_CRoff_vs_Unedit_D35_filtered_mC07"
# plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
#         snap=False, alpha=0.5, label='T_CRoff_vs_Unedit_D35_score_norm', color='red')

dmr_df = dmr_T_CRoff_vs_Unedit_D6_filtered_mC07
experiment_codition = "T_CRoff_vs_Unedit_D6_filtered_mC07"
plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='T_CRoff_vs_Unedit_D6', color='green')

dmr_df = dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07 
experiment_codition="K562_ZFPoffHigh_vs_Unedit_filtered_mC07"
plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='K562_ZFPoffHigh_vs_Unedit') #, color='red')

 
plt.xlabel('CpG units')
plt.ylabel('Score') 
plt.title('Effect size per CpG \n Score_norm') #+ experiment_codition)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16, 5))

dmr_df = dmr_T_CRoff_vs_Unedit_D35_filtered_mC07 
experiment_codition="T_CRoff_vs_Unedit_D35_filtered_mC07"
plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='T_CRoff_vs_Unedit_D35_score_norm', color='red')

dmr_df = dmr_T_CRoff_vs_Unedit_D6_filtered_mC07
experiment_codition = "T_CRoff_vs_Unedit_D6_filtered_mC07"
plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
        snap=False, alpha=0.5, label='T_CRoff_vs_Unedit_D6', color='green')

# dmr_df = dmr_K562_ZFPoffHigh_vs_Unedit_filtered_mC07 
# experiment_codition="K562_ZFPoffHigh_vs_Unedit_filtered_mC07"
# plt.bar(np.arange(len(dmr_df['score_norm'])), dmr_df['score_norm'], 
#         snap=False, alpha=0.5, label='K562_ZFPoffHigh_vs_Unedit') #, color='red')

 
plt.xlabel('CpG units')
plt.ylabel('Score') 
plt.title('Effect size per CpG \n Score_norm') #+ experiment_codition)
plt.legend()
plt.show()

# %% [markdown]
# # TODO: add the repl 1 vs 2 for day 35 for reference in score_norm diffs
