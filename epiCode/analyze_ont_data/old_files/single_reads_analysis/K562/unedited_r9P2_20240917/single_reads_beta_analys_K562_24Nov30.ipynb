# %% [markdown]
# # Analyse K562 P2 R9 run from 20204/09/27

# %%
from dimelo import parse_bam, plot_enrichment_profile, plot_reads
import matplotlib.pyplot as plt
from pathlib import Path
# Out:
# modkit found with expected version 0.2.4

# %%
! ls "/home/michalula/data/cas9_nanopore/data/2024927_Cas9_R9_promethion_K562"
# Out:
# bams_pass_merged.bam	 to_hg19  to_k562_spr30588077  to_t2t_v1_1
# post_seq_basecall_align  to_hg38  to_t2t_v1_0	       trim_bam_pass_merged.bam

# %%
! ls "/home/michalula/data/cas9_nanopore/data/2024927_Cas9_R9_promethion_K562/to_t2t_v1_1"
# Out:
# aligned_T2Tv1_1_trim_bam_pass_merged.bam
# more_mismatches
# sort_aligned_T2Tv1_1_trim_bam_pass_merged.bam
# sort_aligned_T2Tv1_1_trim_bam_pass_merged.bam.bai
# sort_aligned_T2Tv1_1_trim_bam_pass_merged.updated.bam
# sort_aligned_T2Tv1_1_trim_bam_pass_merged.updated.bam.bai
# summary_aligned_T2Tv1_1_trim_bam_pass_merged.tsv

# %% [markdown]
# ### System Information
# Run this cell to list system information about your machine

# %%
import platform
print('System:',platform.system())
print('Release:',platform.release())
print('Version:',platform.version())
print('Processor:',platform.processor())

#  Pyton version
import sys
print(sys.version)
# Out:
# System: Linux
# Release: 6.8.0-45-generic
# Version: #45~22.04.1-Ubuntu SMP PREEMPT_DYNAMIC Wed Sep 11 15:25:05 UTC 2
# Processor: x86_64
# 3.11.9 | packaged by conda-forge | (main, Apr 19 2024, 18:36:13) [GCC 12.3.0]

# %%
from pathlib import Path
from matplotlib import pyplot as plt
import pysam
import pandas as pd
from dimelo import plot_enrichment_profile, load_processed, parse_bam, utils

import seaborn as sns
from matplotlib.axes import Axes
import matplotlib.pyplot as plt

import numpy as np

# %% [markdown]
# #### Download & Use the T2T v.1.1 -> for my Cas9 runs
#
# ! mkdir ./test/output/
# !wget https://s3-us-west-2.amazonaws.com/human-pangenomics/T2T/CHM13/assemblies/chm13.draft_v1.1.fasta.gz -O ./test/output/chm13.draft_v1.1.fasta.gz
# !gunzip ./test/output/chm13.draft_v1.1.fasta.gz
#
# --2024-04-17 15:37:02--  https://s3-us-west-2.amazonaws.com/human-pangenomics/T2T/CHM13/assemblies/chm13.draft_v1.1.fasta.gz
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.92.238.208, 52.218.235.48, 52.92.131.176, ...
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.92.238.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 892637258 (851M) [binary/octet-stream]
# Saving to: ‘./test/output/chm13.draft_v1.1.fasta.gz’
#
# ./test/output/chm13 100%[===================>] 851.29M  39.5MB/s    in 22s
#
# 2024-04-17 15:37:24 (39.5 MB/s) - ‘./test/output/chm13.draft_v1.1.fasta.gz’ saved [892637258/892637258]
#
#
# !pwd
#
# /content/dimelo

# %%
from pathlib import Path
ref_genome_v1_1_file = Path('/home/michalula/data/ref_genomes/to_t2t_v1_1/chm13.draft_v1.1.fasta') #'./test/output/chm13.draft_v1.1.fasta')
ref_genome_v1_1_file
# Out:
# PosixPath('/home/michalula/data/ref_genomes/to_t2t_v1_1/chm13.draft_v1.1.fasta')

# %%
! head /home/michalula/data/ref_genomes/to_t2t_v1_1/chm13.draft_v1.1.fasta
# Out:
# >chr1
# CACCCTAAACCCTAACCCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCCTAAA
# CCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAA
# CCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCCTA
# ACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTA
# ACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCAACCCTAACCCTAA
# CCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAA
# CCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAA
# CCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAA
# CCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAACCCTAA

# %%
# from matplotlib import pyplot as plt
# t2t_cd55 = 'chr1:206586162-206586192'
# # hg38_cd55 = 'chr1:207320867-207320897'

# # caspileup = '/Users/oberondixon-luinenburg/Documents/Ioannidis-Streets/dimelo_test_data/cd55_cas9/cd55_tss/pileup.sorted.bed.gz'
# # caspileup = '/content/drive/MyDrive/Michal Rozenwald/data/CD55/cas9_12ef_101923_misha/dimelo_new_package/cd55_tss_pileup_ws4000/pileup.sorted.bed.gz' # pileup
# # T_bedgz = Path('/content/drive/MyDrive/Michal Rozenwald/data/ENCODE/T_primary_ENCSR663MXB/ENCFF355UVU.m.sorted.bed.gz') #'/Users/oberondixon-luinenburg/Downloads/ENCFF279HCL.m.sorted.bed.gz')
# K562_bedgz = Path('/content/drive/MyDrive/Michal Rozenwald/data/ENCODE/T_primary_ENCSR663MXB/ENCFF355UVU.m.sorted.bed.gz') #'/Users/oberondixon-luinenburg/Downloads/ENCFF279HCL.m.sorted.bed.gz')

# from dimelo import plot_enrichment_profile
# from dimelo import load_processed
# import pysam

# fig, ax = plt.subplots()

# for file,region in zip([caspileup,T_bedgz],[t2t_cd55,hg38_cd55]):
#     mod_counts_vector,val_counts_vector = load_processed.pileup_vectors_from_bedmethyl(
#         bedmethyl_file = file,
#         motif = 'CG,0',
#         regions = region,
#         window_size = None
#     )
#     pileup_frac = mod_counts_vector / val_counts_vector
#     ax.plot(pileup_frac,'*',label=Path(file).name)

# plt.title(f'Region-of-interest near CD55 between bisulfite data and nanopore cas9 data\nT2T:{t2t_cd55}, hg38:{hg38_cd55}')
# plt.xlabel('relative genomic coordinate')
# # plt.legend()
# plt.subplots_adjust(bottom=0.5)  # Adjust the bottom
# # Placing the legend at the bottom outside of the figure
# plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), shadow=True, ncol=2)

# seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
# print(seq)
# seq_list =  [s for s in seq]
# plt.xticks(range(len(seq_list)), seq_list, size='small')

# %%
# from matplotlib import pyplot as plt
# t2t_cd55 = 'chr1:206586162-206586192'
# hg38_cd55 = 'chr1:207320867-207320897'

# # caspileup = '/Users/oberondixon-luinenburg/Documents/Ioannidis-Streets/dimelo_test_data/cd55_cas9/cd55_tss/pileup.sorted.bed.gz'
# caspileup = '/content/drive/MyDrive/Michal Rozenwald/data/CD55/cas9_12ef_101923_misha/dimelo_new_package/cd55_tss_pileup_ws4000/pileup.sorted.bed.gz' # pileup
# T_bedgz = Path('/content/drive/MyDrive/Michal Rozenwald/data/ENCODE/T_primary_ENCSR663MXB/ENCFF355UVU.m.sorted.bed.gz') #'/Users/oberondixon-luinenburg/Downloads/ENCFF279HCL.m.sorted.bed.gz')

# from dimelo import plot_enrichment_profile
# from dimelo import load_processed
# import pysam

# fig, ax = plt.subplots()

# for file,region in zip([caspileup,T_bedgz],[t2t_cd55,hg38_cd55]):
#     mod_counts_vector,val_counts_vector = load_processed.pileup_vectors_from_bedmethyl(
#         bedmethyl_file = file,
#         motif = 'CG,0',
#         regions = region,
#         window_size = None
#     )
#     pileup_frac = mod_counts_vector / val_counts_vector
#     ax.plot(pileup_frac,'*',label=Path(file).name)

# plt.title(f'Region-of-interest near CD55 between bisulfite data and nanopore cas9 data\nT2T:{t2t_cd55}, hg38:{hg38_cd55}')
# plt.xlabel('relative genomic coordinate')
# # plt.legend()
# plt.subplots_adjust(bottom=0.5)  # Adjust the bottom
# # Placing the legend at the bottom outside of the figure
# plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), shadow=True, ncol=2)

# seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
# print(seq)
# seq_list =  [s for s in seq]
# plt.xticks(range(len(seq_list)), seq_list, size='small')

# %% [markdown]
# # Update the .bam file format

# %%
# !modkit update-tags \
#  /home/michalula/data/cas9_nanopore/data/2024927_Cas9_R9_promethion_K562/to_t2t_v1_1/sort_aligned_T2Tv1_1_trim_bam_pass_merged.bam \
#     /home/michalula/data/cas9_nanopore/data/2024927_Cas9_R9_promethion_K562/to_t2t_v1_1/sort_aligned_T2Tv1_1_trim_bam_pass_merged.updated.bam \
#  --mode ambiguous

# %%
# ! samtools index /home/michalula/data/cas9_nanopore/data/2024927_Cas9_R9_promethion_K562/to_t2t_v1_1/sort_aligned_T2Tv1_1_trim_bam_pass_merged.updated.bam

# %%
bam_path = "/home/michalula/data/cas9_nanopore/data/2024927_Cas9_R9_promethion_K562/to_t2t_v1_1/sort_aligned_T2Tv1_1_trim_bam_pass_merged.updated.bam"
# "/home/michalula/data/cas9_nanopore/data/20231019_cas9_12ef_Jurkat/cas9_12ef_101923_misha_mod_mappings.sorted_mC_only.updated.bam"
# "/home/michalula/data/cas9_nanopore/data/20231019_cas9_12ef_Jurkat/cas9_12ef_101923_misha_mod_mappings.sorted_mC_only.bam"

# "/home/michalula/data/cas9_nanopore/data/2024927_Cas9_R9_promethion_K562/post_seq_basecall_align/sort_aligned_t2t_v1_1_trimmed_postrun_basecall_sup_20240927_cas9_R9_promethion.bam"
# "/home/michalula/data/cas9_nanopore/data/2024927_Cas9_R9_promethion_K562/to_t2t_v1_1/more_mismatches/aligned_k16_t2t_v1_1_trim_bam_pass_merged/sort_aligned_dorado_k16_t2t_v1_1_trim_bam_pass_merged.bam"
# "/home/michalula/data/cas9_nanopore/data/20231019_cas9_12ef_Jurkat/cas9_12ef_101923_misha_mod_mappings.sorted_mC_only.bam"
bam_path
# Out:
# '/home/michalula/data/cas9_nanopore/data/2024927_Cas9_R9_promethion_K562/to_t2t_v1_1/sort_aligned_T2Tv1_1_trim_bam_pass_merged.updated.bam'

# %%
output_dir = Path("./dimelo_v2_output")
# Path('/content/drive/MyDrive/Michal Rozenwald/data/CD55/cas9_12ef_101923_misha/dimelo_new_package') # './test/output')

output_dir.mkdir(exist_ok=True)
output_dir
# Out:
# PosixPath('dimelo_v2_output')

# %%
output_dir,bam_path
# Out:
# (PosixPath('dimelo_v2_output'),
#  '/home/michalula/data/cas9_nanopore/data/2024927_Cas9_R9_promethion_K562/to_t2t_v1_1/sort_aligned_T2Tv1_1_trim_bam_pass_merged.updated.bam')

# %% [markdown]
# # using domelo modkit_parsing_beta :

# %%
# using domelo modkit_parsing_beta :
t2t_v1_1_cd55_30bps = 'chr1:206586162-206586192'

extract_file, extract_regions = parse_bam.extract(
    input_file=bam_path, # ctcf_bam_file_updated
    output_name='cas9_12ef_101923_beta_extract_30bps_chr1_206586162_206586192_wsNone_thresh190', # _ws4000 'ctcf_demo_extract',
    ref_genome=ref_genome_v1_1_file, # ref_genome_file,
    output_directory=output_dir,
    regions=t2t_v1_1_cd55_30bps, # [cd55_interest_target_regions], # ctcf_target_regions,ctcf_off_target_regions],
    motifs=['CG,0'], # ['A,0','CG,0'],
    thresh=190,
    window_size=None,

    # cores = 1, # uncomment this line if your process appears to be terminating early (reduces memory usage)
    # quiet = True,
    # cleanup = False,
    # log=True,
)
# Out:
# No specified number of cores requested. 24 available on machine, allocating all.
# Modification threshold of 190 assumed to be for range 0-255. 190/255=0.7450980392156863 will be sent to modkit.
#           | Step 1: Identify motif locations in chm13.draft_v1.1.fasta   0% | 00:00
#           | Step 2: Parse regions in sort_aligned_T2Tv1_1_trim_bam_pass_merged.updated.bam   0% | 00:00<?
#           |    0%
#           | Transferring 257 from reads.CG,0.txt into reads.combined_basemods.h5, new size 257   0% | 00:00<?

# %%
read_data_list, datasets, _ = load_processed.read_vectors_from_hdf5(
    file=extract_file, # extract_file_no_thresh, # raw modification probabilities
    regions=t2t_v1_1_cd55_30bps, # cd55_30bps_interest_coords, # ctcf_target_regions,
    motifs=['CG,0'], # 'A,0'],
    window_size=None,
)
# Print out the data from the first read
for idx,dataset in enumerate(datasets):
    print(dataset)
    for read_data in read_data_list:
        print('\t',read_data[idx])
        break
# Out:
# chromosome
# 	 chr1
# mod_vector
# 	 [False False False ... False False False]
# motif
# 	 CG,0
# read_end
# 	 206589858
# read_name
# 	 ff1fc249-aa9b-4495-be8d-bed3d2ffa67a
# read_start
# 	 206583010
# strand
# 	 +
# val_vector
# 	 [False False False ...  True False  True]
# region_start
# 	 206586162
# region_end
# 	 206586192
# region_strand
# 	 .
# CG,0_mod_fraction
# 	 0.16666666666666666

# %%
read_data_list
# Out:
# [('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589858),
#   'ff1fc249-aa9b-4495-be8d-bed3d2ffa67a',
#   np.int32(206583010),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.16666666666666666)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206588766),
#   'c7283b36-b903-4d07-985d-971a964fce62',
#   np.int32(206583058),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589911),
#   '02d255f8-b148-4db9-978d-110308c0b14f',
#   np.int32(206583059),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590168),
#   'e606bbc7-5ae7-4d55-b64e-43aa1826a969',
#   np.int32(206583106),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ...,  True, False, False]),
#   'CG,0',
#   np.int32(206589924),
#   '3431ebdd-206d-4f46-b112-8f2dcfa65f72',
#   np.int32(206583113),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.125)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589906),
#   'ff18a668-932c-4514-91c0-520f8f59dcb0',
#   np.int32(206583118),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590046),
#   '112290f7-ce17-4607-a7d3-7f106240a595',
#   np.int32(206583118),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589938),
#   'd841e21d-d73a-49cb-8d3f-86c3ea9df1f0',
#   np.int32(206583118),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206587457),
#   '3e4250ab-bdf9-42cb-b64c-d465522f9ed6',
#   np.int32(206583119),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589925),
#   'c49e5926-7675-4562-9322-25168f851665',
#   np.int32(206583120),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589949),
#   '8aeb12ad-6b6d-4f13-a7b6-0112759dcaf5',
#   np.int32(206583121),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589868),
#   '88f69a97-edb6-4f1d-bdc9-f6730a2ef6cc',
#   np.int32(206583124),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589900),
#   'd3b94f62-c39e-4ce8-807a-8d7925c852de',
#   np.int32(206583124),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589935),
#   'd6a53676-88aa-46db-ae7a-afd9e201bca0',
#   np.int32(206583125),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.5)),
#  ('chr1',
#   array([False, False, False, ..., False, False,  True]),
#   'CG,0',
#   np.int32(206589920),
#   '81b18fa4-df3c-4dae-889a-2c34936af9a8',
#   np.int32(206583125),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.125)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206586359),
#   '0c934dbe-36b5-4b32-b223-638f09ffc9d4',
#   np.int32(206583126),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589923),
#   'bb3b020d-1045-4d24-8316-928ec9cc949d',
#   np.int32(206583126),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.2222222222222222)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206594512),
#   '65fe0683-cc55-48ab-9b16-fcf33da52389',
#   np.int32(206583128),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206587361),
#   '272f3574-dfda-4057-8cd2-a6f4fdaa9da6',
#   np.int32(206583128),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590097),
#   '530136dd-106b-4282-976a-1ff161165311',
#   np.int32(206583128),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589894),
#   'a85dbe20-8c13-4edc-bbae-0c6b8aaf02f8',
#   np.int32(206583129),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590090),
#   '7a822d68-e23d-422d-98cb-ffdbb4a6f446',
#   np.int32(206583129),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589916),
#   '5ebf9f42-e959-4b2d-b4ec-a831c692b7f8',
#   np.int32(206583129),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589899),
#   '36b33be9-e199-4826-a3f0-58ec0c88e68e',
#   np.int32(206583130),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589895),
#   '93d86f8e-cff5-44a2-82f0-d957fc6beb36',
#   np.int32(206583130),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206594043),
#   '79e27f7c-5621-40b4-8b94-7d7667c9b7a8',
#   np.int32(206583131),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589917),
#   '144104d2-0c67-4471-8b32-22d43f80d087',
#   np.int32(206583131),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589899),
#   'b76621d1-268b-4df4-9877-f0cd6e32c88e',
#   np.int32(206583131),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590089),
#   '3317cd61-8e22-41b3-bfca-a8c208841d87',
#   np.int32(206583132),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206586791),
#   '279437da-0236-4633-bb4f-6102b0a548fd',
#   np.int32(206583132),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589915),
#   '9add6562-294f-44f7-b7c9-bd2dac724e68',
#   np.int32(206583133),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206588820),
#   '7560a489-c26d-40d8-91e9-af64ca502143',
#   np.int32(206583133),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589898),
#   'ff0dbf00-6814-45ca-bf2e-d48e27535bb1',
#   np.int32(206583134),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206587659),
#   'a84a5fcd-a1f4-4726-b311-4835f6d7ad8c',
#   np.int32(206583134),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.16666666666666666)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206586212),
#   'fed002af-988a-45ce-a8b5-7e782538e62b',
#   np.int32(206583134),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False,  True]),
#   'CG,0',
#   np.int32(206589845),
#   '408744cc-3df8-4813-a3d9-c02a4aa9d67e',
#   np.int32(206583134),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.125)),
#  ('chr1',
#   array([False, False, False, ..., False, False,  True]),
#   'CG,0',
#   np.int32(206587007),
#   'b1b6b822-84d0-40a0-a62d-338c2a024ee9',
#   np.int32(206583136),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.2222222222222222)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589930),
#   'f4972f06-06cc-4ade-b30a-23cde9975d59',
#   np.int32(206583137),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590318),
#   '46976cff-892e-419f-80c8-ba67084b774b',
#   np.int32(206583137),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206588766),
#   'b8e3752c-2d91-4d2b-8017-8b6004f6b053',
#   np.int32(206583137),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589938),
#   '3da45f63-9e9d-4ee7-ad46-dc7c1bad413c',
#   np.int32(206583137),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589723),
#   'ee357ca8-2d58-4633-82e7-03d1520a23c1',
#   np.int32(206583137),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589905),
#   '3c1ae440-8ae5-47e4-acb7-578c2cc1a62c',
#   np.int32(206583138),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589937),
#   'c8b66aa5-d0d4-4755-a044-9686336e2fb1',
#   np.int32(206583139),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.375)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206588669),
#   '171a57f1-bf6c-4828-848d-b5902eaf9865',
#   np.int32(206583140),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589912),
#   'b1cf9c97-2560-4dfd-bc7c-c06736f8eefc',
#   np.int32(206583140),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589925),
#   'db393338-fa80-4e1a-a0f1-2c9fd29a3fa8',
#   np.int32(206583140),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589902),
#   'b89bf60a-1285-412c-9d11-2d49d4ecfef6',
#   np.int32(206583140),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589946),
#   '6ea61913-551f-44b3-b9f5-3fcb7c8744ee',
#   np.int32(206583141),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206586327),
#   'da06d5aa-622f-4a93-9992-f9fd341a657e',
#   np.int32(206583141),
#   '+',
#   array([False, False, False, ..., False, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589917),
#   'ea8a937c-f27c-43ff-8c53-689b3c04cb32',
#   np.int32(206583141),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590142),
#   'd32a0f95-4382-4e49-9900-e16b92773eab',
#   np.int32(206583142),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206587989),
#   '7cf8c883-8332-45bb-b93f-7002a359bda1',
#   np.int32(206583142),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589912),
#   '29046125-b0f0-40ca-bc60-560331014c20',
#   np.int32(206583143),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589914),
#   '00bd721e-99ed-4b1d-82d6-44c8b682e8d1',
#   np.int32(206583143),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589906),
#   '34b543f7-5795-4511-860c-24ab3aaa7336',
#   np.int32(206583143),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206586783),
#   '28761af2-2424-42cb-a3a7-5d3effddcc6e',
#   np.int32(206583143),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ...,  True, False,  True]),
#   'CG,0',
#   np.int32(206587106),
#   '1d68a2e4-4ad7-4e3f-bd89-07aa58c3429d',
#   np.int32(206583143),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.25)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589894),
#   'ebce11da-803c-4e6e-9eab-b7791e80a0a0',
#   np.int32(206583144),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589933),
#   'f1f5bd55-e2e7-4d09-b5ba-b38a10740fe0',
#   np.int32(206583144),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589874),
#   'd5e44291-a649-4a2c-b98d-efa8c91cd2a7',
#   np.int32(206583144),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.1111111111111111)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206605506),
#   'b9f660f1-7be0-4c97-9c22-907694f0bc65',
#   np.int32(206583144),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589888),
#   '7c502aab-4ac3-42f6-a635-926315c6ad3a',
#   np.int32(206583145),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589907),
#   '9d5261ac-f19b-4974-b274-cda46bffecc4',
#   np.int32(206583145),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ...,  True, False, False]),
#   'CG,0',
#   np.int32(206589934),
#   '0fc271ed-7903-47db-ad09-e46bc815dfef',
#   np.int32(206583145),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.14285714285714285)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206588755),
#   'ecfbd14d-b962-40ea-958c-95d70a301e86',
#   np.int32(206583145),
#   '+',
#   array([False, False, False, ..., False, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589938),
#   '965ea225-1fbb-429d-a266-d1a7d2fb9e6e',
#   np.int32(206583145),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589924),
#   'd9c5d8e9-297d-4c47-b40c-f3e4d89cc17f',
#   np.int32(206583145),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590032),
#   '70d51063-52b9-424f-a5cc-29002a7a0a15',
#   np.int32(206583146),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.6)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589835),
#   '10b319d9-0a66-4633-a966-1282a658cd87',
#   np.int32(206583146),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589904),
#   '406feef1-8edc-4992-ac68-a214de17add6',
#   np.int32(206583146),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589931),
#   '72f0a468-89bc-418f-8331-e083f26125c1',
#   np.int32(206583147),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590072),
#   '18123b39-d88d-4a4e-9ead-dbb5bed522b6',
#   np.int32(206583147),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589906),
#   'aaace842-c463-4106-9cde-17776d2f60fb',
#   np.int32(206583147),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589912),
#   '83ccae46-68b2-4320-82d3-0db2059e7d0c',
#   np.int32(206583147),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589905),
#   '7fbf6f3e-6366-4f33-80a8-08a0b1930835',
#   np.int32(206583148),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.25)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589777),
#   '5f2e46fb-1f48-417d-b94a-d02352f95fa0',
#   np.int32(206583148),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589919),
#   '584f89a0-936e-4784-a7f0-093863c558a2',
#   np.int32(206583148),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590240),
#   'cd77bb27-47d8-4f84-85c7-6069f25c4cb7',
#   np.int32(206583148),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False,  True]),
#   'CG,0',
#   np.int32(206589891),
#   'd7b1f058-01a2-41d2-8e15-3be9a1c9b90f',
#   np.int32(206583148),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.14285714285714285)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589917),
#   '0c930163-7961-4bad-b16d-12097398a457',
#   np.int32(206583148),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206587597),
#   '568be4bc-c966-4c9b-b82b-a3e4728bdfc5',
#   np.int32(206583148),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589482),
#   'c67f7dbc-d595-45c9-862d-2d18a1c02710',
#   np.int32(206583149),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589924),
#   'd48cd1fe-2f9e-42ab-bbae-06a8dde7597f',
#   np.int32(206583149),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589923),
#   'e25f5a16-43d4-4c70-9728-323c45d32c9c',
#   np.int32(206583149),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206587459),
#   '4a7ac305-a27e-4bf0-bdcf-a09ee9592035',
#   np.int32(206583149),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589959),
#   '993ede80-2d2f-493f-be35-da53c40681d0',
#   np.int32(206583150),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.2857142857142857)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589928),
#   'd717c0a8-1bd6-42ef-8409-c532ff319f58',
#   np.int32(206583150),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589912),
#   '4329a576-487b-4984-8fd7-ee58bb856712',
#   np.int32(206583150),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589908),
#   '8ccfb2e3-e909-4e78-9e36-fd664dea6f52',
#   np.int32(206583150),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589939),
#   'e08040a2-85a6-4f07-b53a-8d08ba3b1840',
#   np.int32(206583150),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589891),
#   '936dddb3-6185-4375-90ff-f6fa682585fb',
#   np.int32(206583151),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589896),
#   'dac16732-3d15-42ba-ac3b-4af585a2e3fd',
#   np.int32(206583151),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589905),
#   '36ea49da-8a14-4bba-86b4-8debeb964193',
#   np.int32(206583151),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589850),
#   '50f9876e-c452-44e6-99c0-bb1837eb1131',
#   np.int32(206583152),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589713),
#   '2620e8ae-6b43-4271-ba63-a5191a065607',
#   np.int32(206583152),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206586552),
#   '246ea281-27ed-476e-8416-c7296e6d24d5',
#   np.int32(206583152),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589904),
#   'bce823fb-afd5-4152-87ac-ac6458859800',
#   np.int32(206583152),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589875),
#   'd4c4fb9f-7fa2-45ae-8a0f-262c7e94b27a',
#   np.int32(206583152),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206587106),
#   '3cc6cb60-0a3a-44ec-8131-f444057aa8cc',
#   np.int32(206583152),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590059),
#   '08c1f37a-f2ff-4086-8356-63ad2ffe3e05',
#   np.int32(206583153),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589901),
#   '4fa00abd-de7c-44b6-9d8f-b3207e1044e3',
#   np.int32(206583153),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.125)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589865),
#   '9d4df46b-648b-444e-9a56-ac4334d36bc4',
#   np.int32(206583153),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589909),
#   '450cb979-3536-4e04-9517-a6c8b067d614',
#   np.int32(206583153),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ...,  True, False,  True]),
#   'CG,0',
#   np.int32(206589899),
#   'd686b3ee-5bfa-422a-bc4e-7fb58ee09e2f',
#   np.int32(206583153),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.2222222222222222)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206588538),
#   'e26d6fda-d16c-44e8-a04f-1985375b7986',
#   np.int32(206583154),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589840),
#   '2cf84a34-7174-4e33-9156-08a57aa68dab',
#   np.int32(206583154),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589899),
#   'eb0942b1-5bc4-4942-bea3-9e8eae011748',
#   np.int32(206583154),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589890),
#   'fa00bcd3-7d32-42fd-9feb-b1d933037ee3',
#   np.int32(206583154),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206587432),
#   '5004f4d2-dd6a-44af-ac37-48ce1eec80c0',
#   np.int32(206583155),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206588090),
#   '5f77d73d-36b0-47d7-bb4c-46a5cbfb1e83',
#   np.int32(206583155),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206586300),
#   'd5c29fe7-8d10-4266-a3c8-867d3b201342',
#   np.int32(206583155),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589943),
#   'cbedf72c-917a-4def-a138-8778a27b2007',
#   np.int32(206583155),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589923),
#   '400a6c92-5c7e-4e07-a3c1-7547eda29af3',
#   np.int32(206583156),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206586962),
#   'a764dd72-6996-4ceb-a343-1cac86b1cd7c',
#   np.int32(206583156),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589908),
#   'a5f0f4bb-62a3-4d4a-b080-119e6e0f1cb4',
#   np.int32(206583156),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589891),
#   '717493b0-3235-4b40-a8c0-4651466f56ee',
#   np.int32(206583156),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589876),
#   '96c77380-cd81-4906-a984-bdbdfd0baada',
#   np.int32(206583157),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.1111111111111111)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589956),
#   'a6a80d4a-d051-4ee2-9058-c965d1e96c3c',
#   np.int32(206583157),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.2)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589923),
#   '88dd6881-dbf5-4637-b244-4f1f0f0596da',
#   np.int32(206583158),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.125)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590330),
#   'e495fe2a-c0de-4a96-9e5a-53f87ec1207e',
#   np.int32(206583158),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589859),
#   '6cd917b2-e7a1-42b2-a980-5ca5c3f3deaf',
#   np.int32(206583158),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589906),
#   '138f8518-9e72-4ed8-89a4-03e62bff2788',
#   np.int32(206583158),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589857),
#   'bbbd0db4-6cea-4608-87ae-65ed8a344a55',
#   np.int32(206583158),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589955),
#   '3f99d499-a9f7-4a3a-b359-3a23ce3f7710',
#   np.int32(206583158),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589824),
#   '20b6201d-f323-44b9-bd8b-ac076910c086',
#   np.int32(206583159),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589923),
#   '9363b663-edfd-4352-ac1a-f425044310f6',
#   np.int32(206583160),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589959),
#   '1e1e0280-65ee-4682-90f6-584d52461e25',
#   np.int32(206583160),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589936),
#   '03280f1c-ac38-417f-be4e-a81bc62c05c7',
#   np.int32(206583160),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589826),
#   'be53fd06-3875-4b8a-b748-2dfc55e6e39f',
#   np.int32(206583160),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206598388),
#   'b54cea8c-d206-425b-a1b2-1d45cb901082',
#   np.int32(206583160),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589920),
#   '5eae6e85-fde3-463e-a26c-cca69c93ed16',
#   np.int32(206583160),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590030),
#   'cb246373-f77a-412f-a6d0-ba0178387cdb',
#   np.int32(206583161),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589906),
#   'f087c367-f2f1-4cad-a153-d14a0d22a829',
#   np.int32(206583161),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589873),
#   '42ec294c-55e9-4846-9cef-14df7d7734f9',
#   np.int32(206583161),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589871),
#   '39aeda22-d468-43d0-98df-00824ddf62e2',
#   np.int32(206583162),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589939),
#   '3e3d5299-2be2-4843-b5fe-3094a4a48525',
#   np.int32(206583162),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206587743),
#   '4372aec5-87b9-4398-8f71-7d7df39c2bea',
#   np.int32(206583162),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589874),
#   'acddb7c6-3071-4080-80dd-afebe83ea022',
#   np.int32(206583162),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589927),
#   '2be3343d-964d-4de1-adc7-f75adcd601c3',
#   np.int32(206583162),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206587341),
#   '799165cc-76ab-48b8-930f-9cfa19377725',
#   np.int32(206583162),
#   '+',
#   array([False, False, False, ..., False, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ...,  True, False,  True]),
#   'CG,0',
#   np.int32(206590096),
#   '06949baf-e6de-4af1-8f94-ddf8ca3296bf',
#   np.int32(206583162),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.375)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589922),
#   'c23140ea-5466-4689-8b80-2d4f79b755f4',
#   np.int32(206583162),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.1111111111111111)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589907),
#   'ee9fe4b8-8902-4015-924f-88eea83fed59',
#   np.int32(206583162),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206588388),
#   'ee16436c-7af7-4765-a33f-f7029b733cac',
#   np.int32(206583163),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589864),
#   'b6619e22-d525-433d-a350-b75df7beef6f',
#   np.int32(206583163),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589937),
#   '09c0c774-38c4-4e33-9a64-ef506a90d1f0',
#   np.int32(206583163),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206590031),
#   '6396f087-5082-4f5f-ae74-4ea654d9e061',
#   np.int32(206583164),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589901),
#   '36d309cc-dc41-45c1-a35c-b5f7d95972da',
#   np.int32(206583164),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589688),
#   '45d6c45b-60a0-4a28-bf5f-a6f2b8c188b9',
#   np.int32(206583164),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589912),
#   '3e4cbdab-8e01-491b-aef8-dcd708f75d47',
#   np.int32(206583164),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589944),
#   '88c7cb15-ed84-4e54-89ff-04a4c1d46070',
#   np.int32(206583164),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206588038),
#   '7b9bb7c3-ed86-4738-83f6-7bd901ca99fb',
#   np.int32(206583165),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.125)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589911),
#   'e094c298-d63b-4c7b-8cdd-6ffde694e8f0',
#   np.int32(206583165),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589891),
#   '4f44b11a-8cc9-40a7-996c-a5bf716544a7',
#   np.int32(206583165),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589883),
#   '303ecf45-3b35-4216-bec6-1916b7ab8b9f',
#   np.int32(206583165),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589924),
#   'd3220d38-6c66-44e9-b7d6-26eac8d7c4ec',
#   np.int32(206583165),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589906),
#   '5181674e-0194-4c7a-8a91-bdf251fc71f9',
#   np.int32(206583165),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589867),
#   '0ba5cc36-0e0c-48b2-b4e0-820353d3bd08',
#   np.int32(206583165),
#   '+',
#   array([False, False, False, ..., False, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589927),
#   'df21df5e-6cce-49b3-8339-71670caf97b0',
#   np.int32(206583166),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ...,  True, False,  True]),
#   'CG,0',
#   np.int32(206589113),
#   '91e83428-107a-488e-aa49-dce1ee0effed',
#   np.int32(206583166),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.3333333333333333)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589959),
#   '4047059c-b932-4f21-b795-9f0bd4cc72d4',
#   np.int32(206583166),
#   '-',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589886),
#   'fd6d819f-bb00-49f1-8b43-b9432a90bab7',
#   np.int32(206583166),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589895),
#   'd4510a86-8aee-4e15-8be7-771878c5d324',
#   np.int32(206583166),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589914),
#   '60d9a9dd-644e-4844-87be-71194487ade8',
#   np.int32(206583166),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589917),
#   'fe4b6d02-3665-4b7d-bedd-7fc81a4f0135',
#   np.int32(206583166),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589919),
#   '66d277c3-8c0f-407e-9e30-f47cad097629',
#   np.int32(206583166),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
#   np.int32(206589074),
#   'c266a7d0-1ddf-4180-9e09-309f08e9fb44',
#   np.int32(206583166),
#   '+',
#   array([False, False, False, ...,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.125)),
#  ('chr1',
#   array([False, False, False, ..., False, False, False]),
#   'CG,0',
# ...
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False]),
#   'CG,0',
#   np.int32(206589954),
#   'c5f44506-ef09-4f52-8ec7-b8e02c0f15ce',
#   np.int32(206585445),
#   '-',
#   array([False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False,  True,
#          False, False, False, False,  True, False, False, False, False,
#           True, False,  True, False,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0)),
#  ('chr1',
#   array([False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False]),
#   'CG,0',
#   np.int32(206589935),
#   'd0804736-5d96-4264-a9a5-f052c7d0c61e',
#   np.int32(206585714),
#   '-',
#   array([False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False,
#           True, False, False, False, False, False, False, False, False,
#          False,  True, False,  True, False,  True, False,  True, False,
#           True, False,  True, False,  True, False,  True]),
#   206586162,
#   206586192,
#   '.',
#   np.float64(0.0))]

# %%
read_data_list[0][1] #['mod_vector']
# Out:
# array([False, False, False, ..., False, False, False])

# %%
from matplotlib import pyplot as plt
from dimelo import plot_reads

plot_reads.plot_reads(
    extract_file, # extracted_h5,
    regions = 'chr1:206582520-206585020',
    motifs = ['CG,0'],
    thresh = 0.75,
    sort_by = ['shuffle','strand'],
    relative = False,
    window_size = None, # 5000,
    s=5,
)
# Out:
# <Axes: xlabel='pos', ylabel='read_name'>

# %%
from matplotlib import pyplot as plt
from dimelo import plot_reads

plot_reads.plot_reads(
    extract_file, # extracted_h5,
    regions = 'chr1:206582520-206585020',
    motifs = ['CG,0'],
    thresh = 0.75,
    sort_by = ['shuffle','strand'],
    relative = False,
    window_size =  5000, # None, #
    s=5,
)
# Out:
# <Axes: xlabel='pos', ylabel='read_name'>

# %%
# chr1_
206586162-206586192
# Out:
# -30

# %%
# ref_genome_v1_1_file
window_size = 4000
outname = f'cd55_window{window_size}'
num_cores = 32

# cas9 = parse_bam.extract(
#     input_file=bam_cas9_12ef_101923_updated, # cd55_filepath,
#     output_name=outname,
#     ref_genome=ref_genome_v1_1_file, # '/clusterfs/nilah/oberon/genomes/chm13.draft_v1.1.fasta',
#     regions=t2t_cd55_30bps, # bed_files="chr1:206586162-206586192", # [bed_region],
#     basemods=['CG,0'],
#     cores=num_cores,
#     thresh=0.75,
#     window_size=window_size,
# )
t2t_v1_1_cd55_30bps = 'chr1:206586162-206586192'

# = extract_file, extract_regions
cas9  = parse_bam.extract(
    input_file=bam_path, # ctcf_bam_file_updated
    output_name='cas9_12ef_101923_extract_chr1_206586162_206586192_ws4000_thresh075', # _ws4000 'ctcf_demo_extract',
    ref_genome=ref_genome_v1_1_file, # ref_genome_file,
    output_directory=output_dir,
    regions=t2t_v1_1_cd55_30bps, # [cd55_interest_target_regions], # ctcf_target_regions,ctcf_off_target_regions],
    motifs=['CG,0'], # ['A,0','CG,0'],
    thresh=0.75, # 190,
    window_size=window_size, # None,
    # cores = 1, # uncomment this line if your process appears to be terminating early (reduces memory usage)
    # quiet = True,
    # cleanup = False,
    # log=True,
)
# Out:
# No specified number of cores requested. 24 available on machine, allocating all.
# Modification threshold of 0.75 will be treated as coming from range 0-1.
#           | Step 1: Identify motif locations in chm13.draft_v1.1.fasta   0% | 00:00
#           | Step 2: Parse regions in sort_aligned_T2Tv1_1_trim_bam_pass_merged.updated.bam   0% | 00:00<?
#           |    0%
#           | Transferring 310 from reads.CG,0.txt into reads.combined_basemods.h5, new size 310   0% | 00:00<?

# %%
extract_file_ws4000, extract_regions_ws4000 = cas9
extract_file_ws4000
# Out:
# PosixPath('dimelo_v2_output/cas9_12ef_101923_extract_chr1_206586162_206586192_ws4000_thresh075/reads.combined_basemods.h5')

# %%
plot_reads.plot_reads(
    extract_file_ws4000, # cas9,
    "chr1:206586162-206586192", # bed_region,
    ['CG,0'],
    window_size = 4000,
    s=1)
plt.xlabel('bp relative to CD55 differential methylated region (t2t v1.1 chr1:206586177)')
plt.title('cas9_12ef_101923_misha_mod_mappings.retagged.sorted_mC_only.bam CpG extraction')
# Out:
# Text(0.5, 1.0, 'cas9_12ef_101923_misha_mod_mappings.retagged.sorted_mC_only.bam CpG extraction')

# %%
plot_reads.plot_reads(
    extract_file_ws4000, # cas9,
    "chr1:206586162-206586192", # bed_region,
    ['CG,0'],
    window_size = 4000,
    sort_by = ['strand'], # ['shuffle','strand'],
    # sort_by = ['shuffle', 'strand', 'region_start'], # ['shuffle','strand'],
    s=1)
plt.xlabel('bp relative to CD55 differential methylated region (t2t v1.1 chr1:206586177)')
# plt.title('cas9_12ef_101923_misha_mod_mappings.retagged.sorted_mC_only.bam CpG extraction')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plot_reads.plot_reads(
#       2     extract_file_ws4000, # cas9,
#       3     "chr1:206586162-206586192", # bed_region,
#       4     ['CG,0'],
#       5     window_size = 4000,
#       6     sort_by = ['strand'], # ['shuffle','strand'],
#       7     # sort_by = ['shuffle', 'strand', 'region_start'], # ['shuffle','strand'],
#       8     s=1)
#       9 plt.xlabel('bp relative to CD55 differential methylated region (t2t v1.1 chr1:206586177)')
#      10 # plt.title('cas9_12ef_101923_misha_mod_mappings.retagged.sorted_mC_only.bam CpG extraction')
#
# NameError: name 'plot_reads' is not defined

# %% [markdown]
# # Sort reads by the region start

# %%
# Sort reads by the region start

plot_reads.plot_reads(
    extract_file_ws4000, # cas9,
    "chr1:206586162-206586192", # bed_region,
    ['CG,0'],
    window_size = 4000,
    sort_by = ['region_start'], # ['shuffle','strand'],
    # sort_by = ['shuffle', 'strand', 'region_start'], # ['shuffle','strand'],
    s=1)
# plt.xlabel('bp relative to CD55 differential methylated region (t2t v1.1 chr1:206586177)')
# plt.title('cas9_12ef_101923_misha_mod_mappings.retagged.sorted_mC_only.bam CpG extraction')
# Out:
# <Axes: xlabel='pos', ylabel='read_name'>

# %%
ax=plot_reads.plot_reads(
    extract_file_ws4000, # cas9,
    "chr1:206586162-206586192", # bed_region,
    ['CG,0'],
    window_size = 4000,
    sort_by = ['region_start', 'shuffle'], # ['shuffle','strand'],
    # sort_by = ['shuffle', 'strand', 'region_start'], # ['shuffle','strand'],
    s=1)
ax.get_legend() 
#only works after the legend was created. Try
leg = ax.legend()

plt.xlabel('bp relative to CD55 differential methylated region (t2t v1.1 chr1:206586177)')
plt.title('cas9_12ef_101923_misha_mod_mappings.retagged.sorted_mC_only.bam CpG extraction')
# Out:
# Text(0.5, 1.0, 'cas9_12ef_101923_misha_mod_mappings.retagged.sorted_mC_only.bam CpG extraction')

# %%
ax = plot_reads.plot_reads(
    extract_file_ws4000, # cas9,
    "chr1:206586162-206586192", # bed_region,
    ['CG,0'],
    window_size = 4000,
    sort_by = ['region_start', 'strand'], # ['shuffle','strand'],
    # sort_by = ['shuffle', 'strand', 'region_start'], # ['shuffle','strand'],
    s=1)
plt.xlabel('bp relative to CD55 differential methylated region (t2t v1.1 chr1:206586177)')
plt.title('cas9_12ef_101923_misha_mod_mappings.retagged.sorted_mC_only.bam CpG extraction')
# Out:
# Text(0.5, 1.0, 'cas9_12ef_101923_misha_mod_mappings.retagged.sorted_mC_only.bam CpG extraction')

# %%
ax = plot_reads.plot_reads(
    extract_file_ws4000, # cas9,
    "chr1:206586162-206586192", # bed_region,
    ['CG,0'],
    window_size = 4000,
    sort_by = ['shuffle','strand'], # ['region_start', 'strand'], #
    # sort_by = ['shuffle', 'strand', 'region_start'], # ['shuffle','strand'],
    s=1)
plt.xlabel('bp relative to CD55 differential methylated region (t2t v1.1 chr1:206586177)')
plt.title('cas9_12ef_101923_misha_mod_mappings.retagged.sorted_mC_only.bam CpG extraction')
# Out:
# Text(0.5, 1.0, 'cas9_12ef_101923_misha_mod_mappings.retagged.sorted_mC_only.bam CpG extraction')

# %%
from matplotlib import pyplot as plt
from dimelo import plot_reads

fig, ax = plt.subplots()

ax = plot_reads.plot_reads(
    extract_file, # extracted_h5,
    regions = t2t_v1_1_cd55_30bps, #'chr1:206582520-206585020',
    motifs = ['CG,0'],
    thresh = 0.75,
    sort_by = ['shuffle','strand'],
    # relative = False,
    relative = True,
    window_size = None, # 5000,
    s=5,
)
# plt.xlim(206582520,206585020)


seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
print(seq)
seq_list =  [s for s in seq]
plt.xticks(np.arange(len(seq_list)) - 15, seq_list, size='small')
# Out:
# CCGCCCCGAGGCGCGCGCGCGCGCGCGCAC
# ([<matplotlib.axis.XTick at 0x7f34578b2e90>,
#   <matplotlib.axis.XTick at 0x7f3457709dd0>,
#   <matplotlib.axis.XTick at 0x7f34576e6a50>,
#   <matplotlib.axis.XTick at 0x7f3457770510>,
#   <matplotlib.axis.XTick at 0x7f34577ba190>,
#   <matplotlib.axis.XTick at 0x7f34577007d0>,
#   <matplotlib.axis.XTick at 0x7f3457819bd0>,
#   <matplotlib.axis.XTick at 0x7f34577d8b10>,
#   <matplotlib.axis.XTick at 0x7f34576ee290>,
#   <matplotlib.axis.XTick at 0x7f3457801310>,
#   <matplotlib.axis.XTick at 0x7f3457807250>,
#   <matplotlib.axis.XTick at 0x7f3457824f10>,
#   <matplotlib.axis.XTick at 0x7f3457807950>,
#   <matplotlib.axis.XTick at 0x7f3457804d10>,
#   <matplotlib.axis.XTick at 0x7f345789ab90>,
#   <matplotlib.axis.XTick at 0x7f3457898910>,
#   <matplotlib.axis.XTick at 0x7f345775ced0>,
#   <matplotlib.axis.XTick at 0x7f3457880450>,
#   <matplotlib.axis.XTick at 0x7f345775fcd0>,
#   <matplotlib.axis.XTick at 0x7f345773dc50>,
#   <matplotlib.axis.XTick at 0x7f345773fd90>,
#   <matplotlib.axis.XTick at 0x7f3457759d90>,
#   <matplotlib.axis.XTick at 0x7f345773e2d0>,
#   <matplotlib.axis.XTick at 0x7f3457740390>,
#   <matplotlib.axis.XTick at 0x7f3457742390>,
#   <matplotlib.axis.XTick at 0x7f3457742d10>,
#   <matplotlib.axis.XTick at 0x7f345776e5d0>,
#   <matplotlib.axis.XTick at 0x7f3457748790>,
#   <matplotlib.axis.XTick at 0x7f3457741cd0>,
#   <matplotlib.axis.XTick at 0x7f345774acd0>],
#  [Text(-15, 0, 'C'),
#   Text(-14, 0, 'C'),
#   Text(-13, 0, 'G'),
#   Text(-12, 0, 'C'),
#   Text(-11, 0, 'C'),
#   Text(-10, 0, 'C'),
#   Text(-9, 0, 'C'),
#   Text(-8, 0, 'G'),
#   Text(-7, 0, 'A'),
#   Text(-6, 0, 'G'),
#   Text(-5, 0, 'G'),
#   Text(-4, 0, 'C'),
#   Text(-3, 0, 'G'),
#   Text(-2, 0, 'C'),
#   Text(-1, 0, 'G'),
#   Text(0, 0, 'C'),
#   Text(1, 0, 'G'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'G'),
#   Text(4, 0, 'C'),
#   Text(5, 0, 'G'),
#   Text(6, 0, 'C'),
#   Text(7, 0, 'G'),
#   Text(8, 0, 'C'),
#   Text(9, 0, 'G'),
#   Text(10, 0, 'C'),
#   Text(11, 0, 'G'),
#   Text(12, 0, 'C'),
#   Text(13, 0, 'A'),
#   Text(14, 0, 'C')])

# %%
from matplotlib import pyplot as plt
from dimelo import plot_reads

fig, ax = plt.subplots()

ax = plot_reads.plot_reads(
    extract_file, # extracted_h5,
    regions = t2t_v1_1_cd55_30bps, #'chr1:206582520-206585020',
    motifs = ['CG,0'],
    thresh = 0.75,
    sort_by = ['shuffle','strand'],
    # relative = False,
    relative = True,
    window_size = None, # 5000,
    s=5,
)
# plt.xlim(206582520,206585020)


seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
print(seq)
seq_list =  [s for s in seq]
plt.xticks(np.arange(len(seq_list)) - 15, seq_list, size='small')
# Out:
# CCGCCCCGAGGCGCGCGCGCGCGCGCGCAC
# ([<matplotlib.axis.XTick at 0x7f345772d350>,
#   <matplotlib.axis.XTick at 0x7f3457789dd0>,
#   <matplotlib.axis.XTick at 0x7f34579784d0>,
#   <matplotlib.axis.XTick at 0x7f3457712c90>,
#   <matplotlib.axis.XTick at 0x7f3457921f10>,
#   <matplotlib.axis.XTick at 0x7f3457713410>,
#   <matplotlib.axis.XTick at 0x7f34577f9310>,
#   <matplotlib.axis.XTick at 0x7f34577fac90>,
#   <matplotlib.axis.XTick at 0x7f345770bb10>,
#   <matplotlib.axis.XTick at 0x7f34573433d0>,
#   <matplotlib.axis.XTick at 0x7f345736d550>,
#   <matplotlib.axis.XTick at 0x7f345736f5d0>,
#   <matplotlib.axis.XTick at 0x7f345733d0d0>,
#   <matplotlib.axis.XTick at 0x7f345733f590>,
#   <matplotlib.axis.XTick at 0x7f34577ad0d0>,
#   <matplotlib.axis.XTick at 0x7f3457379b10>,
#   <matplotlib.axis.XTick at 0x7f345737bc90>,
#   <matplotlib.axis.XTick at 0x7f345737db90>,
#   <matplotlib.axis.XTick at 0x7f345737fbd0>,
#   <matplotlib.axis.XTick at 0x7f345737e1d0>,
#   <matplotlib.axis.XTick at 0x7f3457382010>,
#   <matplotlib.axis.XTick at 0x7f3457388250>,
#   <matplotlib.axis.XTick at 0x7f345738a210>,
#   <matplotlib.axis.XTick at 0x7f3457390390>,
#   <matplotlib.axis.XTick at 0x7f3457392350>,
#   <matplotlib.axis.XTick at 0x7f3457381710>,
#   <matplotlib.axis.XTick at 0x7f3457398910>,
#   <matplotlib.axis.XTick at 0x7f345739a810>,
#   <matplotlib.axis.XTick at 0x7f34573a49d0>,
#   <matplotlib.axis.XTick at 0x7f34573a6a50>],
#  [Text(-15, 0, 'C'),
#   Text(-14, 0, 'C'),
#   Text(-13, 0, 'G'),
#   Text(-12, 0, 'C'),
#   Text(-11, 0, 'C'),
#   Text(-10, 0, 'C'),
#   Text(-9, 0, 'C'),
#   Text(-8, 0, 'G'),
#   Text(-7, 0, 'A'),
#   Text(-6, 0, 'G'),
#   Text(-5, 0, 'G'),
#   Text(-4, 0, 'C'),
#   Text(-3, 0, 'G'),
#   Text(-2, 0, 'C'),
#   Text(-1, 0, 'G'),
#   Text(0, 0, 'C'),
#   Text(1, 0, 'G'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'G'),
#   Text(4, 0, 'C'),
#   Text(5, 0, 'G'),
#   Text(6, 0, 'C'),
#   Text(7, 0, 'G'),
#   Text(8, 0, 'C'),
#   Text(9, 0, 'G'),
#   Text(10, 0, 'C'),
#   Text(11, 0, 'G'),
#   Text(12, 0, 'C'),
#   Text(13, 0, 'A'),
#   Text(14, 0, 'C')])

# %%
from matplotlib import pyplot as plt
from dimelo import plot_reads

fig, ax = plt.subplots()

ax = plot_reads.plot_reads(
    extract_file, # extracted_h5,
    regions = t2t_v1_1_cd55_30bps, #'chr1:206582520-206585020',
    motifs = ['CG,0'],
    thresh = 0.75,
    sort_by = ['shuffle', 'strand'], # 'region_start'], # 'strand'], # 'shuffle',
    # relative = False,
    relative = True,
    window_size = None, # 5000,
    s=5,
)
# plt.xlim(206582520,206585020)


seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
print(seq)
seq_list =  [s for s in seq]
plt.xticks(np.arange(len(seq_list)) - 15, seq_list, size='small')
# Out:
# CCGCCCCGAGGCGCGCGCGCGCGCGCGCAC
# ([<matplotlib.axis.XTick at 0x7f34573cd850>,
#   <matplotlib.axis.XTick at 0x7f34577d9dd0>,
#   <matplotlib.axis.XTick at 0x7f34573a4610>,
#   <matplotlib.axis.XTick at 0x7f3457310510>,
#   <matplotlib.axis.XTick at 0x7f34573f3510>,
#   <matplotlib.axis.XTick at 0x7f3457346690>,
#   <matplotlib.axis.XTick at 0x7f34574096d0>,
#   <matplotlib.axis.XTick at 0x7f345740b690>,
#   <matplotlib.axis.XTick at 0x7f3457382950>,
#   <matplotlib.axis.XTick at 0x7f345721f590>,
#   <matplotlib.axis.XTick at 0x7f3457221a50>,
#   <matplotlib.axis.XTick at 0x7f3457223a10>,
#   <matplotlib.axis.XTick at 0x7f345723dd90>,
#   <matplotlib.axis.XTick at 0x7f345723fd50>,
#   <matplotlib.axis.XTick at 0x7f345737f190>,
#   <matplotlib.axis.XTick at 0x7f34572462d0>,
#   <matplotlib.axis.XTick at 0x7f3457248410>,
#   <matplotlib.axis.XTick at 0x7f345724a610>,
#   <matplotlib.axis.XTick at 0x7f345724c790>,
#   <matplotlib.axis.XTick at 0x7f3457249e10>,
#   <matplotlib.axis.XTick at 0x7f345724edd0>,
#   <matplotlib.axis.XTick at 0x7f3457258f10>,
#   <matplotlib.axis.XTick at 0x7f345725af90>,
#   <matplotlib.axis.XTick at 0x7f3457258550>,
#   <matplotlib.axis.XTick at 0x7f34573c4490>,
#   <matplotlib.axis.XTick at 0x7f345724e1d0>,
#   <matplotlib.axis.XTick at 0x7f3457269510>,
#   <matplotlib.axis.XTick at 0x7f345726b450>,
#   <matplotlib.axis.XTick at 0x7f3457279690>,
#   <matplotlib.axis.XTick at 0x7f345727b650>],
#  [Text(-15, 0, 'C'),
#   Text(-14, 0, 'C'),
#   Text(-13, 0, 'G'),
#   Text(-12, 0, 'C'),
#   Text(-11, 0, 'C'),
#   Text(-10, 0, 'C'),
#   Text(-9, 0, 'C'),
#   Text(-8, 0, 'G'),
#   Text(-7, 0, 'A'),
#   Text(-6, 0, 'G'),
#   Text(-5, 0, 'G'),
#   Text(-4, 0, 'C'),
#   Text(-3, 0, 'G'),
#   Text(-2, 0, 'C'),
#   Text(-1, 0, 'G'),
#   Text(0, 0, 'C'),
#   Text(1, 0, 'G'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'G'),
#   Text(4, 0, 'C'),
#   Text(5, 0, 'G'),
#   Text(6, 0, 'C'),
#   Text(7, 0, 'G'),
#   Text(8, 0, 'C'),
#   Text(9, 0, 'G'),
#   Text(10, 0, 'C'),
#   Text(11, 0, 'G'),
#   Text(12, 0, 'C'),
#   Text(13, 0, 'A'),
#   Text(14, 0, 'C')])

# %%
from matplotlib import pyplot as plt
from dimelo import plot_reads

fig, ax = plt.subplots()

ax = plot_reads.plot_reads(
    extract_file, # extracted_h5,
    regions = t2t_v1_1_cd55_30bps, #'chr1:206582520-206585020',
    motifs = ['CG,0'],
    thresh = 0.75,
    sort_by = ['shuffle', 'strand', 'region_start'], # 'strand'], # 'shuffle',
    # relative = False,
    relative = True,
    window_size = None, # 5000,
    s=5,
)
# plt.xlim(206582520,206585020)


seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
print(seq)
seq_list =  [s for s in seq]
plt.xticks(np.arange(len(seq_list)) - 15, seq_list, size='small')
# Out:
# CCGCCCCGAGGCGCGCGCGCGCGCGCGCAC
# ([<matplotlib.axis.XTick at 0x7f345724bf10>,
#   <matplotlib.axis.XTick at 0x7f3457341650>,
#   <matplotlib.axis.XTick at 0x7f3457297f50>,
#   <matplotlib.axis.XTick at 0x7f345721d590>,
#   <matplotlib.axis.XTick at 0x7f34572c6550>,
#   <matplotlib.axis.XTick at 0x7f34572c7590>,
#   <matplotlib.axis.XTick at 0x7f34573050d0>,
#   <matplotlib.axis.XTick at 0x7f34572d83d0>,
#   <matplotlib.axis.XTick at 0x7f345727d850>,
#   <matplotlib.axis.XTick at 0x7f34572f4550>,
#   <matplotlib.axis.XTick at 0x7f34572f6590>,
#   <matplotlib.axis.XTick at 0x7f34572e8650>,
#   <matplotlib.axis.XTick at 0x7f34572ea750>,
#   <matplotlib.axis.XTick at 0x7f3457234890>,
#   <matplotlib.axis.XTick at 0x7f34573aab10>,
#   <matplotlib.axis.XTick at 0x7f3457236cd0>,
#   <matplotlib.axis.XTick at 0x7f3457237590>,
#   <matplotlib.axis.XTick at 0x7f34572cae90>,
#   <matplotlib.axis.XTick at 0x7f3457119010>,
#   <matplotlib.axis.XTick at 0x7f3457235990>,
#   <matplotlib.axis.XTick at 0x7f345711b450>,
#   <matplotlib.axis.XTick at 0x7f3457120490>,
#   <matplotlib.axis.XTick at 0x7f3457123750>,
#   <matplotlib.axis.XTick at 0x7f3457125950>,
#   <matplotlib.axis.XTick at 0x7f3457127850>,
#   <matplotlib.axis.XTick at 0x7f3457120b90>,
#   <matplotlib.axis.XTick at 0x7f345712de90>,
#   <matplotlib.axis.XTick at 0x7f345712fdd0>,
#   <matplotlib.axis.XTick at 0x7f3457131f50>,
#   <matplotlib.axis.XTick at 0x7f3457133f50>],
#  [Text(-15, 0, 'C'),
#   Text(-14, 0, 'C'),
#   Text(-13, 0, 'G'),
#   Text(-12, 0, 'C'),
#   Text(-11, 0, 'C'),
#   Text(-10, 0, 'C'),
#   Text(-9, 0, 'C'),
#   Text(-8, 0, 'G'),
#   Text(-7, 0, 'A'),
#   Text(-6, 0, 'G'),
#   Text(-5, 0, 'G'),
#   Text(-4, 0, 'C'),
#   Text(-3, 0, 'G'),
#   Text(-2, 0, 'C'),
#   Text(-1, 0, 'G'),
#   Text(0, 0, 'C'),
#   Text(1, 0, 'G'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'G'),
#   Text(4, 0, 'C'),
#   Text(5, 0, 'G'),
#   Text(6, 0, 'C'),
#   Text(7, 0, 'G'),
#   Text(8, 0, 'C'),
#   Text(9, 0, 'G'),
#   Text(10, 0, 'C'),
#   Text(11, 0, 'G'),
#   Text(12, 0, 'C'),
#   Text(13, 0, 'A'),
#   Text(14, 0, 'C')])

# %%
from matplotlib import pyplot as plt
from dimelo import plot_reads

fig, ax = plt.subplots()

ax = plot_reads.plot_reads(
    extract_file, # extracted_h5,
    regions = t2t_v1_1_cd55_30bps, #'chr1:206582520-206585020',
    motifs = ['CG,0'],
    thresh = 0.75,
    sort_by = ['region_start'], # 'strand'], # 'shuffle',
    # relative = False,
    relative = True,
    window_size = None, # 5000,
    s=5,
)
# plt.xlim(206582520,206585020)


seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
print(seq)
seq_list =  [s for s in seq]
plt.xticks(np.arange(len(seq_list)) - 15, seq_list, size='small')
# Out:
# CCGCCCCGAGGCGCGCGCGCGCGCGCGCAC
# ([<matplotlib.axis.XTick at 0x7f345711ae90>,
#   <matplotlib.axis.XTick at 0x7f345715d550>,
#   <matplotlib.axis.XTick at 0x7f3457156dd0>,
#   <matplotlib.axis.XTick at 0x7f345715cb50>,
#   <matplotlib.axis.XTick at 0x7f34149c4f50>,
#   <matplotlib.axis.XTick at 0x7f341f1b6fd0>,
#   <matplotlib.axis.XTick at 0x7f3457dea350>,
#   <matplotlib.axis.XTick at 0x7f3457de0f10>,
#   <matplotlib.axis.XTick at 0x7f3457c1ac90>,
#   <matplotlib.axis.XTick at 0x7f3457e00550>,
#   <matplotlib.axis.XTick at 0x7f3457e02ed0>,
#   <matplotlib.axis.XTick at 0x7f34573ab850>,
#   <matplotlib.axis.XTick at 0x7f3457de4550>,
#   <matplotlib.axis.XTick at 0x7f3457b12490>,
#   <matplotlib.axis.XTick at 0x7f3457b12c90>,
#   <matplotlib.axis.XTick at 0x7f3457c3df10>,
#   <matplotlib.axis.XTick at 0x7f3457c36a90>,
#   <matplotlib.axis.XTick at 0x7f3457135810>,
#   <matplotlib.axis.XTick at 0x7f3457df6c90>,
#   <matplotlib.axis.XTick at 0x7f3457c69610>,
#   <matplotlib.axis.XTick at 0x7f3457c5d990>,
#   <matplotlib.axis.XTick at 0x7f3457c857d0>,
#   <matplotlib.axis.XTick at 0x7f3457c53690>,
#   <matplotlib.axis.XTick at 0x7f3457951610>,
#   <matplotlib.axis.XTick at 0x7f3457c47490>,
#   <matplotlib.axis.XTick at 0x7f3457cdc990>,
#   <matplotlib.axis.XTick at 0x7f3457c4a210>,
#   <matplotlib.axis.XTick at 0x7f3457b20ed0>,
#   <matplotlib.axis.XTick at 0x7f3457c49dd0>,
#   <matplotlib.axis.XTick at 0x7f3460361750>],
#  [Text(-15, 0, 'C'),
#   Text(-14, 0, 'C'),
#   Text(-13, 0, 'G'),
#   Text(-12, 0, 'C'),
#   Text(-11, 0, 'C'),
#   Text(-10, 0, 'C'),
#   Text(-9, 0, 'C'),
#   Text(-8, 0, 'G'),
#   Text(-7, 0, 'A'),
#   Text(-6, 0, 'G'),
#   Text(-5, 0, 'G'),
#   Text(-4, 0, 'C'),
#   Text(-3, 0, 'G'),
#   Text(-2, 0, 'C'),
#   Text(-1, 0, 'G'),
#   Text(0, 0, 'C'),
#   Text(1, 0, 'G'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'G'),
#   Text(4, 0, 'C'),
#   Text(5, 0, 'G'),
#   Text(6, 0, 'C'),
#   Text(7, 0, 'G'),
#   Text(8, 0, 'C'),
#   Text(9, 0, 'G'),
#   Text(10, 0, 'C'),
#   Text(11, 0, 'G'),
#   Text(12, 0, 'C'),
#   Text(13, 0, 'A'),
#   Text(14, 0, 'C')])

# %%
seq_list
# Out:
# ['C',
#  'C',
#  'G',
#  'C',
#  'C',
#  'C',
#  'C',
#  'G',
#  'A',
#  'G',
#  'G',
#  'C',
#  'G',
#  'C',
#  'G',
#  'C',
#  'G',
#  'C',
#  'G',
#  'C',
#  'G',
#  'C',
#  'G',
#  'C',
#  'G',
#  'C',
#  'G',
#  'C',
#  'A',
#  'C']

# %%
from matplotlib import pyplot as plt
from dimelo import plot_reads

fig, ax = plt.subplots()

ax = plot_reads.plot_reads(
    extract_file, # extracted_h5,
    regions = t2t_v1_1_cd55_30bps, #'chr1:206582520-206585020',
    motifs = ['CG,0'],
    thresh = 0.75,
    sort_by = ['shuffle','strand'],
    # relative = False,
    relative = True,
    window_size = None, # 5000,
    s=5,
)
# plt.xlim(206582520,206585020)


seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
print(seq)
seq_list =  [s for s in seq]
plt.xticks(np.arange(len(seq_list)) - 15, seq_list, size='small')
# Out:
# CCGCCCCGAGGCGCGCGCGCGCGCGCGCAC
# ([<matplotlib.axis.XTick at 0x7f345791ac90>,
#   <matplotlib.axis.XTick at 0x7f3457cc9650>,
#   <matplotlib.axis.XTick at 0x7f3457b9f8d0>,
#   <matplotlib.axis.XTick at 0x7f3457918510>,
#   <matplotlib.axis.XTick at 0x7f3457ba9b10>,
#   <matplotlib.axis.XTick at 0x7f3457ba8050>,
#   <matplotlib.axis.XTick at 0x7f3457bbe2d0>,
#   <matplotlib.axis.XTick at 0x7f3457bc83d0>,
#   <matplotlib.axis.XTick at 0x7f3457be0b50>,
#   <matplotlib.axis.XTick at 0x7f3457bcac90>,
#   <matplotlib.axis.XTick at 0x7f34571968d0>,
#   <matplotlib.axis.XTick at 0x7f34571a8490>,
#   <matplotlib.axis.XTick at 0x7f3457c0f750>,
#   <matplotlib.axis.XTick at 0x7f34571ab710>,
#   <matplotlib.axis.XTick at 0x7f34571919d0>,
#   <matplotlib.axis.XTick at 0x7f3457193b50>,
#   <matplotlib.axis.XTick at 0x7f34571bdb50>,
#   <matplotlib.axis.XTick at 0x7f34571bfc90>,
#   <matplotlib.axis.XTick at 0x7f34571abd10>,
#   <matplotlib.axis.XTick at 0x7f34571ba1d0>,
#   <matplotlib.axis.XTick at 0x7f34571b02d0>,
#   <matplotlib.axis.XTick at 0x7f34571b2310>,
#   <matplotlib.axis.XTick at 0x7f34571ac450>,
#   <matplotlib.axis.XTick at 0x7f3457be1b90>,
#   <matplotlib.axis.XTick at 0x7f34571aecd0>,
#   <matplotlib.axis.XTick at 0x7f3457198d50>,
#   <matplotlib.axis.XTick at 0x7f345719af10>,
#   <matplotlib.axis.XTick at 0x7f345719ad10>,
#   <matplotlib.axis.XTick at 0x7f345786e910>,
#   <matplotlib.axis.XTick at 0x7f34571c4550>],
#  [Text(-15, 0, 'C'),
#   Text(-14, 0, 'C'),
#   Text(-13, 0, 'G'),
#   Text(-12, 0, 'C'),
#   Text(-11, 0, 'C'),
#   Text(-10, 0, 'C'),
#   Text(-9, 0, 'C'),
#   Text(-8, 0, 'G'),
#   Text(-7, 0, 'A'),
#   Text(-6, 0, 'G'),
#   Text(-5, 0, 'G'),
#   Text(-4, 0, 'C'),
#   Text(-3, 0, 'G'),
#   Text(-2, 0, 'C'),
#   Text(-1, 0, 'G'),
#   Text(0, 0, 'C'),
#   Text(1, 0, 'G'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'G'),
#   Text(4, 0, 'C'),
#   Text(5, 0, 'G'),
#   Text(6, 0, 'C'),
#   Text(7, 0, 'G'),
#   Text(8, 0, 'C'),
#   Text(9, 0, 'G'),
#   Text(10, 0, 'C'),
#   Text(11, 0, 'G'),
#   Text(12, 0, 'C'),
#   Text(13, 0, 'A'),
#   Text(14, 0, 'C')])

# %%
from matplotlib import pyplot as plt
from dimelo import plot_reads

fig, ax = plt.subplots()

ax = plot_reads.plot_reads(
    extract_file, # extracted_h5,
    regions = t2t_v1_1_cd55_30bps, #'chr1:206582520-206585020',
    motifs = ['CG,0'],
    thresh = 0.75,
    sort_by = ['region_end','region_start' ], # 'strand'], # 'shuffle',
    # relative = False,
    relative = True,
    window_size = None, # 5000,
    s=5,
)
# plt.xlim(206582520,206585020)


seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
print(seq)
seq_list =  [s for s in seq]
plt.xticks(np.arange(len(seq_list)) - 15, seq_list, size='small')
# Out:
# CCGCCCCGAGGCGCGCGCGCGCGCGCGCAC
# ([<matplotlib.axis.XTick at 0x7f3457b9e1d0>,
#   <matplotlib.axis.XTick at 0x7f3457197f90>,
#   <matplotlib.axis.XTick at 0x7f34571f8650>,
#   <matplotlib.axis.XTick at 0x7f34571d0510>,
#   <matplotlib.axis.XTick at 0x7f345703cdd0>,
#   <matplotlib.axis.XTick at 0x7f345703e410>,
#   <matplotlib.axis.XTick at 0x7f345703f590>,
#   <matplotlib.axis.XTick at 0x7f345703a710>,
#   <matplotlib.axis.XTick at 0x7f345727f090>,
#   <matplotlib.axis.XTick at 0x7f34571faf50>,
#   <matplotlib.axis.XTick at 0x7f3457058490>,
#   <matplotlib.axis.XTick at 0x7f345705ab10>,
#   <matplotlib.axis.XTick at 0x7f3457070dd0>,
#   <matplotlib.axis.XTick at 0x7f3457035e10>,
#   <matplotlib.axis.XTick at 0x7f3457073850>,
#   <matplotlib.axis.XTick at 0x7f3457078490>,
#   <matplotlib.axis.XTick at 0x7f345707ba50>,
#   <matplotlib.axis.XTick at 0x7f3457081bd0>,
#   <matplotlib.axis.XTick at 0x7f3457083dd0>,
#   <matplotlib.axis.XTick at 0x7f3457073f10>,
#   <matplotlib.axis.XTick at 0x7f34570860d0>,
#   <matplotlib.axis.XTick at 0x7f34570882d0>,
#   <matplotlib.axis.XTick at 0x7f3457088490>,
#   <matplotlib.axis.XTick at 0x7f3457098390>,
#   <matplotlib.axis.XTick at 0x7f3457740dd0>,
#   <matplotlib.axis.XTick at 0x7f345709a510>,
#   <matplotlib.axis.XTick at 0x7f34570a0750>,
#   <matplotlib.axis.XTick at 0x7f34570a2610>,
#   <matplotlib.axis.XTick at 0x7f34570a4810>,
#   <matplotlib.axis.XTick at 0x7f34570a6910>],
#  [Text(-15, 0, 'C'),
#   Text(-14, 0, 'C'),
#   Text(-13, 0, 'G'),
#   Text(-12, 0, 'C'),
#   Text(-11, 0, 'C'),
#   Text(-10, 0, 'C'),
#   Text(-9, 0, 'C'),
#   Text(-8, 0, 'G'),
#   Text(-7, 0, 'A'),
#   Text(-6, 0, 'G'),
#   Text(-5, 0, 'G'),
#   Text(-4, 0, 'C'),
#   Text(-3, 0, 'G'),
#   Text(-2, 0, 'C'),
#   Text(-1, 0, 'G'),
#   Text(0, 0, 'C'),
#   Text(1, 0, 'G'),
#   Text(2, 0, 'C'),
#   Text(3, 0, 'G'),
#   Text(4, 0, 'C'),
#   Text(5, 0, 'G'),
#   Text(6, 0, 'C'),
#   Text(7, 0, 'G'),
#   Text(8, 0, 'C'),
#   Text(9, 0, 'G'),
#   Text(10, 0, 'C'),
#   Text(11, 0, 'G'),
#   Text(12, 0, 'C'),
#   Text(13, 0, 'A'),
#   Text(14, 0, 'C')])

# %%
extract_file
# Out:
# PosixPath('dimelo_v2_output/cas9_12ef_101923_beta_extract_30bps_chr1_206586162_206586192_wsNone_thresh190/reads.combined_basemods.h5')

# %% [markdown]
# # Extract structured on target reads

# %%
import numpy as np
import pandas as pd

from pathlib import Path

import seaborn as sns
from matplotlib.axes import Axes
import matplotlib.pyplot as plt

from dimelo import parse_bam, plot_enrichment_profile, plot_reads, load_processed

# %%
t2t_v1_1_cd55_30bps
# Out:
# 'chr1:206586162-206586192'

# %%
from pathlib import Path

import pandas as pd
import seaborn as sns
from matplotlib.axes import Axes
import matplotlib.pyplot as plt

# from . import load_processed
# from . import utils

reads,read_names,mods,regions_dict = load_processed.readwise_binary_modification_arrays(
    extract_file, # extract_file_no_thresh, # raw modification probabilities
    regions=t2t_v1_1_cd55_30bps, # cd55_30bps_interest_coords, # ctcf_target_regions,
    motifs=['CG,0'], # 'A,0'],
    sort_by = ['strand'], # 'shuffle',
    window_size=None,
    thresh = 0.001, # vs.  0.00196,
    relative = True, # False, #

)
      # file = mod_file_name,
      # regions = regions,
      # motifs = motifs,
      # window_size = window_size,
      # thresh = thresh,
      # relative = relative,
      # sort_by = sort_by,
    # )
  # match mod_file_name.suffix:
  #     case _:
  #         reads, read_names, mods = load_processed.reads_from_hdf5(
  #             file=mod_file_name,
#             bed_file=bed_file_name,
  #             mod_names=mod_names,
  #             window_size=window_size,
  #         )

# Convert data frame where each row represents a read to a data frame where each row represents a single modified position in a read
df = pd.DataFrame({
    'read_name': read_names,
    'mod': mods,
    'pos': reads
}).explode('pos')

# %%
df
# Out:
#     read_name   mod  pos
# 0           0  CG,0    4
# 1           7  CG,0    4
# 2           8  CG,0    8
# 3          23  CG,0  -14
# 4          23  CG,0   -9
# 5          28  CG,0    4
# 6          30  CG,0  -14
# 7          33  CG,0    0
# 8          33  CG,0    4
# 9          33  CG,0    6
# 10         40  CG,0  -14
# 11         41  CG,0   -4
# 12         41  CG,0    0
# 13         41  CG,0    2
# 14         49  CG,0  -14
# 15         49  CG,0    8
# 16         50  CG,0    2
# 17         50  CG,0    4
# 18         60  CG,0  -14
# 19         65  CG,0    4
# 20         65  CG,0    6
# 21         73  CG,0  -14
# 22         73  CG,0    4
# 23         74  CG,0    2
# 24         93  CG,0    4
# 25         94  CG,0   10
# 26        120  CG,0    4
# 27        120  CG,0    6
# 28        134  CG,0    6
# 29        137  CG,0   -9
# 30        137  CG,0    2
# 31        137  CG,0    4
# 32        145  CG,0    6
# 33        147  CG,0    4
# 34        157  CG,0  -14
# 35        164  CG,0    2
# 36        179  CG,0   -9
# 37        184  CG,0   10
# 38        186  CG,0    4
# 39        186  CG,0    6
# 40        189  CG,0   -4
# 41        189  CG,0   -2
# 42        189  CG,0    0
# 43        201  CG,0  -14
# 44        203  CG,0    8
# 45        203  CG,0   10
# 46        205  CG,0  -14
# 47        240  CG,0    7
# 48        241  CG,0   -3
# 49        241  CG,0    7
# 50        241  CG,0    9

# %%
# @title read_name vs count()

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  counted = (series['read_name']
                .value_counts()
              .reset_index(name='counts')
              .rename({'index': 'read_name'}, axis=1)
              .sort_values('read_name', ascending=True))
  xs = counted['read_name']
  ys = counted['counts']
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('read_name', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('read_name')
_ = plt.ylabel('count()')

# %%
# @title read_name vs count()

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  counted = (series['read_name']
                .value_counts()
              .reset_index(name='counts')
              .rename({'index': 'read_name'}, axis=1)
              .sort_values('read_name', ascending=True))
  xs = counted['read_name']
  ys = counted['counts']
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)], marker='o' )

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = df.sort_values('read_name', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('read_name')
_ = plt.ylabel('count()')

# %%
# @title read_name

from matplotlib import pyplot as plt
df['read_name'].plot(kind='hist', bins=20, title='read_name')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
len(np.unique(df['read_name']))
# Out:
# 33

# %%
reads,read_names,mods,regions_dict = load_processed.readwise_binary_modification_arrays(
    extract_file, # extract_file_no_thresh, # raw modification probabilities
    regions=t2t_v1_1_cd55_30bps, # cd55_30bps_interest_coords, # ctcf_target_regions,
    motifs=['CG,0'], # 'A,0'],
    relative = False,
    thresh=0.001,
    # window_size = None, # window_size,
)
      # file = mod_file_name,
      # regions = regions,
      # motifs = motifs,
      # window_size = window_size,
      # thresh = thresh,
      # relative = relative,
      # sort_by = sort_by,
  # )
  # match mod_file_name.suffix:
  #     case _:
  #         reads, read_names, mods = load_processed.reads_from_hdf5(
  #             file=mod_file_name,
#             bed_file=bed_file_name,
  #             mod_names=mod_names,
  #             window_size=window_size,
  #         )

# Convert data frame where each row represents a read to a data frame where each row represents a single modified position in a read
df_with_coords = pd.DataFrame({
    'read_name': read_names,
    'mod': mods,
    'pos': reads
}).explode('pos')
     

len(np.unique(df_with_coords.read_name))
     
30

df_with_coords
# Out:
#     read_name   mod        pos
# 0           0  CG,0  206586181
# 1           4  CG,0  206586185
# 2          13  CG,0  206586173
# 3          13  CG,0  206586177
# 4          13  CG,0  206586179
# 5          14  CG,0  206586184
# 6          16  CG,0  206586163
# 7          16  CG,0  206586181
# 8          33  CG,0  206586163
# 9          35  CG,0  206586187
# 10         36  CG,0  206586163
# 11         36  CG,0  206586185
# 12         43  CG,0  206586173
# 13         43  CG,0  206586175
# 14         43  CG,0  206586177
# 15         57  CG,0  206586181
# 16         57  CG,0  206586183
# 17         60  CG,0  206586181
# 18         64  CG,0  206586179
# 19         68  CG,0  206586177
# 20         68  CG,0  206586181
# 21         68  CG,0  206586183
# 22         75  CG,0  206586163
# 23         75  CG,0  206586168
# 24         79  CG,0  206586181
# 25         86  CG,0  206586179
# 26         86  CG,0  206586181
# 27        101  CG,0  206586179
# 28        104  CG,0  206586185
# 29        104  CG,0  206586187
# 30        117  CG,0  206586163
# 31        118  CG,0  206586163
# 32        119  CG,0  206586181
# 33        141  CG,0  206586174
# 34        141  CG,0  206586184
# 35        141  CG,0  206586186
# 36        142  CG,0  206586163
# 37        152  CG,0  206586163
# 38        160  CG,0  206586181
# 39        160  CG,0  206586183
# 40        167  CG,0  206586168
# 41        179  CG,0  206586163
# 42        184  CG,0  206586181
# 43        184  CG,0  206586183
# 44        190  CG,0  206586183
# 45        196  CG,0  206586183
# 46        213  CG,0  206586181
# 47        217  CG,0  206586187
# 48        246  CG,0  206586168
# 49        246  CG,0  206586179
# 50        246  CG,0  206586181

# %%
df_with_coords.shape
# Out:
# (51, 3)

# %%
# @title read_name vs pos

from matplotlib import pyplot as plt
df_with_coords.plot(kind='scatter', x='read_name', y='pos', s=32, alpha=.8)
df_with_coords.plot(kind='scatter', x='read_name', y='pos', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# # Pile up reads

# %%
# pileup_file, pileup_regions = parse_bam.pileup(
#     input_file=ctcf_bam_file_updated,
#     output_name='ctcf_demo_pileup_on_target',
#     ref_genome=ref_genome_file,
#     output_directory=output_dir,
#     regions=[ctcf_target_regions,ctcf_off_target_regions],
#     motifs=['A,0','CG,0'],
#     # parsing can optionally specify mod codes. 
#     # The default is Y or a for adenine and m or Z for cytosine, corresponding to methylation
#     # motifs = ['A,0,Y','CG,0,Z'], 
#     thresh=190,
#     window_size=1000,
#     # cores = 1, # uncomment this line if your process appears to be terminating early (reduces memory usage)
#     # quiet = True,
#     # cleanup = False,
#     # log=True,
# )

# %%
bam_path
# Out:
# '/home/michalula/data/cas9_nanopore/data/2024927_Cas9_R9_promethion_K562/to_t2t_v1_1/sort_aligned_T2Tv1_1_trim_bam_pass_merged.updated.bam'

# %%
output_dir
# Out:
# PosixPath('dimelo_v2_output')

# %%
pileup_file, pileup_regions = parse_bam.pileup(
    input_file=bam_path, # ctcf_bam_file_updated,
    output_name= "pileup_extract_K562_P2_30bps_chr1_206586162_206586192_wsNone_thresh190", # 'ctcf_demo_pileup_on_target',
    ref_genome=ref_genome_v1_1_file, #ref_genome_file,
    output_directory=output_dir,
    regions=t2t_v1_1_cd55_30bps, #[ctcf_target_regions,ctcf_off_target_regions],
    motifs=['CG,0'], # ['A,0','CG,0'],
    # parsing can optionally specify mod codes. 
    # The default is Y or a for adenine and m or Z for cytosine, corresponding to methylation
    # motifs = ['A,0,Y','CG,0,Z'], 
    thresh=190,
    window_size=None,
    # window_size=4000,
    # cores = 1, # uncomment this line if your process appears to be terminating early (reduces memory usage)
    # quiet = True,
    # cleanup = False,
    # log=True,
)
# Out:
# No specified number of cores requested. 24 available on machine, allocating all.
# Modification threshold of 190 assumed to be for range 0-255. 190/255=0.7450980392156863 will be sent to modkit.
#           | Step 1: Identify motif locations in chm13.draft_v1.1.fasta   0% | 00:00
#           | Step 2: Parse regions in sort_aligned_T2Tv1_1_trim_bam_pass_merged.updated.bam   0% | 00:00<?
#           |    0%

# %%
pileup_file, pileup_regions = parse_bam.pileup(
    input_file=bam_path, # ctcf_bam_file_updated,
    output_name= "pileup_extract_K562_P2_ws4000_around_chr1_206586162_206586192_thresh190", # 'ctcf_demo_pileup_on_target',
    ref_genome=ref_genome_v1_1_file, #ref_genome_file,
    output_directory=output_dir,
    regions=t2t_v1_1_cd55_30bps, #[ctcf_target_regions,ctcf_off_target_regions],
    motifs=['CG,0'], # ['A,0','CG,0'],
    # parsing can optionally specify mod codes. 
    # The default is Y or a for adenine and m or Z for cytosine, corresponding to methylation
    # motifs = ['A,0,Y','CG,0,Z'], 
    thresh=190,
    # window_size=None,
    window_size=4000,
    # cores = 1, # uncomment this line if your process appears to be terminating early (reduces memory usage)
    # quiet = True,
    # cleanup = False,
    # log=True,
)
# Out:
# No specified number of cores requested. 24 available on machine, allocating all.
# Modification threshold of 190 assumed to be for range 0-255. 190/255=0.7450980392156863 will be sent to modkit.
#           | Step 1: Identify motif locations in chm13.draft_v1.1.fasta   0% | 00:00
#           | Step 2: Parse regions in sort_aligned_T2Tv1_1_trim_bam_pass_merged.updated.bam   0% | 00:00<?
#           |    0%

# %%
# # using domelo modkit_parsing_main :
# t2t_v1_1_cd55_30bps = 'chr1:206586162-206586192'
# # t2t_v1_1_cd55_30bps = 'chr1:206586162-206586192'

# # using domelo modkit_parsing_main:
# pileup_file = parse_bam.pileup(
#     input_file=bam_path, #ctcf_bam_file,
#     output_name='pileup_extract_K562_P2_30bps_chr1_206586162_206586192_wsNone_thresh190', #'ctcf_demo_pileup',
#     ref_genome=ref_genome_v1_1_file, # ref_genome_file,
#     output_directory=output_dir,
#     region_str=t2t_v1_1_cd55_30bps, # bed_files= [ctcf_target_regions],
#     basemods=['CG,0'],
#     thresh=190,
#     window_size=None,
#     # window_size=1000,
#     # cores=None,
#     # cleanup=False
# )

# %%
plt.figure(figsize=(4, 2)) # If you want a different sized plot, you can us matplotlib commands
plot_enrichment_profile.by_modification(
    mod_file_name=pileup_file,
    regions=t2t_v1_1_cd55_30bps, #ctcf_target_regions,
    window_size=None, #1000,
    motifs=['CG,0'], # ['A,0','CG,0'],
    single_strand=False, # if set to True, regions that specify the strand will only pull from reads on the strand (as opposed to both strands)
    regions_5to3prime=False, # if set to True, regions on the reverse (-) strand will be flipped so everything is 5 prime to 3 prime
    smooth_window=50,
    palette = { # you can pass down kwargs to sns barplot if you want to
        # 'A,0':'blue',
        'CG,0':'orange'
    }
)
# Out:
# <Axes: xlabel='pos', ylabel='fraction modified bases'>

# %%
fig, ax = plt.subplots()

mod_counts_vector,val_counts_vector = load_processed.pileup_vectors_from_bedmethyl(
        bedmethyl_file = pileup_file, # file,
        motif = 'CG,0',
        regions = t2t_v1_1_cd55_30bps, # region,
        window_size = None
    )
pileup_frac = mod_counts_vector / val_counts_vector
ax.plot(pileup_frac,'*',label=Path(pileup_file).name)

plt.title(f'Region-of-interest near CD55 between bisulfite data and nanopore cas9 data\nT2T:{t2t_v1_1_cd55_30bps}, hg38:{"hg38_cd55"}')
plt.xlabel('relative genomic coordinate')
# plt.legend()
plt.subplots_adjust(bottom=0.5)  # Adjust the bottom
# Placing the legend at the bottom outside of the figure
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), shadow=True, ncol=2)

seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
print(seq)
seq_list =  [s for s in seq]
plt.xticks(range(len(seq_list)), seq_list, size='small')
# Out:
# CCGCCCCGAGGCGCGCGCGCGCGCGCGCAC
# /tmp/ipykernel_1388423/2540628470.py:9: RuntimeWarning: invalid value encountered in divide
#   pileup_frac = mod_counts_vector / val_counts_vector
# ([<matplotlib.axis.XTick at 0x7f3456e9f150>,
#   <matplotlib.axis.XTick at 0x7f344bd95750>,
#   <matplotlib.axis.XTick at 0x7f3456e53310>,
#   <matplotlib.axis.XTick at 0x7f3456d2a150>,
#   <matplotlib.axis.XTick at 0x7f3456d2bcd0>,
#   <matplotlib.axis.XTick at 0x7f3456d3de90>,
#   <matplotlib.axis.XTick at 0x7f3456d480d0>,
#   <matplotlib.axis.XTick at 0x7f3456d4a150>,
#   <matplotlib.axis.XTick at 0x7f3456d50390>,
#   <matplotlib.axis.XTick at 0x7f3456d52350>,
#   <matplotlib.axis.XTick at 0x7f3456d50d90>,
#   <matplotlib.axis.XTick at 0x7f3456d58490>,
#   <matplotlib.axis.XTick at 0x7f3456d5ab50>,
#   <matplotlib.axis.XTick at 0x7f3456d5ccd0>,
#   <matplotlib.axis.XTick at 0x7f3456d5ed90>,
#   <matplotlib.axis.XTick at 0x7f3456d5d6d0>,
#   <matplotlib.axis.XTick at 0x7f3456d61110>,
#   <matplotlib.axis.XTick at 0x7f3456d630d0>,
#   <matplotlib.axis.XTick at 0x7f3456d71090>,
#   <matplotlib.axis.XTick at 0x7f3456d73050>,
#   <matplotlib.axis.XTick at 0x7f3456d79090>,
#   <matplotlib.axis.XTick at 0x7f3456d603d0>,
#   <matplotlib.axis.XTick at 0x7f3456d7b490>,
#   <matplotlib.axis.XTick at 0x7f3456d81590>,
#   <matplotlib.axis.XTick at 0x7f3456d83590>,
#   <matplotlib.axis.XTick at 0x7f3456d850d0>,
#   <matplotlib.axis.XTick at 0x7f3456d87650>,
#   <matplotlib.axis.XTick at 0x7f3456d86e90>,
#   <matplotlib.axis.XTick at 0x7f3456d89910>,
#   <matplotlib.axis.XTick at 0x7f3456d8b950>],
#  [Text(0, 0, 'C'),
#   Text(1, 0, 'C'),
#   Text(2, 0, 'G'),
#   Text(3, 0, 'C'),
#   Text(4, 0, 'C'),
#   Text(5, 0, 'C'),
#   Text(6, 0, 'C'),
#   Text(7, 0, 'G'),
#   Text(8, 0, 'A'),
#   Text(9, 0, 'G'),
#   Text(10, 0, 'G'),
#   Text(11, 0, 'C'),
#   Text(12, 0, 'G'),
#   Text(13, 0, 'C'),
#   Text(14, 0, 'G'),
#   Text(15, 0, 'C'),
#   Text(16, 0, 'G'),
#   Text(17, 0, 'C'),
#   Text(18, 0, 'G'),
#   Text(19, 0, 'C'),
#   Text(20, 0, 'G'),
#   Text(21, 0, 'C'),
#   Text(22, 0, 'G'),
#   Text(23, 0, 'C'),
#   Text(24, 0, 'G'),
#   Text(25, 0, 'C'),
#   Text(26, 0, 'G'),
#   Text(27, 0, 'C'),
#   Text(28, 0, 'A'),
#   Text(29, 0, 'C')])

# %%
pileup_frac
# Out:
# array([       nan, 0.04639175, 0.        ,        nan,        nan,
#               nan, 0.02380952, 0.        ,        nan,        nan,
#               nan, 0.01298701, 0.03571429, 0.00617284, 0.        ,
#        0.01554404, 0.        , 0.0255102 , 0.        , 0.06060606,
#        0.        , 0.03409091, 0.04651163, 0.02941176, 0.03225806,
#        0.04761905, 0.        ,        nan,        nan,        nan])

# %%
# from matplotlib import pyplot as plt
# t2t_cd55 = 'chr1:206586162-206586192'
# # hg38_cd55 = 'chr1:207320867-207320897'

# # caspileup = '/Users/oberondixon-luinenburg/Documents/Ioannidis-Streets/dimelo_test_data/cd55_cas9/cd55_tss/pileup.sorted.bed.gz'
# # caspileup = '/content/drive/MyDrive/Michal Rozenwald/data/CD55/cas9_12ef_101923_misha/dimelo_new_package/cd55_tss_pileup_ws4000/pileup.sorted.bed.gz' # pileup
# # T_bedgz = Path('/content/drive/MyDrive/Michal Rozenwald/data/ENCODE/T_primary_ENCSR663MXB/ENCFF355UVU.m.sorted.bed.gz') #'/Users/oberondixon-luinenburg/Downloads/ENCFF279HCL.m.sorted.bed.gz')
# K562_bedgz = Path('/content/drive/MyDrive/Michal Rozenwald/data/ENCODE/T_primary_ENCSR663MXB/ENCFF355UVU.m.sorted.bed.gz') #'/Users/oberondixon-luinenburg/Downloads/ENCFF279HCL.m.sorted.bed.gz')

from dimelo import plot_enrichment_profile
from dimelo import load_processed
import pysam

fig, ax = plt.subplots()

for file,region in zip([caspileup,T_bedgz],
                       [t2t_cd55,hg38_cd55]):
    mod_counts_vector,val_counts_vector = load_processed.pileup_vectors_from_bedmethyl(
        bedmethyl_file = file,
        motif = 'CG,0',
        regions = region,
        window_size = None
    )
    pileup_frac = mod_counts_vector / val_counts_vector
    ax.plot(pileup_frac,'*',label=Path(file).name)

plt.title(f'Region-of-interest near CD55 between bisulfite data and nanopore cas9 data\nT2T:{t2t_cd55}, hg38:{hg38_cd55}')
plt.xlabel('relative genomic coordinate')
# plt.legend()
plt.subplots_adjust(bottom=0.5)  # Adjust the bottom
# Placing the legend at the bottom outside of the figure
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), shadow=True, ncol=2)

seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
print(seq)
seq_list =  [s for s in seq]
plt.xticks(range(len(seq_list)), seq_list, size='small')

# %%
# from matplotlib import pyplot as plt
# t2t_cd55 = 'chr1:206586162-206586192'
# # hg38_cd55 = 'chr1:207320867-207320897'

# # caspileup = '/Users/oberondixon-luinenburg/Documents/Ioannidis-Streets/dimelo_test_data/cd55_cas9/cd55_tss/pileup.sorted.bed.gz'
# # caspileup = '/content/drive/MyDrive/Michal Rozenwald/data/CD55/cas9_12ef_101923_misha/dimelo_new_package/cd55_tss_pileup_ws4000/pileup.sorted.bed.gz' # pileup
# # T_bedgz = Path('/content/drive/MyDrive/Michal Rozenwald/data/ENCODE/T_primary_ENCSR663MXB/ENCFF355UVU.m.sorted.bed.gz') #'/Users/oberondixon-luinenburg/Downloads/ENCFF279HCL.m.sorted.bed.gz')
# K562_bedgz = Path('/content/drive/MyDrive/Michal Rozenwald/data/ENCODE/T_primary_ENCSR663MXB/ENCFF355UVU.m.sorted.bed.gz') #'/Users/oberondixon-luinenburg/Downloads/ENCFF279HCL.m.sorted.bed.gz')

# from dimelo import plot_enrichment_profile
# from dimelo import load_processed
# import pysam

# fig, ax = plt.subplots()

# for file,region in zip([caspileup,T_bedgz],[t2t_cd55,hg38_cd55]):
#     mod_counts_vector,val_counts_vector = load_processed.pileup_vectors_from_bedmethyl(
#         bedmethyl_file = file,
#         motif = 'CG,0',
#         regions = region,
#         window_size = None
#     )
#     pileup_frac = mod_counts_vector / val_counts_vector
#     ax.plot(pileup_frac,'*',label=Path(file).name)

# plt.title(f'Region-of-interest near CD55 between bisulfite data and nanopore cas9 data\nT2T:{t2t_cd55}, hg38:{hg38_cd55}')
# plt.xlabel('relative genomic coordinate')
# # plt.legend()
# plt.subplots_adjust(bottom=0.5)  # Adjust the bottom
# # Placing the legend at the bottom outside of the figure
# plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), shadow=True, ncol=2)

# seq = pysam.FastaFile(ref_genome_v1_1_file).fetch('chr1',206586162,206586192)
# print(seq)
# seq_list =  [s for s in seq]
# plt.xticks(range(len(seq_list)), seq_list, size='small')
