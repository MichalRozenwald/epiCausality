# %% [markdown]
# # Modkit dmr
# ## Use my Filtered Reads

# %% [markdown]
# Based on:
# https://nanoporetech.github.io/modkit/intro_dmr.html#perform-differential-methylation-scoring

# %% [markdown]
# Select kernal: dimelo_v2_modkit_parsing

# %% [markdown]
# Preparing the input data
# The inputs to all modkit dmr commands are two or more bedMethyl files (created by modkit pileup) that have been compressed with bgzip and indexed with tabix. An example of how to generate the input data is shown below:
#
#
# ref=grch38.fasta
# threads=32
#
# norm=normal_sample.bam
# norm_pileup=normal_pileup.bed
#
# modkit pileup ${norm} ${norm_pileup} \
#   --cpg \
#   --ref ${ref} \
#   --threads ${threads} \
#   --log-filepath log.txt
#
# bgzip -k ${norm_pileup}
# tabix -p bed ${norm_pileup}.gz
#
# # pileup and compression can also be done in one step
# tumor=tumor_sample.bam
# tumor_pileup=tumor_pileup.bed.gz
#
# modkit pileup ${tumor} - \
#   --cpg \
#   --ref ${ref} \
#   --threads ${threads} \
#   --log-filepath log.txt | ${bgzip} -c > ${tumor_pileup}
#
# tabix -p bed ${tumor_pileup}

# %%
from datetime import datetime

def current_time():
    """Returns the current date and time as a formatted string."""
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S") 

if __name__ == "__main__":
    print("Current Date and Time:", current_time())
# Out:
# Current Date and Time: 2025-11-09 15:10:53

# %%
# %%bash
# echo "hello"
# Out:
# hello

# %%
! ls /home/michalula/data/ref_genomes/t2t_v2_0/
# Out:
# chm13v2.0.fa	  chm13v2.0.fa.fai		   haplotype_vcf
# chm13v2.0.fa.amb  chm13v2.0.fa.pac		   up_chm13v2.0.fasta
# chm13v2.0.fa.ann  chm13v2.0.fa.sa		   up_chm13v2.0.fasta.fai
# chm13v2.0.fa.bwt  convert_to_uppercase_fasta.bash

# %%
! ls /home/michalula/data/cas9_nanopore/data/20250908_nCATs_T_CRoff_Day_35/5mCG/to_t2t_v2_0
# Out:
# align_t2t_v2_0_trim_20250908_Day35_CROFF_Tcells_2Libraries_Minion_R9.dna_r9.4.1_e8_sup@v3.3.5mCG.bam
# sort_align_t2t_v2_0_trim_20250908_Day35_CROFF_Tcells_2Libraries_Minion_R9.dna_r9.4.1_e8_sup@v3.3.5mCG.bam
# sort_align_t2t_v2_0_trim_20250908_Day35_CROFF_Tcells_2Libraries_Minion_R9.dna_r9.4.1_e8_sup@v3.3.5mCG.bam.bai
# summary_sort_align_t2t_v2_0_trim_20250908_Day35_CROFF_Tcells_2Libraries_Minion_R9.dna_r9.4.1_e8_sup@v3.3.5mCG.tsv

# %%
# %%bash
#
# ref_genome_fa="/home/michalula/data/ref_genomes/t2t_v2_0/chm13v2.0.fa"
# # ref= "/home/michalula/data/ref_genomes/to_t2t_v1_1/chm13.draft_v1.1.fasta"
#
# threads=32
#
# date_today="20251109"
# # data_folder_path="/home/michalula/data/cas9_nanopore/data/20250908_nCATs_T_CRoff_Day_35/5mCG/to_t2t_v2_0/"
# # CROFF_day35_bam=${data_folder_path}"sort_align_t2t_v2_0_trim_20250908_Day35_CROFF_Tcells_2Libraries_Minion_R9.dna_r9.4.1_e8_sup@v3.3.5mCG.bam"
#
# data_folder_path="/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/croff/analyze_single_reads/dimelo_v2_output/"
# pileup_data_folder_path=${data_folder_path}"pileup/"
# mkdir ${pileup_data_folder_path}
#
# filtered_CROFF_day35_bam=${data_folder_path}"filtered_reads_overlap_MORE_than_0.9_Tcells_CRISPRoff_Day35_postEP_R9minion_threshold_mC0.995_T2Tv2_0_filterMode10_NoFullyUnmeth_ovrlap0.9_mismat0.7_mapQ60.bam"
# pileup_CROFF_day35_bam=${pileup_data_folder_path}${date_today}"_filtered""_pileup_CROFF_Day35_Tcells.bam"
# # "/home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_CROFF_Day28/mergered_outputs/pileup_sort_merge_sort_align_t2t_v1_1_trim_20250721_nCATs_Tcells_CROFF_Day28_minion_run2_day8.dna_r9.4.1_e8_sup@v3.3.5mCG.bam"
# # norm=normal_sample.bam
# # norm_pileup=normal_pileup.bed
#
# modkit pileup ${filtered_CROFF_day35_bam} ${pileup_CROFF_day35_bam} \
#   --cpg \
#   --ref ${ref_genome_fa} \
#   --threads ${threads} \
#   --log-filepath log.txt
#
# bgzip -k ${pileup_CROFF_day35_bam}
# tabix -p bed ${pileup_CROFF_day35_bam}.gz
#
# printf '%s\n' "filtered_CROFF_day35_bam: $filtered_CROFF_day35_bam"
# printf '%s\n' "pileup_CROFF_day35_bam: $pileup_CROFF_day35_bam"
# cat "$pileup_CROFF_day35_bam"
# Out:
# mkdir: cannot create directory ‘/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/croff/analyze_single_reads/dimelo_v2_output/pileup/’: File exists
# > calculated chunk size: 48, interval size 100000, processing 4800000 positions concurrently
# > filtering to only CpG motifs
# > attempting to sample 10042 reads
# > Using filter threshold 0.7246094 for C.
# > Done, processed 328 rows. Processed ~326 reads and skipped zero reads.

# %%
# %%bash

# ref_genome_fa="/home/michalula/data/ref_genomes/t2t_v2_0/chm13v2.0.fa"
# # ref= "/home/michalula/data/ref_genomes/to_t2t_v1_1/chm13.draft_v1.1.fasta"

# threads=32

# date_today="20251109"
# # data_folder_path="/home/michalula/data/cas9_nanopore/data/20250908_nCATs_T_CRoff_Day_35/5mCG/to_t2t_v2_0/"
# # CROFF_day35_bam=${data_folder_path}"sort_align_t2t_v2_0_trim_20250908_Day35_CROFF_Tcells_2Libraries_Minion_R9.dna_r9.4.1_e8_sup@v3.3.5mCG.bam"

# data_folder_path="/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/croff/analyze_single_reads/dimelo_v2_output/"
# pileup_data_folder_path=${data_folder_path}"pileup/"

# filtered_CROFF_day35_bam=${data_folder_path}"filtered_reads_overlap_MORE_than_0.9_Tcells_CRISPRoff_Day35_postEP_R9minion_threshold_mC0.995_T2Tv2_0_filterMode10_NoFullyUnmeth_ovrlap0.9_mismat0.7_mapQ60.bam"
# pileup_CROFF_day35_bam=${pileup_data_folder_path}${date_today}"_filtered""_pileup_CROFF_Day35_Tcells.bam"

# printf '%s\n' "filtered_CROFF_day35_bam: $filtered_CROFF_day35_bam"
# printf '%s\n' "pileup_CROFF_day35_bam: $pileup_CROFF_day35_bam"
# cat "$pileup_CROFF_day35_bam"
# Out:
# filtered_CROFF_day35_bam: /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/croff/analyze_single_reads/dimelo_v2_output/filtered_reads_overlap_MORE_than_0.9_Tcells_CRISPRoff_Day35_postEP_R9minion_threshold_mC0.995_T2Tv2_0_filterMode10_NoFullyUnmeth_ovrlap0.9_mismat0.7_mapQ60.bam
# pileup_CROFF_day35_bam: /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/croff
home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/unedited/merged_2libraries/dimelo_v2_output/filtered_reads_overlap_MORE_than_0.9_Tcells_NT_Day35_postEP_R9minion_threshold_mC0.995_T2Tv2_0_filterMode10_NoFullyUnmeth_ovrlap0.9_mismat0.7_mapQ60.bam"
# Out:
# /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/unedited/merged_2libraries/dimelo_v2_output/filtered_reads_overlap_MORE_than_0.9_Tcells_NT_Day35_postEP_R9minion_threshold_mC0.995_T2Tv2_0_filterMode10_NoFullyUnmeth_ovrlap0.9_mismat0.7_mapQ60.bam

# %%
# %%bash
#
# date_today="20251109"
# data_folder_path="/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/unedited/merged_2libraries/dimelo_v2_output/"
# pileup_data_folder_path=${data_folder_path}"pileup/"
# mkdir ${pileup_data_folder_path}
#
# # pileup_dir_path="/home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_UNEDITED_Day28/merged_outputs/5mCG/to_t2t_v2_0/pileup"
# # mkdir ${pileup_dir_path}
#
# filtered_Unedit_day35_bam=${data_folder_path}"filtered_reads_overlap_MORE_than_0.9_Tcells_NT_Day35_postEP_R9minion_threshold_mC0.995_T2Tv2_0_filterMode10_NoFullyUnmeth_ovrlap0.9_mismat0.7_mapQ60.bam"
# # "/home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_UNEDITED_Day28/merged_outputs/5mCG/to_t2t_v2_0/sort_align_t2t_v2_0_trim_20250721_nCATs_Tcells_UNEDITED_Day28_minion_merged_flowcells_output.dna_r9.4.1_e8_sup@v3.3.5mCG.bam"
# # pileup_Unedit_day28_bam="/home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_UNEDITED_Day28/merged_outputs/pileup_sorted_align_t2t_v1_1_trim_20250721_nCATs_Tcells_UNEDITED_Day28_minion_merged.dna_r9.4.1_e8_sup@v3.3.5mCG.bam"
# # pileup_Unedit_day28_bam=${pileup_dir_path}"/pileup_Unedit_Day28_Tcells_20250721.bam"
# # pileup_Unedit_day35_bam="/home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_UNEDITED_Day28/merged_outputs/5mCG/to_t2t_v2_0/pileup/pileup_Unedit_Day28_Tcells_20250721.bam"
# pileup_Unedit_day35_bam=${pileup_data_folder_path}${date_today}"_filtered""_pileup_NT_Day35_Tcells.bam"
# cat "$pileup_Unedit_day35_bam"
#
# ref_genome_fa="/home/michalula/data/ref_genomes/t2t_v2_0/chm13v2.0.fa"
# # ref="/home/michalula/data/ref_genomes/to_t2t_v1_1/chm13.draft_v1.1.fasta"
#
# threads=32
#
# modkit pileup ${filtered_Unedit_day35_bam} ${pileup_Unedit_day35_bam} \
#   --cpg \
#   --ref ${ref_genome_fa} \
#   --threads ${threads} \
#   --log-filepath log.txt
#
# bgzip -k ${pileup_Unedit_day35_bam}
# tabix -p bed ${pileup_Unedit_day35_bam}.gz
#
# printf '%s\n' "filtered_Unedit_day35_bam: $filtered_Unedit_day35_bam"
# printf '%s\n' "pileup_Unedit_day35_bam: $pileup_Unedit_day35_bam"
# cat "$pileup_Unedit_day35_bam"
# Out:
# mkdir: cannot create directory ‘/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/unedited/merged_2libraries/dimelo_v2_output/pileup/’: File exists
# > calculated chunk size: 48, interval size 100000, processing 4800000 positions concurrently
# > filtering to only CpG motifs
# > attempting to sample 10042 reads
# > Using filter threshold 0.8636719 for C.
# > Done, processed 285 rows. Processed ~201 reads and skipped zero reads.

# %% [markdown]
# 3. Detecting differential modification at single base positions
# The modkit dmr pair command has the ability to score individual bases (e.g. differentially methylated CpGs). To run single-base analysis on one or more paired samples, simply omit the --regions (-r) option when running modkit dmr pair. When performing single-base analysis the likelihood ratio score and a MAP-based p-value are available. For details on the likelihood ratio score and the MAP-based p-value, see the scoring details section. For example the above command becomes:
#
# dmr_result=single_base_haplotype_dmr.bed
#
# modkit dmr pair \
#   -a ${hp1_pileup}.gz \
#   -b ${hp2_pileup}.gz \
#   -o ${dmr_result} \
#   --ref ${ref} \
#   --base C \
#   --threads ${threads} \
#   --log-filepath dmr.log

# %%
# ! ls "/home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_UNEDITED_Day28/merged_outputs/5mCG"

# %%
# ! ls /home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_UNEDITED_Day28/merged_outputs/5mCG/pileup_sorted_align_t2t_v1_1_trim_20250721_nCATs_Tcells_UNEDITED_Day28_minion_merged.dna_r9.4.1_e8_sup@v3.3.5mCG.bam.gz

# %%
# /home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_UNEDITED_Day28/merged_outputs/pileup_sorted_align_t2t_v1_1_trim_20250721_nCATs_Tcells_UNEDITED_Day28_minion_merged.dna_r9.4.1_e8_sup.5mCG.bam.gz

# %%
# %%bash
# ls -ld /home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_UNEDITED_Day28/merged_outputs
# ls -l /home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_UNEDITED_Day28/merged_outputs/pileup_sorted_align_t2t_v1_1_trim_20250721_nCATs_Tcells_UNEDITED_Day28_minion_merged.dna_r9.4.1_e8_sup.5mCG.bam.gz

# %%
# %%bash
#
# pileup_data_folder_path="/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/unedited/merged_2libraries/dimelo_v2_output/pileup/"
# pileup_Unedit_day35_bam=${pileup_data_folder_path}"20251109_filtered_pileup_NT_Day35_Tcells.bam"
# # "/home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_UNEDITED_Day28/merged_outputs/5mCG/to_t2t_v2_0/pileup/pileup_Unedit_Day28_Tcells_20250721.bam"
#
# echo "pileup_Unedit_day35_bam: ${pileup_Unedit_day35_bam}.gz"
#
# ls "${pileup_data_folder_path}"
# ls -ld "${pileup_data_folder_path}"
# ls -ld "${pileup_Unedit_day35_bam}.gz"
# # ls -l "${pileup_Unedit_day28_bam}.gz"
#
# chmod u+rwx "${pileup_data_folder_path}"
# chmod u+rwx "${pileup_Unedit_day35_bam}.gz"
#
# # ls "${pileup_data_folder_path}"
# ls -ld "${pileup_data_folder_path}"
# ls -ld "${pileup_Unedit_day35_bam}.gz"
# Out:
# pileup_Unedit_day35_bam: /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/unedited/merged_2libraries/dimelo_v2_output/pileup/20251109_filtered_pileup_NT_Day35_Tcells.bam.gz
# 20251109_filtered_pileup_NT_Day35_Tcells.bam
# 20251109_filtered_pileup_NT_Day35_Tcells.bam.gz
# 20251109_filtered_pileup_NT_Day35_Tcells.bam.gz.tbi
# drwxrwxr-x 2 michalula michalula 4096 Nov  9 15:55 /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/unedited/merged_2libraries/dimelo_v2_output/pileup/
# -rwxrw-r-- 1 michalula michalula 5591 Nov  9 15:55 /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/unedited/merged_2libraries/dimelo_v2_output/pileup/20251109_filtered_pileup_NT_Day35_Tcells.bam.gz
# drwxrwxr-x 2 michalula michalula 4096 Nov  9 15:55 /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/unedited/merged_2libraries/dimelo_v2_output/pileup/
# -rwxrw-r-- 1 michalula michalula 5591 Nov  9 15:55 /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/unedited/merged_2libraries/dimelo_v2_output/pileup/20251109_filtered_pileup_NT_Day35_Tcells.bam.gz

# %%
# %%bash
#
# # pileup_data_folder_path="/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/unedited/merged_2libraries/dimelo_v2_output/pileup/"
# # pileup_Unedit_day35_bam=${pileup_data_folder_path}"20251109_filtered_pileup_NT_Day35_Tcells.bam"
# # # "/home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_UNEDITED_Day28/merged_outputs/5mCG/to_t2t_v2_0/pileup/pileup_Unedit_Day28_Tcells_20250721.bam"
# pileup_data_folder_path="/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/croff/analyze_single_reads/dimelo_v2_output/pileup/"
# pileup_CROFF_day35_bam=${pileup_data_folder_path}"20251109_filtered_pileup_CROFF_Day35_Tcells.bam"
#
# echo "pileup_CROFF_day35_bam: ${pileup_CROFF_day35_bam}.gz"
#
# ls "${pileup_data_folder_path}"
# ls -ld "${pileup_data_folder_path}"
# ls -ld "${pileup_CROFF_day35_bam}.gz"
# # ls -l "${pileup_Unedit_day28_bam}.gz"
#
# chmod u+rwx "${pileup_data_folder_path}"
# chmod u+rwx "${pileup_CROFF_day35_bam}.gz"
#
#
# # ls "${pileup_data_folder_path}"
# ls -ld "${pileup_data_folder_path}"
# ls -ld "${pileup_CROFF_day35_bam}.gz"
# Out:
# pileup_CROFF_day35_bam: /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/croff/analyze_single_reads/dimelo_v2_output/pileup/20251109_filtered_pileup_CROFF_Day35_Tcells.bam.gz
# 20251109_filtered_pileup_CROFF_Day35_Tcells.bam
# 20251109_filtered_pileup_CROFF_Day35_Tcells.bam.gz
# 20251109_filtered_pileup_CROFF_Day35_Tcells.bam.gz.tbi
# drwxrwxr-x 2 michalula michalula 4096 Nov  9 15:50 /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/croff/analyze_single_reads/dimelo_v2_output/pileup/
# -rwxrw-r-- 1 michalula michalula 7120 Nov  9 15:50 /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/croff/analyze_single_reads/dimelo_v2_output/pileup/20251109_filtered_pileup_CROFF_Day35_Tcells.bam.gz
# drwxrwxr-x 2 michalula michalula 4096 Nov  9 15:50 /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/croff/analyze_single_reads/dimelo_v2_output/pileup/
# -rwxrw-r-- 1 michalula michalula 7120 Nov  9 15:50 /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/croff/analyze_single_reads/dimelo_v2_output/pileup/20251109_filtered_pileup_CROFF_Day35_Tcells.bam.gz

# %%
# %%bash

#    chmod u+rwx "/home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_UNEDITED_Day28/merged_outputs/5mCG/to_t2t_v2_0/pileup/"
#    chmod u+rwx "/home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_CROFF_Day28/mergered_outputs/5mCG/to_t2t_v2_0/pileup_CROFF_Day28_Tcells_20250721.bam.gz"

# %%
# %%bash

# ls -ld /home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_UNEDITED_Day28/merged_outputs
# ls -ld "/home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_CROFF_Day28/mergered_outputs/5mCG/to_t2t_v2_0/pileup_CROFF_Day28_Tcells_20250721.bam.gz"
# Out:
# drwxrwxr-x 4 michalula michalula 4096 Aug  1 01:35 /home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_UNEDITED_Day28/merged_outputs
# -rwxrw-r-- 1 michalula michalula 5354303 Sep 24 12:10 /home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_CROFF_Day28/mergered_outputs/5mCG/to_t2t_v2_0/pileup_CROFF_Day28_Tcells_20250721.bam.gz

# %%
# ls /home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_UNEDITED_Day28/merged_outputs/pileup_sorted_align_t2t_v1_1_trim_20250721_nCATs_Tcells_UNEDITED_Day28_minion_merged.dna_r9.4.1_e8_sup.5mCG.bam.gz

# %%
 # %%bash
 
 # 3. Detecting differential modification at single base positions
# The modkit dmr pair command has the ability to score individual bases (e.g. differentially methylated CpGs). To run single-base analysis on one or more paired samples, simply omit the --regions (-r) option when running modkit dmr pair. When performing single-base analysis the likelihood ratio score and a MAP-based p-value are available. For details on the likelihood ratio score and the MAP-based p-value, see the scoring details section. For example the above command becomes:
date_today="20251109"

experiment_codition="day35_CRoff_vs_Unedit"
dmr_output_path="/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/modkit_dmr/"
dmr_result=${dmr_output_path}${date_today}"_single_base_"${experiment_codition}".bed"

# pileup_Unedit_day28_bam="/home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_UNEDITED_Day28/merged_outputs/pileup_sorted_align_t2t_v1_1_trim_20250721_nCATs_Tcells_UNEDITED_Day28_minion_merged.dna_r9.4.1_e8_sup@v3.3.5mCG.bam"
# removed the @ from the file name
# pileup_Unedit_day28_bam="/home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_UNEDITED_Day28/merged_outputs/pileup_sorted_align_t2t_v1_1_trim_20250721_nCATs_Tcells_UNEDITED_Day28_minion_merged.dna_r9.4.1_e8_sup.5mCG.bam"
# pileup_Unedit_day28_bam="/home/michalula/code/epiCausality/epiCode/differential_methyl/pileups/t2t_v1_1/pileup_Unedit_Day28_Tcells_20250721.bam"

pileup_data_folder_path="/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/unedited/merged_2libraries/dimelo_v2_output/pileup/"
pileup_Unedit_day35_bam=${pileup_data_folder_path}"20251109_filtered_pileup_NT_Day35_Tcells.bam"
# "/home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_UNEDITED_Day28/merged_outputs/5mCG/to_t2t_v2_0/pileup/pileup_Unedit_Day28_Tcells_20250721.bam"

echo "pileup_Unedit_day35_bam: ${pileup_Unedit_day35_bam}.gz"
ls -l "${pileup_Unedit_day35_bam}.gz"
# "/home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_UNEDITED_Day28/merged_outputs/pileup_sorted_align_t2t_v1_1_trim_20250721_nCATs_Tcells_UNEDITED_Day28_minion_merged.dna_r9.4.1_e8_sup.5mCG.bam"
# pileup_Unedit_day28_bam_gz="/home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_UNEDITED_Day28/merged_outputs/pileup_sorted_align_t2t_v1_1_trim_20250721_nCATs_Tcells_UNEDITED_Day28_minion_merged.dna_r9.4.1_e8_sup.5mCG.bam.gz"
  
# pileup_CROFF_day28_bam="/home/michalula/data/cas9_nanopore/data/20250721_nCATs_Tcells_CROFF_Day28/mergered_outputs/pileup_sort_merge_sort_align_t2t_v1_1_trim_20250721_nCATs_Tcells_CROFF_Day28_minion_run2_day8.dna_r9.4.1_e8_sup@v3.3.5mCG.bam"
# pileup_CROFF_day28_bam="/home/michalula/code/epiCausality/epiCode/differential_methyl/pileups/t2t_v1_1/pileup_CROFF_Day28_Tcells_20250721.bam"
pileup_data_folder_path="/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/croff/analyze_single_reads/dimelo_v2_output/pileup/"
pileup_CROFF_day35_bam=${pileup_data_folder_path}"20251109_filtered_pileup_CROFF_Day35_Tcells.bam"

echo "pileup_CROFF_day35_bam: ${pileup_CROFF_day35_bam}.gz"
ls -l "${pileup_CROFF_day35_bam}.gz"

ref_genome_fa="/home/michalula/data/ref_genomes/t2t_v2_0/chm13v2.0.fa"
# ref="/home/michalula/data/ref_genomes/to_t2t_v1_1/chm13.draft_v1.1.fasta"
threads=32
 
cd ${dmr_output_path}
# '/home/michalula/code/epiCausality/epiCode/differential_methyl'

modkit dmr pair \
  -a ${pileup_Unedit_day35_bam}.gz \
  -b ${pileup_CROFF_day35_bam}.gz \
  -o ${dmr_result} \
  --ref ${ref_genome_fa} \
  --base C \
  --threads ${threads} \
  --log-filepath dmr.log


echo "dmr_result: $dmr_result"
ls -lah $dmr_result
# Out:
# pileup_Unedit_day35_bam: /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/unedited/merged_2libraries/dimelo_v2_output/pileup/20251109_filtered_pileup_NT_Day35_Tcells.bam.gz
# -rwxrw-r-- 1 michalula michalula 5591 Nov  9 15:55 /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/unedited/merged_2libraries/dimelo_v2_output/pileup/20251109_filtered_pileup_NT_Day35_Tcells.bam.gz
# pileup_CROFF_day35_bam: /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/croff/analyze_single_reads/dimelo_v2_output/pileup/20251109_filtered_pileup_CROFF_Day35_Tcells.bam.gz
# -rwxrw-r-- 1 michalula michalula 7120 Nov  9 15:50 /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/croff/analyze_single_reads/dimelo_v2_output/pileup/20251109_filtered_pileup_CROFF_Day35_Tcells.bam.gz
# > Error! refusing to overwrite existing file /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/modkit_dmr/20251109_single_base_day35_CRoff_vs_Unedit.bed
# dmr_result: /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/modkit_dmr/20251109_single_base_day35_CRoff_vs_Unedit.bed
# -rw-rw-r-- 1 michalula michalula 29K Nov  9 16:23 /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/modkit_dmr/20251109_single_base_day35_CRoff_vs_Unedit.bed

# %%
# %%bash
#
# date_today="20251109"
# experiment_codition="day35_CRoff_vs_Unedit"
# dmr_output_path="/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/modkit_dmr/"
# dmr_result=${dmr_output_path}${date_today}"single_base_"${experiment_codition}".bed"
#
# echo "dmr_result: $dmr_result"
# # ls -lah $dmr_result
# ls -lah $dmr_output_path
# # cat $dmr_result
# Out:
# dmr_result: /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/modkit_dmr/20251109single_base_day35_CRoff_vs_Unedit.bed
# total 196K
# drwxrwxr-x 2 michalula michalula 4.0K Nov  9 16:24 .
# drwxrwxr-x 6 michalula michalula 4.0K Nov  9 14:56 ..
# -rw-rw-r-- 1 michalula michalula 141K Nov  9 16:18 20251109_modkit_dif_day35.ipynb
# -rw-rw-r-- 1 michalula michalula  29K Nov  9 16:23 20251109_single_base_day35_CRoff_vs_Unedit.bed
# -rw-rw-r-- 1 michalula michalula 8.3K Nov  9 16:24 dmr.log

# %%
pwd
# Out:
# '/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/modkit_dmr'

# %%
# Visualize modkit DMR result
import os
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# Path to the DMR BED output (adjust if you use a different file)
date_today="20251109"

experiment_codition="day35_CRoff_vs_Unedit"
dmr_folder_path="/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/modkit_dmr/"
dmr_path=dmr_folder_path+date_today+"_single_base_"+experiment_codition+".bed"

# dmr_path = dmr_output_path+"dmr_analyze" # '/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/modkit_dmr' 
dmr_output_path = dmr_folder_path + "dmr_analyze" # '/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/modkit_dmr' 

# "/home/michalula/code/epiCausality/epiCode/differential_methyl/modkit_output/single_base_day28_CRoff_vs_Unedit_dmr_20251109.bed"
out_dir = os.path.dirname(dmr_folder_path) or "."
os.makedirs(out_dir, exist_ok=True)

# Try reading with a header first, fall back to headerless read
try:
    df = pd.read_csv(dmr_path, sep='	', comment='#', header=0, engine='python')
    if df.shape[1] < 3:
        df = pd.read_csv(dmr_path, sep='	', comment='#', header=None, engine='python')
except Exception as e:
    print("Failed to read DMR file:", e)
    raise

# If the file had no header, pandas will give integer column names - assign common BED/DMR names
if isinstance(df.columns[0], int):
    ncols = df.shape[1]
    default_names = ["chrom", "start", "end", "name", "score", "strand"]
    names = default_names[:ncols] + [f"col{i}" for i in range(len(default_names), ncols)]
    df.columns = names

# Coerce numeric-looking columns where possible
for c in df.columns:
    try:
        df[c] = pd.to_numeric(df[c], errors='ignore')
    except Exception:
        pass

print("DMR file:", dmr_path)
print("Rows,cols:", df.shape)
display(df.head())
display(df.describe(include="all").T)

# Make histograms of numeric columns and save as HTML
numcols = df.select_dtypes(include=[np.number]).columns.tolist()
if len(numcols):
    for col in numcols:
        fig = px.histogram(df, x=col, nbins=80, title=f"Histogram of {col}")
        html = os.path.join(out_dir, f"dmr_hist_{col}.html")
        fig.write_html(html)
        print("Saved", html)

# Scatter: genomic position vs score (if present)
score_col = None
if 'start' in df.columns:
    if 'score' in df.columns:
        score_col = 'score'
    else:
        # try to find a numeric column to plot against position
        for c in numcols:
            if c != 'start' and c != 'end':
                score_col = c
                break
    if score_col is not None:
        df_plot = df.copy()
        df_plot['pos'] = df_plot['start'].astype(int)
        fig = px.scatter(df_plot, x='pos', y=score_col, color='chrom' if 'chrom' in df_plot.columns else None,
                         title=f"Position vs {score_col}", hover_data=df_plot.columns.tolist(), height=600)
        html = os.path.join(out_dir, 'dmr_position_score_scatter.html')
        fig.write_html(html)
        print("Saved", html)

# Show a table of top hits (by p-value or by score if p-value not present)
rank_col = None
for key in ['pvalue','p_val','p.value','p','padj','qval','score']:
    if key in df.columns:
        rank_col = key
        break
if rank_col is None and len(numcols):
    rank_col = numcols[0]
if rank_col is not None:
    ascending = True if 'p' in str(rank_col).lower() or 'q' in str(rank_col).lower() else False
    top = df.sort_values(by=rank_col, ascending=ascending).head(50)
    display(top)

print("Done. Visualizations saved to:", out_dir)
# Out:
# DMR file: /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/modkit_dmr/20251109_single_base_day35_CRoff_vs_Unedit.bed
# Rows,cols: (284, 11)
# /tmp/ipykernel_110735/1108096088.py:41: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[c] = pd.to_numeric(df[c], errors='ignore')
#    chr1  206583090  206583091  chr1:206583090-206583091  -0.2776317365982791  \
# 0  chr1  206583173  206583174  chr1:206583173-206583174             0.646872
# 1  chr1  206583174  206583175  chr1:206583174-206583175            -0.202477
# 2  chr1  206583387  206583388  chr1:206583387-206583388             0.062585
# 3  chr1  206583388  206583389  chr1:206583388-206583389            -0.193315
# 4  chr1  206583707  206583708  chr1:206583707-206583708             0.023835
#
#     m:1   1    m:2    2 m:100.00 m:100.00.1
# 0  m:65  77  m:138  152  m:84.42    m:90.79
# 1  m:81  84  m:112  118  m:96.43    m:94.92
# 2  m:57  80  m:134  175  m:71.25    m:76.57
# 3  m:61  70   m:85  101  m:87.14    m:84.16
# 4  m:95  99  m:175  187  m:95.96    m:93.58
#                           count unique                       top freq  \
# chr1                        284      1                      chr1  284
# 206583090                 284.0    NaN                       NaN  NaN
# 206583091                 284.0    NaN                       NaN  NaN
# chr1:206583090-206583091    284    284  chr1:206590033-206590034    1
# -0.2776317365982791       284.0    NaN                       NaN  NaN
# m:1                         284     63                       m:0   86
# 1                         284.0    NaN                       NaN  NaN
# m:2                         284    140                     m:103    8
# 2                         284.0    NaN                       NaN  NaN
# m:100.00                    284    153                    m:0.00   86
# m:100.00.1                  284    263                  m:100.00    4
#
#                                       mean          std          min  \
# chr1                                   NaN          NaN          NaN
# 206583090                 206586766.492958  1298.980493  206583173.0
# 206583091                 206586767.492958  1298.980493  206583174.0
# chr1:206583090-206583091               NaN          NaN          NaN
# -0.2776317365982791              46.443029    39.622072     -0.33665
# m:1                                    NaN          NaN          NaN
# 1                                82.017606     18.35062          1.0
# m:2                                    NaN          NaN          NaN
# 2                               133.056338    40.996901          4.0
# m:100.00                               NaN          NaN          NaN
# m:100.00.1                             NaN          NaN          NaN
#
#                                    25%          50%           75%          max
# chr1                               NaN          NaN           NaN          NaN
# 206583090                 206586303.75  206586991.0  206587276.25  206590033.0
# 206583091                 206586304.75  206586992.0  206587277.25  206590034.0
# chr1:206583090-206583091           NaN          NaN           NaN          NaN
# -0.2776317365982791          10.542503    40.640984     71.408926    166.59992
# m:1                                NaN          NaN           NaN          NaN
# 1                                 76.0         85.0          95.0        106.0
# m:2                                NaN          NaN           NaN          NaN
# 2                                106.0        121.0         171.0        198.0
# m:100.00                           NaN          NaN           NaN          NaN
# m:100.00.1                         NaN          NaN           NaN          NaN
# Saved /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/modkit_dmr/dmr_hist_206583090.html
# Saved /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/modkit_dmr/dmr_hist_206583091.html
# Saved /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/modkit_dmr/dmr_hist_-0.2776317365982791.html
# Saved /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/modkit_dmr/dmr_hist_1.html
# Saved /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/modkit_dmr
# 280            -0.327781   m:4    4    m:7    7  m:100.00   m:100.00
# 279            -0.327891   m:5    5    m:5    5  m:100.00   m:100.00
# 278             0.267852  m:61   63  m:111  112   m:96.83    m:99.11
# 277             2.314911  m:69   70   m:88   97   m:98.57    m:90.72
# 276            -0.017542  m:92   99  m:164  182   m:92.93    m:90.11
# 275             0.707679  m:70   70  m:100  102  m:100.00    m:98.04
# 274             0.670918  m:97   98  m:172  172   m:98.98   m:100.00
# 273            -0.203315  m:79   83  m:115  119   m:95.18    m:96.64
# 272             0.575241  m:98  102  m:176  191   m:96.08    m:92.15
# 271             7.014649  m:64   82  m:111  116   m:78.05    m:95.69
# 270             6.959531  m:63   85  m:163  177   m:74.12    m:92.09
# 269            -0.252143  m:43   52   m:76   89   m:82.69    m:85.39
# 268             0.334465  m:84   96  m:170  185   m:87.50    m:91.89
# 267             0.907328  m:54   63   m:97  104   m:85.71    m:93.27
# 266             3.184056  m:81  101  m:169  185   m:80.20    m:91.35
# 265             3.252334  m:59   78   m:94  104   m:75.64    m:90.38
# 264            15.127453  m:49   76  m:157  168   m:64.47    m:93.45
# 263             6.551560  m:38   77   m:84  111   m:49.35    m:75.68
# 262             5.416751  m:47   95  m:126  179   m:49.47    m:70.39
# 261            10.590468  m:58   85  m:110  118   m:68.24    m:93.22
# 260            13.176519  m:68   94  m:171  180   m:72.34    m:95.00
# 259            17.027938   m:4   83   m:45  117    m:4.82    m:38.46
# 258            15.992813   m:6   99   m:61  177    m:6.06    m:34.46
# 257            55.478374  m:16   80  m:106  116   m:20.00    m:91.38
# 256            66.971596  m:13   87  m:147  169   m:14.94    m:86.98
# 255            21.100533  m:11   75   m:68  111   m:14.67    m:61.26
# 254            36.759332   m:8   79  m:107  162   m:10.13    m:66.05
# 253            65.836173   m:5   87   m:96  118    m:5.75    m:81.36
# 252           121.711280   m:0   99  m:159  183    m:0.00    m:86.89
# 251            44.354192   m:4   77   m:75  107    m:5.19    m:70.09
# 250            56.872459   m:7   92  m:123  169    m:7.61    m:72.78
# 249            66.620910   m:0   86   m:82  115    m:0.00    m:71.30
# 248            76.370893   m:1  103  m:122  177    m:0.97    m:68.93
# 247            26.356273   m:0   59   m:31   60    m:0.00    m:51.67
# 246            15.323535   m:5   75   m:54  134    m:6.67    m:40.30
# 245            56.803638   m:0   80   m:70  103    m:0.00    m:67.96
# 244            65.609356   m:1   93  m:103  152    m:1.08    m:67.76
# 243            22.372419   m:0   89   m:36  120    m:0.00    m:30.00
# 242            31.341106   m:0  100   m:61  179    m:0.00    m:34.08
# 241            44.617555   m:1   67   m:66   97    m:1.49    m:68.04
# 240            51.407257   m:1   99   m:97  178    m:1.01    m:54.49
# 239            27.039866   m:1   74   m:44   94    m:1.35    m:46.81
# 238            34.906951   m:3  105   m:82  183    m:2.86    m:44.81
# 237            48.380398   m:0   83   m:63  106    m:0.00    m:59.43
# 236            50.720527   m:1   91   m:96  168    m:1.10    m:57.14
# 235            35.273909   m:0   54   m:55   90    m:0.00    m:61.11
# 234            44.149039   m:1   94   m:85  166    m:1.06    m:51.20
# Done. Visualizations saved to: /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_35/modkit_dmr
