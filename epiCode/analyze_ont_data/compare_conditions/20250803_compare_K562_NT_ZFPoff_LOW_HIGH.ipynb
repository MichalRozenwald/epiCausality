# %% [markdown]
# # Compare mC fractures across conditions

# %%
import sys
from pathlib import Path
from datetime import datetime
from matplotlib import pyplot as plt 
import seaborn as sns
import pandas as pd
import numpy as np
# import time
# import shap


# Add the folder containing 'my_functions.py' to sys.path
sys.path.append("/home/michalula/code/epiCausality/epiCode/utils/") # str(Path(__file__).parent / 'utils'))

# Import the module or specific functions
# from /home/michalula/code/epiCausality/epiCode/utils/funcs_extract_mC_profiles_from_BAMs.py
# from funcs_extract_mC_profiles_from_BAMs import system_info, extract_from_bam
from funcs_extract_mC_profiles_from_BAMs import (
    system_info,
    get_reference_sequence,
    create_output_directory,
    extract_from_bam,
    process_extracted_reads,
    visualize_data,
    create_padded_reads,
    plot_padded_reads,
    save_padded_reads,
    remove_low_methylated_reads,
    process_extracted_reads_no_fully_unmethylated,
    create_padded_reads_no_fully_unmethylated
    # main,
)
from funcs_analize_forward_reverse_extracted_mC_reads import analize_forward_reverse_CGs_pipeline, load_padded_reads
# Out:
# modkit found with expected version 0.2.4

# %% [markdown]
# # K562 Unedited

# %%
# ! ls "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_6/unedited/dimelo_v2_output"

# %%
save_folder_path = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/K562/unedited/dimelo_v2_output/"
# "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_6/unedited/dimelo_v2_output/"
save_padded_reads_name_np = save_folder_path + "CG_137_removed_low70_methylated_padded_reads_K562_Unedited_D2_Thr0.7_NoFullyUnmethylated_T2Tv2_mCthresh0.7_t2t_v2_0_chr1:206583354-206589854_2025-08-05_units_combined_numFWD96_numRVS132.npy"
# Load padded reads
CGs_K562_unedited_mc07_remove_low70 = load_padded_reads(save_folder_path, save_padded_reads_name_np)
CGs_K562_unedited_mc07_remove_low70.shape
# Out:
# Padded reads loaded successfully.
# (228, 137)

# %%
save_folder_path = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/K562/unedited/dimelo_v2_output/"
save_padded_reads_name_np = save_folder_path + "CG_137_removed_low70_methylated_padded_reads_K562_Unedited_D2_Thr0.995_NoFullyUnmethylated_T2Tv2_mCthresh0.995_t2t_v2_0_chr1:206583354-206589854_2025-08-05_units_combined_numFWD84_numRVS113.npy"
# Load padded reads
CGs_K562_unedited_mc0995_remove_low70 = load_padded_reads(save_folder_path, save_padded_reads_name_np)
CGs_K562_unedited_mc0995_remove_low70.shape
# Out:
# Padded reads loaded successfully.
# (197, 137)

# %%
save_folder_path = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/K562/unedited/dimelo_v2_output/"
save_padded_reads_name_np = save_folder_path + "CG_137_removed_low70_methylated_padded_reads_K562_Unedited_D2_Thr0.995_NoFullyUnmethylated_T2Tv2_mCthresh0.995_t2t_v2_0_chr1:206583354-206589854_2025-08-05_units_combined_numFWD84_numRVS113.npy"
# Load padded reads
CGs_K562_unedited_mc0995_remove_low70 = load_padded_reads(save_folder_path, save_padded_reads_name_np)
CGs_K562_unedited_mc0995_remove_low70.shape
# Out:
# Padded reads loaded successfully.
# (197, 137)

# %% [markdown]
# # K562 ZFPoff LOW

# %%
save_folder_path = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/K562/post_sort/ZFPoff_sortLOW/dimelo_v2_output/"
save_padded_reads_name_np = save_folder_path + "CG_137_removed_low70_methylated_padded_reads_K562_ZFPOFFpostSort_LOW70_Thr0.7_NoFullyUnmethylated_T2Tv2_mCthresh0.7_t2t_v2_0_chr1:206583354-206589854_2025-08-05_units_combined_numFWD961_numRVS1238.npy"
# Load padded reads
CGs_K562_ZFPoff_LOW_mc07_remove_low70 = load_padded_reads(save_folder_path, save_padded_reads_name_np)
CGs_K562_ZFPoff_LOW_mc07_remove_low70.shape
# Out:
# Padded reads loaded successfully.
# (2199, 137)

# %%
save_folder_path = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/K562/post_sort/ZFPoff_sortLOW/dimelo_v2_output/"
save_padded_reads_name_np = save_folder_path + "CG_137_removed_low70_methylated_padded_reads_K562_ZFPOFFpostSort_LOW70_Thr0.995_NoFullyUnmethylated_T2Tv2_mCthresh0.995_t2t_v2_0_chr1:206583354-206589854_2025-08-05_units_combined_numFWD855_numRVS1124.npy"
# Load padded reads
CGs_K562_ZFPoff_LOW_mc0995_remove_low70 = load_padded_reads(save_folder_path, save_padded_reads_name_np)
CGs_K562_ZFPoff_LOW_mc0995_remove_low70.shape
# Out:
# Padded reads loaded successfully.
# (1979, 137)

# %% [markdown]
# # K562 ZFPoff HIGH

# %%
save_folder_path = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/K562/post_sort/ZFPoff_sortHIGH/dimelo_v2_output/"
save_padded_reads_name_np = save_folder_path + "CG_137_removed_low70_methylated_padded_reads_K562_ZFPOFFpostSort_HIGH_Thr0.7_NoFullyUnmethylated_T2Tv2_mCthresh0.7_t2t_v2_0_chr1:206583354-206589854_2025-08-05_units_combined_numFWD623_numRVS726.npy"
# Load padded reads
CGs_K562_ZFPoff_HIGH_mc07_remove_low70 = load_padded_reads(save_folder_path, save_padded_reads_name_np)
CGs_K562_ZFPoff_HIGH_mc07_remove_low70.shape
# Out:
# Padded reads loaded successfully.
# (1349, 137)

# %%
save_folder_path = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/K562/post_sort/ZFPoff_sortHIGH/dimelo_v2_output/"
save_padded_reads_name_np = save_folder_path + "CG_137_removed_low70_methylated_padded_reads_K562_ZFPOFFpostSort_HIGH_Thr0.995_NoFullyUnmethylated_T2Tv2_mCthresh0.995_t2t_v2_0_chr1:206583354-206589854_2025-08-05_units_combined_numFWD587_numRVS640.npy"
# Load padded reads
CGs_K562_ZFPoff_HIGH_mc0995_remove_low70 = load_padded_reads(save_folder_path, save_padded_reads_name_np)
CGs_K562_ZFPoff_HIGH_mc0995_remove_low70.shape
# Out:
# Padded reads loaded successfully.
# (1227, 137)

# %%
CGs_pd = CGs_K562_unedited_mc07_remove_low70
CGs_K562_unedited_mc07_remove_low70_sums = np.nansum(CGs_pd, axis=0) 
CGs_K562_unedited_mc07_remove_low70_frac = CGs_K562_unedited_mc07_remove_low70_sums  / len(CGs_pd) 

CGs_pd = CGs_K562_ZFPoff_LOW_mc07_remove_low70
CGs_K562_ZFPoff_LOW_mc07_remove_low70_sums = np.nansum(CGs_pd, axis=0) 
CGs_K562_ZFPoff_LOW_mc07_remove_low70_frac = CGs_K562_ZFPoff_LOW_mc07_remove_low70_sums  / len(CGs_pd) 

CGs_pd = CGs_K562_ZFPoff_HIGH_mc07_remove_low70
CGs_K562_ZFPoff_HIGH_mc07_remove_low70_sums = np.nansum(CGs_pd, axis=0) 
CGs_K562_ZFPoff_HIGH_mc07_remove_low70_frac = CGs_K562_ZFPoff_HIGH_mc07_remove_low70_sums  / len(CGs_pd) 



plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_K562_ZFPoff_HIGH_mc07_remove_low70_frac)), CGs_K562_ZFPoff_HIGH_mc07_remove_low70_frac, snap=False, alpha=0.5, label='K562 ZFPoff High')
plt.bar(np.arange(len(CGs_K562_unedited_mc07_remove_low70_frac)), CGs_K562_unedited_mc07_remove_low70_frac, snap=False, alpha=0.5, label='K562 Unedited')
plt.bar(np.arange(len(CGs_K562_ZFPoff_LOW_mc07_remove_low70_frac)), CGs_K562_ZFPoff_LOW_mc07_remove_low70_frac, snap=False, alpha=0.5, label='K562 ZFPoff Low')

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for Unedited T cells CGs day 28 \n mC threshold 70%; >80% * mean(mC)')
plt.legend()
# Show the plot
plt.show()



plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_K562_unedited_mc07_remove_low70_frac)), CGs_K562_unedited_mc07_remove_low70_frac, snap=False, alpha=0.5, label='K562 Unedited')
plt.bar(np.arange(len(CGs_K562_ZFPoff_LOW_mc07_remove_low70_frac)), CGs_K562_ZFPoff_LOW_mc07_remove_low70_frac, snap=False, alpha=0.5, label='K562 ZFPoff Low')

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for Unedited T cells CGs day 28 \n mC threshold 70%; >80% * mean(mC)')
plt.legend()
# Show the plot
plt.show()

# DIFFERENCES

# dif_mCthresh_CRoff_unedit_0995 = CGs_CRoff_0995_remove_low80_frac - CGs_unedited_0995_remove_low80_frac

# plt.figure(figsize=(16, 5))
# plt.bar(np.arange(len(dif_mCthresh_CRoff_unedit_0995)), dif_mCthresh_CRoff_unedit_0995, snap=False, alpha=0.5, label='CRoff - unedited' )

# # Add labels and title
# plt.xlabel('CpG units')
# plt.ylabel('Fraction of mC difference')
# plt.title('Fraction Differences between mC CRISPRoff and Unedited T cells day 28 \n confidence  threshold 99.5% (<80%*mean(mC) removed)')
# plt.legend()

# # Show the plot
# plt.show()

# %% [markdown]
# # Day 6 post ElectroPoration (EP)

# %%
save_folder_path = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_6/unedited/dimelo_v2_output/"
save_padded_reads_name_np = save_folder_path + "CG_137_removed_low70_methylated_padded_reads_day6_unedited_Tcells_Thr0.7_NoFullyUnmethylated_T2Tv2_mCthresh0.7_t2t_v2_0_chr1:206583354-206589854_2025-08-03_units_combined_numFWD613_numRVS748.npy"
# Load padded reads
CGs_unedited_D6_mc07_remove_low70 = load_padded_reads(save_folder_path, save_padded_reads_name_np)
CGs_unedited_D6_mc07_remove_low70.shape
# Out:
# Padded reads loaded successfully.
# (1361, 137)

# %%
save_folder_path = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_6/unedited/dimelo_v2_output/"
save_padded_reads_name_np = save_folder_path + "CG_137_removed_low80_methylated_padded_reads_day6_unedited_Tcells_Thr0.995_NoFullyUnmethylated_T2Tv2_mCthresh0.995_t2t_v2_0_chr1:206583354-206589854_2025-08-03_units_combined_numFWD493_numRVS604.npy"

# Load padded reads
CGs_unedited_D6_mc0995_remove_low80 = load_padded_reads(save_folder_path, save_padded_reads_name_np)
CGs_unedited_D6_mc0995_remove_low80.shape
# Out:
# Padded reads loaded successfully.
# (1097, 137)

# %%
save_folder_path = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_6/unedited/dimelo_v2_output/"
save_padded_reads_name_np = save_folder_path+ "CG_137_removed_low70_methylated_padded_reads_day6_unedited_Tcells_Thr0.995_NoFullyUnmethylated_T2Tv2_mCthresh0.995_t2t_v2_0_chr1:206583354-206589854_2025-08-03_units_combined_numFWD546_numRVS673.npy"

# Load padded reads
CGs_unedited_D6_mc0995_remove_low70 = load_padded_reads(save_folder_path, save_padded_reads_name_np)
CGs_unedited_D6_mc0995_remove_low70.shape #, CGs_unedited_D6_mc0995_remove_low70
# Out:
# Padded reads loaded successfully.
# (1219, 137)

# %% [markdown]
# ## CRISPRoff Day 6

# %%
# ! ls /home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_6/croff/dimelo_v2_output/

# %%
save_folder_path = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_6/croff/dimelo_v2_output/"
save_padded_reads_name_np = "CG_137_removed_low70_methylated_padded_reads_day6_CRoff_D6_chr1_Tcells_Thr0.7_NoFullyUnmethylated_T2Tv2_mCthresh0.7_t2t_v2_0_chr1:206583354-206589854_2025-08-04_units_combined_numFWD995_numRVS1519.npy"
# Load padded reads
CGs_CRoff_D6_mc07_remove_low70 = load_padded_reads(save_folder_path, save_padded_reads_name_np)
CGs_CRoff_D6_mc07_remove_low70.shape # , CGs_CRoff_D6_mc0995_remove_low80
# Out:
# Padded reads loaded successfully.
# (2514, 137)

# %%
save_folder_path = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_6/croff/dimelo_v2_output/"
save_padded_reads_name_np = "CG_137_removed_low80_methylated_padded_reads_day6_CRoff_D6_chr1_Tcells_Thr0.995_NoFullyUnmethylated_T2Tv2_mCthresh0.995_t2t_v2_0_chr1:206583354-206589854_2025-08-04_units_combined_numFWD855_numRVS1120.npy"

# Load padded reads
CGs_CRoff_D6_mc0995_remove_low80 = load_padded_reads(save_folder_path, save_padded_reads_name_np)
CGs_CRoff_D6_mc0995_remove_low80.shape # , CGs_CRoff_D6_mc0995_remove_low80
# Out:
# Padded reads loaded successfully.
# (1975, 137)

# %%
save_folder_path = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_6/croff/dimelo_v2_output/"
save_padded_reads_name_np = save_folder_path+ "CG_137_removed_low50_methylated_padded_reads_day6_CRoff_D6_chr1_Tcells_Thr0.995_NoFullyUnmethylated_T2Tv2_mCthresh0.995_t2t_v2_0_chr1:206583354-206589854_2025-08-04_units_combined_numFWD1002_numRVS1459.npy"

# Load padded reads
CGs_CRoff_D6_mc0995_remove_low50 = load_padded_reads(save_folder_path, save_padded_reads_name_np)
CGs_CRoff_D6_mc0995_remove_low50.shape# , CGs_CRoff_D6_mc0995_remove_low50
# Out:
# Padded reads loaded successfully.
# (2461, 137)

# %%
save_folder_path = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_6/croff/dimelo_v2_output/"
save_padded_reads_name_np = save_folder_path + "CG_137_removed_low70_methylated_padded_reads_day6_CRoff_D6_chr1_Tcells_Thr0.995_NoFullyUnmethylated_T2Tv2_mCthresh0.995_t2t_v2_0_chr1:206583354-206589854_2025-08-04_units_combined_numFWD911_numRVS1232.npy"

# Load padded reads
CGs_CRoff_D6_mc0995_remove_low70 = load_padded_reads(save_folder_path, save_padded_reads_name_np)
CGs_CRoff_D6_mc0995_remove_low70.shape# , CGs_CRoff_D6_mc0995_remove_low70
# Out:
# Padded reads loaded successfully.
# (2143, 137)

# %% [markdown]
# # Day 28 post EP
# ## Unedited Cells

# %%
# save_padded_reads_name_np = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_28" + \
    # "/unedited/dimelo_v2_output/CG_137_removed_low80_methylated_padded_reads_day28_NT_chr1_Tcells_Thr0.995_NoFullyUnmethylated_T2Tv2_mCthresh0.995_t2t_v2_0_chr1:206583354-206589854_2025-08-04_units_combined_numFWD4_numRVS15.npy"

save_padded_reads_name_np = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_28/unedited/dimelo_v2_output/CG_137_removed_low80_methylated_padded_reads_day28_NT_D28_chr1_Tcells_Thr0.995_NoFullyUnmethylated_T2Tv2_mCthresh0.995_t2t_v2_0_chr1:206583354-206589854_2025-08-04_units_combined_numFWD4_numRVS15.npy"
# Load padded reads
CGs_unedited_D28_mc0995_remove_low80 = load_padded_reads(save_folder_path, save_padded_reads_name_np)
CGs_unedited_D28_mc0995_remove_low80.shape
# Out:
# Padded reads loaded successfully.
# (19, 137)

# %%
# save_padded_reads_name_np = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_28" + \
#     "/unedited/dimelo_v2_output/CG_137_removed_low70_methylated_padded_reads_day28_NT_chr1_Tcells_Thr0.995_NoFullyUnmethylated_T2Tv2_mCthresh0.995_t2t_v2_0_chr1:206583354-206589854_2025-08-04_units_combined_numFWD6_numRVS16.npy"
save_padded_reads_name_np = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_28/unedited/dimelo_v2_output/CG_137_removed_low70_methylated_padded_reads_day28_NT_D28_chr1_Tcells_Thr0.995_NoFullyUnmethylated_T2Tv2_mCthresh0.995_t2t_v2_0_chr1:206583354-206589854_2025-08-04_units_combined_numFWD6_numRVS16.npy"
# Load padded reads
CGs_unedited_D28_mc0995_remove_low70 = load_padded_reads(save_folder_path, save_padded_reads_name_np)
CGs_unedited_D28_mc0995_remove_low70.shape
# Out:
# Padded reads loaded successfully.
# (22, 137)

# %%
# ! ls "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_28/unedited/dimelo_v2_output"

# %%
# save_padded_reads_name_np = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_28" + \
#     "/unedited/dimelo_v2_output/CG_137_removed_low70_methylated_padded_reads_day28_NT_chr1_Tcells_Thr0.7_NoFullyUnmethylated_T2Tv2_mCthresh0.7_t2t_v2_0_chr1:206583354-206589854_2025-08-04_units_combined_numFWD7_numRVS15.npy"
save_padded_reads_name_np = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_28/unedited/dimelo_v2_output/CG_137_removed_low70_methylated_padded_reads_day28_NT_D28_chr1_Tcells_Thr0.7_NoFullyUnmethylated_T2Tv2_mCthresh0.7_t2t_v2_0_chr1:206583354-206589854_2025-08-04_units_combined_numFWD7_numRVS15.npy"

# Load padded reads
CGs_unedited_D28_mc07_remove_low70 = load_padded_reads(save_folder_path, save_padded_reads_name_np)
CGs_unedited_D28_mc07_remove_low70.shape
# Out:
# Padded reads loaded successfully.
# (22, 137)

# %%
# ! ls "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_28/croff/dimelo_v2_output/"

# %%
save_padded_reads_name_np = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_28/croff/dimelo_v2_output/CG_137_removed_low70_methylated_padded_reads_day28_CRoff_D28_chr1_Tcells_Thr0.7_NoFullyUnmethylated_T2Tv2_mCthresh0.7_t2t_v2_0_chr1:206583354-206589854_2025-08-04_units_combined_numFWD6_numRVS5.npy"

# Load padded reads
CGs_CRoff_D28_mc07_remove_low70 = load_padded_reads(save_folder_path, save_padded_reads_name_np)
CGs_CRoff_D28_mc07_remove_low70.shape
# Out:
# Padded reads loaded successfully.
# (11, 137)

# %%
# save_padded_reads_name_np = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_28"+ \
#     "/croff/dimelo_v2_output/CG_137_removed_low70_methylated_padded_reads_day28_CRoff_chr1_Tcells_Thr0.995_NoFullyUnmethylated_T2Tv2_mCthresh0.995_t2t_v2_0_chr1:206583354-206589854_2025-08-04_units_combined_numFWD6_numRVS4.npy"
save_padded_reads_name_np = "/home/michalula/code/epiCausality/epiCode/analyze_ont_data/T2T_v2.0_mapped/T_cells/day_28/croff/dimelo_v2_output/CG_137_removed_low80_methylated_padded_reads_day28_CRoff_D28_chr1_Tcells_Thr0.995_NoFullyUnmethylated_T2Tv2_mCthresh0.995_t2t_v2_0_chr1:206583354-206589854_2025-08-04_units_combined_numFWD6_numRVS4.npy"
# Load padded reads
CGs_CRoff_D28_mc0995_remove_low80 = load_padded_reads(save_folder_path, save_padded_reads_name_np)
CGs_CRoff_D28_mc0995_remove_low80.shape
# Out:
# Padded reads loaded successfully.
# (10, 137)

# %%
CGs_pd = CGs_K562_unedited_mc0995_remove_low70
CGs_K562_unedited_mc0995_remove_low70_sums = np.nansum(CGs_pd, axis=0) 
CGs_K562_unedited_mc0995_remove_low70_frac = CGs_K562_unedited_mc0995_remove_low70_sums  / len(CGs_pd) 

CGs_pd = CGs_K562_ZFPoff_LOW_mc0995_remove_low70
CGs_K562_ZFPoff_LOW_mc0995_remove_low70_sums = np.nansum(CGs_pd, axis=0) 
CGs_K562_ZFPoff_LOW_mc0995_remove_low70_frac = CGs_K562_ZFPoff_LOW_mc0995_remove_low70_sums  / len(CGs_pd) 

CGs_pd = CGs_K562_ZFPoff_HIGH_mc0995_remove_low70
CGs_K562_ZFPoff_HIGH_mc0995_remove_low70_sums = np.nansum(CGs_pd, axis=0) 
CGs_K562_ZFPoff_HIGH_mc0995_remove_low70_frac = CGs_K562_ZFPoff_HIGH_mc0995_remove_low70_sums  / len(CGs_pd) 



plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_K562_ZFPoff_HIGH_mc0995_remove_low70_frac)), CGs_K562_ZFPoff_HIGH_mc0995_remove_low70_frac, snap=False, alpha=0.5, label='K562 ZFPoff High')
plt.bar(np.arange(len(CGs_K562_unedited_mc0995_remove_low70_frac)), CGs_K562_unedited_mc0995_remove_low70_frac, snap=False, alpha=0.5, label='K562 Unedited')
plt.bar(np.arange(len(CGs_K562_ZFPoff_LOW_mc0995_remove_low70_frac)), CGs_K562_ZFPoff_LOW_mc0995_remove_low70_frac, snap=False, alpha=0.5, label='K562 ZFPoff Low')

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for K562 cells CGs \n mC threshold 99.5%; >80% * mean(mC)')
plt.legend()
# Show the plot
plt.show()



plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_K562_unedited_mc0995_remove_low70_frac)), CGs_K562_unedited_mc0995_remove_low70_frac, snap=False, alpha=0.5, label='K562 Unedited')
plt.bar(np.arange(len(CGs_K562_ZFPoff_LOW_mc0995_remove_low70_frac)), CGs_K562_ZFPoff_LOW_mc0995_remove_low70_frac, snap=False, alpha=0.5, label='K562 ZFPoff Low')

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for K562 cells \n mC threshold 99.5%; >80% * mean(mC)')
plt.legend()
# Show the plot
plt.show()

# DIFFERENCES

# dif_mCthresh_CRoff_unedit_0995 = CGs_CRoff_0995_remove_low80_frac - CGs_unedited_0995_remove_low80_frac

# plt.figure(figsize=(16, 5))
# plt.bar(np.arange(len(dif_mCthresh_CRoff_unedit_0995)), dif_mCthresh_CRoff_unedit_0995, snap=False, alpha=0.5, label='CRoff - unedited' )

# # Add labels and title
# plt.xlabel('CpG units')
# plt.ylabel('Fraction of mC difference')
# plt.title('Fraction Differences between mC CRISPRoff and Unedited T cells day 28 \n confidence  threshold 99.5% (<80%*mean(mC) removed)')
# plt.legend()

# # Show the plot
# plt.show()


CGs_D6_pd = CGs_unedited_D6_mc07_remove_low70
CGs_D6_unedited_07_remove_low70_sums = np.nansum(CGs_D6_pd, axis=0) 
CGs_D6_unedited_07_remove_low70_frac = CGs_D6_unedited_07_remove_low70_sums  / len(CGs_D6_pd) 

CGs_D6_pd = CGs_CRoff_D6_mc07_remove_low70
CGs_CRoff_D6_07_remove_low70_sums = np.nansum(CGs_D6_pd, axis=0) 
CGs_CRoff_D6_07_remove_low70_frac = CGs_CRoff_D6_07_remove_low70_sums  / len(CGs_D6_pd) 

plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_CRoff_D6_07_remove_low70_frac)), CGs_CRoff_D6_07_remove_low70_frac, snap=False, alpha=0.5, label='CRISPRoff')
plt.bar(np.arange(len(CGs_D6_unedited_07_remove_low70_frac)), CGs_D6_unedited_07_remove_low70_frac, snap=False, alpha=0.5, label='Unedited')

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for Unedited T cells CGs \n mC threshold 70%; >70% * mean(mC)')
plt.legend()
# Show the plot
plt.show()

# DIFFERENCES
dif_mCthresh_CRoff_unedit_07 = CGs_CRoff_D6_07_remove_low70_frac - CGs_D6_unedited_07_remove_low70_frac

plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(dif_mCthresh_CRoff_unedit_07)), dif_mCthresh_CRoff_unedit_07, snap=False, alpha=0.5, label='CRoff - unedited' )

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC difference')
plt.title('Fraction Differences between mC CRISPRoff and Unedited T cells day 6 \n confidence  threshold 70% (<70%*mean(mC) removed)')
plt.legend()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_K562_ZFPoff_HIGH_mc0995_remove_low70_frac)), CGs_K562_ZFPoff_HIGH_mc0995_remove_low70_frac, snap=False, alpha=0.5, label='K562: ZFPoff High')

plt.bar(np.arange(len(CGs_CRoff_D6_0995_remove_low70_frac)), CGs_CRoff_D6_0995_remove_low70_frac, snap=False, alpha=0.5, label='T cells: CRISPRoff')

plt.bar(np.arange(len(CGs_D6_unedited_0995_remove_low70_frac)), CGs_D6_unedited_0995_remove_low70_frac, snap=False, alpha=0.5, label='T cells: Unedited')

plt.bar(np.arange(len(CGs_K562_unedited_mc0995_remove_low70_frac)), CGs_K562_unedited_mc0995_remove_low70_frac, snap=False, alpha=0.5, label='K562: Unedited')

plt.bar(np.arange(len(CGs_K562_ZFPoff_LOW_mc0995_remove_low70_frac)), CGs_K562_ZFPoff_LOW_mc0995_remove_low70_frac, snap=False, alpha=0.5, label='K562: ZFPoff Low')

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for mCGs \n mC threshold 99.5%; >70% * mean(mC)')
plt.legend()
# Show the plot
plt.show()

# %%
plt.figure(figsize=(16, 5))

plt.bar(np.arange(len(CGs_K562_ZFPoff_HIGH_mc07_remove_low70_frac)), CGs_K562_ZFPoff_HIGH_mc07_remove_low70_frac, snap=False, alpha=0.5, label='K562: ZFPoff High')
plt.bar(np.arange(len(CGs_CRoff_D6_07_remove_low70_frac)), CGs_CRoff_D6_07_remove_low70_frac, snap=False, alpha=0.5, label='T cells: CRISPRoff')

plt.bar(np.arange(len(CGs_D6_unedited_07_remove_low70_frac)), CGs_D6_unedited_07_remove_low70_frac, snap=False, alpha=0.5, label='T cells: Unedited')
plt.bar(np.arange(len(CGs_K562_unedited_mc07_remove_low70_frac)), CGs_K562_unedited_mc07_remove_low70_frac, snap=False, alpha=0.5, label='K562: Unedited')

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for mCGs \n mC threshold 70%; >70% * mean(mC)')
plt.legend()
# Show the plot
plt.show()

# %%
plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_K562_ZFPoff_HIGH_mc07_remove_low70_frac)), CGs_K562_ZFPoff_HIGH_mc07_remove_low70_frac, snap=False, alpha=0.5, label='K562: ZFPoff High')
plt.bar(np.arange(len(CGs_CRoff_D6_07_remove_low70_frac)), CGs_CRoff_D6_07_remove_low70_frac, snap=False, alpha=0.5, label='T cells: CRISPRoff')

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for mCGs \n mC threshold 70%; >70% * mean(mC)')
plt.legend()
# Show the plot
plt.show()

# %%
plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_D6_unedited_07_remove_low70_frac)), CGs_D6_unedited_07_remove_low70_frac, snap=False, alpha=0.5, label='T cells: Unedited')
plt.bar(np.arange(len(CGs_K562_unedited_mc07_remove_low70_frac)), CGs_K562_unedited_mc07_remove_low70_frac, snap=False, alpha=0.5, label='K562: Unedited')

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for mCGs \n mC threshold 70%; >70% * mean(mC)')
plt.legend()
# Show the plot
plt.show()

# %%
plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_D6_unedited_0995_remove_low70_frac)), CGs_D6_unedited_0995_remove_low70_frac, snap=False, alpha=0.5, label='T cells: Unedited')
plt.bar(np.arange(len(CGs_K562_unedited_mc0995_remove_low70_frac)), CGs_K562_unedited_mc0995_remove_low70_frac, snap=False, alpha=0.5, label='K562: Unedited')

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for mCGs \n mC threshold 99.5%; >70% * mean(mC)')
plt.legend()
# Show the plot
plt.show()

# %%
# CGs_pd = CGs_unedited_mc0995_remove_low80
# CGs_unedited_0995_remove_low80_sums = np.nansum(CGs_pd, axis=0) 
# CGs_unedited_0995_remove_low80_frac = CGs_unedited_0995_remove_low80_sums  / len(CGs_pd) 

# CGs_pd = CGs_CRoff_mc0995_remove_low80
# CGs_CRoff_0995_remove_low80_sums = np.nansum(CGs_pd, axis=0) 
# CGs_CRoff_0995_remove_low80_frac = CGs_CRoff_0995_remove_low80_sums  / len(CGs_pd) 

# plt.figure(figsize=(16, 5))
# plt.bar(np.arange(len(CGs_CRoff_0995_remove_low80_frac)), CGs_CRoff_0995_remove_low80_frac, snap=False, alpha=0.5, label='CRISPRoff')
# plt.bar(np.arange(len(CGs_unedited_0995_remove_low80_frac)), CGs_unedited_0995_remove_low80_frac, snap=False, alpha=0.5, label='Unedited')

# # Add labels and title
# plt.xlabel('CpG units')
# plt.ylabel('Fraction of mC')
# plt.title('Fraction of mC for Unedited T cells CGs day 28 \n mC threshold 99.5%; >80% * mean(mC)')
# plt.legend()
# # Show the plot
# plt.show()

# # DIFFERENCES

# dif_mCthresh_CRoff_unedit_0995 = CGs_CRoff_0995_remove_low80_frac - CGs_unedited_0995_remove_low80_frac

# plt.figure(figsize=(16, 5))
# plt.bar(np.arange(len(dif_mCthresh_CRoff_unedit_0995)), dif_mCthresh_CRoff_unedit_0995, snap=False, alpha=0.5, label='CRoff - unedited' )

# # Add labels and title
# plt.xlabel('CpG units')
# plt.ylabel('Fraction of mC difference')
# plt.title('Fraction Differences between mC CRISPRoff and Unedited T cells day 28 \n confidence  threshold 99.5% (<80%*mean(mC) removed)')
# plt.legend()

# # Show the plot
# plt.show()

# %%
CGs_D6_pd = CGs_unedited_D6_mc0995_remove_low80
CGs_D6_unedited_0995_remove_low80_sums = np.nansum(CGs_D6_pd, axis=0) 
CGs_D6_unedited_0995_remove_low80_frac = CGs_D6_unedited_0995_remove_low80_sums  / len(CGs_D6_pd) 

CGs_D6_pd = CGs_CRoff_D6_mc0995_remove_low80
CGs_CRoff_D6_0995_remove_low80_sums = np.nansum(CGs_D6_pd, axis=0) 
CGs_CRoff_D6_0995_remove_low80_frac = CGs_CRoff_D6_0995_remove_low80_sums  / len(CGs_D6_pd) 

CGs_pd = CGs_unedited_D28_mc0995_remove_low80
CGs_unedited_D28_0995_remove_low80_sums = np.nansum(CGs_pd, axis=0) 
CGs_unedited_D28_0995_remove_low80_frac = CGs_unedited_D28_0995_remove_low80_sums  / len(CGs_pd) 

CGs_pd = CGs_CRoff_D28_mc0995_remove_low80
CGs_CRoff_D28_0995_remove_low80_sums = np.nansum(CGs_pd, axis=0) 
CGs_CRoff_D28_0995_remove_low80_frac = CGs_CRoff_D28_0995_remove_low80_sums  / len(CGs_pd) 


plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_CRoff_D6_0995_remove_low80_frac)), CGs_CRoff_D6_0995_remove_low80_frac, snap=False, alpha=0.5, label='CRISPRoff Day 6')
plt.bar(np.arange(len(CGs_CRoff_D28_0995_remove_low80_frac)), CGs_CRoff_D28_0995_remove_low80_frac, snap=False, alpha=0.5, label='CRISPRoff Day 28')

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for Unedited T cells CGs Day 6 \n mC threshold 99.5%; >80% * mean(mC)')
plt.legend()
# Show the plot
plt.show()
plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_D6_unedited_0995_remove_low80_frac)), CGs_D6_unedited_0995_remove_low80_frac, snap=False, alpha=0.5, label='Unedited Day 6')
plt.bar(np.arange(len(CGs_unedited_D28_0995_remove_low80_frac)), CGs_unedited_D28_0995_remove_low80_frac, snap=False, alpha=0.5, label='Unedited Day 28')

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for Unedited T cells CGs  \n mC threshold 99.5%; >80% * mean(mC)')
plt.legend()
# Show the plot
plt.show()


plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_CRoff_D6_0995_remove_low80_frac)), CGs_CRoff_D6_0995_remove_low80_frac, snap=False, alpha=0.5, label='CRISPRoff Day 6')
plt.bar(np.arange(len(CGs_CRoff_D28_0995_remove_low80_frac)), CGs_CRoff_D28_0995_remove_low80_frac, snap=False, alpha=0.5, label='CRISPRoff Day 28')

plt.bar(np.arange(len(CGs_D6_unedited_0995_remove_low80_frac)), CGs_D6_unedited_0995_remove_low80_frac, snap=False, alpha=0.5, label='Unedited Day 6')
plt.bar(np.arange(len(CGs_unedited_D28_0995_remove_low80_frac)), CGs_unedited_D28_0995_remove_low80_frac, snap=False, alpha=0.5, label='Unedited Day 28')

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for Unedited T cells CGs \n mC threshold 99.5%; >80% * mean(mC)')
plt.legend()
# Show the plot
plt.show()

# DIFFERENCES

dif_mCthresh_CRoff_unedit_0995 = CGs_CRoff_D6_0995_remove_low80_frac - CGs_D6_unedited_0995_remove_low80_frac

plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(dif_mCthresh_CRoff_unedit_0995)), dif_mCthresh_CRoff_unedit_0995, snap=False, alpha=0.5, label='CRoff - unedited' )

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC difference')
plt.title('Fraction Differences between mC CRISPRoff and Unedited T cells day 6 \n confidence  threshold 99.5% (<80%*mean(mC) removed)')
plt.legend()

# Show the plot
plt.show()

# %%
CGs_D6_pd = CGs_unedited_D6_mc0995_remove_low80
CGs_D6_unedited_0995_remove_low80_sums = np.nansum(CGs_D6_pd, axis=0) 
CGs_D6_unedited_0995_remove_low80_frac = CGs_D6_unedited_0995_remove_low80_sums  / len(CGs_D6_pd) 

CGs_D6_pd = CGs_CRoff_D6_mc0995_remove_low80
CGs_CRoff_D6_0995_remove_low80_sums = np.nansum(CGs_D6_pd, axis=0) 
CGs_CRoff_D6_0995_remove_low80_frac = CGs_CRoff_D6_0995_remove_low80_sums  / len(CGs_D6_pd) 

plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_CRoff_D6_0995_remove_low80_frac)), CGs_CRoff_D6_0995_remove_low80_frac, snap=False, alpha=0.5, label='CRISPRoff')
plt.bar(np.arange(len(CGs_D6_unedited_0995_remove_low80_frac)), CGs_D6_unedited_0995_remove_low80_frac, snap=False, alpha=0.5, label='Unedited')

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for Unedited T cells CGs \n mC threshold 99.5%; >80% * mean(mC)')
plt.legend()
# Show the plot
plt.show()

# DIFFERENCES

dif_mCthresh_CRoff_unedit_0995 = CGs_CRoff_D6_0995_remove_low80_frac - CGs_D6_unedited_0995_remove_low80_frac

plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(dif_mCthresh_CRoff_unedit_0995)), dif_mCthresh_CRoff_unedit_0995, snap=False, alpha=0.5, label='CRoff - unedited' )

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC difference')
plt.title('Fraction Differences between mC CRISPRoff and Unedited T cells day 6 \n confidence  threshold 99.5% (<80%*mean(mC) removed)')
plt.legend()

# Show the plot
plt.show()

# %%
CGs_D6_pd = CGs_unedited_D6_mc0995_remove_low70
CGs_D6_unedited_0995_remove_low70_sums = np.nansum(CGs_D6_pd, axis=0) 
CGs_D6_unedited_0995_remove_low70_frac = CGs_D6_unedited_0995_remove_low70_sums  / len(CGs_D6_pd) 

CGs_D6_pd = CGs_CRoff_D6_mc0995_remove_low70
CGs_CRoff_D6_0995_remove_low70_sums = np.nansum(CGs_D6_pd, axis=0) 
CGs_CRoff_D6_0995_remove_low70_frac = CGs_CRoff_D6_0995_remove_low70_sums  / len(CGs_D6_pd) 

plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_CRoff_D6_0995_remove_low70_frac)), CGs_CRoff_D6_0995_remove_low70_frac, snap=False, alpha=0.5, label='CRISPRoff')
plt.bar(np.arange(len(CGs_D6_unedited_0995_remove_low70_frac)), CGs_D6_unedited_0995_remove_low70_frac, snap=False, alpha=0.5, label='Unedited')

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for Unedited T cells CGs \n mC threshold 99.5%; >70% * mean(mC)')
plt.legend()
# Show the plot
plt.show()

# DIFFERENCES
dif_mCthresh_CRoff_unedit_0995 = CGs_CRoff_D6_0995_remove_low70_frac - CGs_D6_unedited_0995_remove_low70_frac

plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(dif_mCthresh_CRoff_unedit_0995)), dif_mCthresh_CRoff_unedit_0995, snap=False, alpha=0.5, label='CRoff - unedited' )

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC difference')
plt.title('Fraction Differences between mC CRISPRoff and Unedited T cells day 6 \n confidence  threshold 99.5% (<70%*mean(mC) removed)')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # Use 0.7 Confidence in mC Dorado Calls

# %%
# CGs_pd = CGs_unedited_D6_mc07_remove_low70
# CGs_unedited_07_remove_low70_sums = np.nansum(CGs_pd, axis=0) 
# CGs_unedited_07_remove_low70_frac = CGs_unedited_07_remove_low70_sums  / len(CGs_pd) 

# CGs_pd = CGs_CRoff_mc07_remove_low70
# CGs_CRoff_07_remove_low70_sums = np.nansum(CGs_pd, axis=0) 
# CGs_CRoff_07_remove_low70_frac = CGs_CRoff_07_remove_low70_sums  / len(CGs_pd) 

# plt.figure(figsize=(16, 5))
# plt.bar(np.arange(len(CGs_CRoff_07_remove_low70_frac)), CGs_CRoff_07_remove_low70_frac, snap=False, alpha=0.5, label='CRISPRoff')
# plt.bar(np.arange(len(CGs_unedited_07_remove_low70_frac)), CGs_unedited_07_remove_low70_frac, snap=False, alpha=0.5, label='Unedited')

# # Add labels and title
# plt.xlabel('CpG units')
# plt.ylabel('Fraction of mC')
# plt.title('Fraction of mC for Unedited T cells CGs \n mC threshold 70%; >70% * mean(mC)')
# plt.legend()
# # Show the plot
# plt.show()

# # DIFFERENCES
# dif_mCthresh_CRoff_unedit_07 = CGs_CRoff_07_remove_low70_frac - CGs_unedited_07_remove_low70_frac

# plt.figure(figsize=(16, 5))
# plt.bar(np.arange(len(dif_mCthresh_CRoff_unedit_07)), dif_mCthresh_CRoff_unedit_07, snap=False, alpha=0.5, label='CRoff - unedited' )

# # Add labels and title
# plt.xlabel('CpG units')
# plt.ylabel('Fraction of mC difference')
# plt.title('Fraction Differences between mC CRISPRoff and Unedited T cells day 28 \n confidence  threshold 70% (<70%*mean(mC) removed)')
# plt.legend()

# # Show the plot
# plt.show()

# %%
CGs_D6_pd = CGs_unedited_D6_mc07_remove_low70
CGs_D6_unedited_07_remove_low70_sums = np.nansum(CGs_D6_pd, axis=0) 
CGs_D6_unedited_07_remove_low70_frac = CGs_D6_unedited_07_remove_low70_sums  / len(CGs_D6_pd) 

CGs_D6_pd = CGs_CRoff_D6_mc07_remove_low70
CGs_CRoff_D6_07_remove_low70_sums = np.nansum(CGs_D6_pd, axis=0) 
CGs_CRoff_D6_07_remove_low70_frac = CGs_CRoff_D6_07_remove_low70_sums  / len(CGs_D6_pd) 

plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_CRoff_D6_07_remove_low70_frac)), CGs_CRoff_D6_07_remove_low70_frac, snap=False, alpha=0.5, label='CRISPRoff')
plt.bar(np.arange(len(CGs_D6_unedited_07_remove_low70_frac)), CGs_D6_unedited_07_remove_low70_frac, snap=False, alpha=0.5, label='Unedited')

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for Unedited T cells CGs \n mC threshold 70%; >70% * mean(mC)')
plt.legend()
# Show the plot
plt.show()

# DIFFERENCES
dif_mCthresh_CRoff_unedit_07 = CGs_CRoff_D6_07_remove_low70_frac - CGs_D6_unedited_07_remove_low70_frac

plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(dif_mCthresh_CRoff_unedit_07)), dif_mCthresh_CRoff_unedit_07, snap=False, alpha=0.5, label='CRoff - unedited' )

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC difference')
plt.title('Fraction Differences between mC CRISPRoff and Unedited T cells day 6 \n confidence  threshold 70% (<70%*mean(mC) removed)')
plt.legend()

# Show the plot
plt.show()

# %%
CGs_D6_pd = CGs_unedited_D6_mc07_remove_low70
CGs_D6_unedited_07_remove_low70_sums = np.nansum(CGs_D6_pd, axis=0) 
CGs_D6_unedited_07_remove_low70_frac = CGs_D6_unedited_07_remove_low70_sums  / len(CGs_D6_pd) 

CGs_D6_pd = CGs_CRoff_D6_mc07_remove_low70
CGs_CRoff_D6_07_remove_low70_sums = np.nansum(CGs_D6_pd, axis=0) 
CGs_CRoff_D6_07_remove_low70_frac = CGs_CRoff_D6_07_remove_low70_sums  / len(CGs_D6_pd) 


plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_CRoff_D6_07_remove_low70_frac)), CGs_CRoff_D6_07_remove_low70_frac, snap=False, alpha=0.5, label='CRISPRoff day 6')
plt.bar(np.arange(len(CGs_CRoff_D28_07_remove_low70_frac)), CGs_CRoffD28_07_remove_low70_frac, snap=False, alpha=0.5, label='CRISPRoff day 28')
# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for Unedited T cells CGs \n mC threshold 70%; >70% * mean(mC)')
plt.legend()
# Show the plot
plt.show()



# DIFFERENCES
dif_mCthresh_CRoff_D6_07 = CGs_CRoff_D6_07_remove_low70_frac - CGs_CRoff_07_remove_low70_frac
plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(dif_mCthresh_CRoff_D6_07)), dif_mCthresh_CRoff_D6_07, snap=False, alpha=0.5, label='CRoff Day 6 - Day 28' )
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC difference')
plt.title('Fraction Differences between mC CRISPRoff and Unedited T cells day 6 \n confidence  threshold 99.5% (<70%*mean(mC) removed)')
plt.legend()

# Show the plot
plt.show()

## =--------- UNEDITED Day 6 vs Day 38

plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_D6_unedited_07_remove_low70_frac)), CGs_D6_unedited_07_remove_low70_frac, snap=False, alpha=0.5, label='Unedited day 6')
plt.bar(np.arange(len(CGs_unedited_D28_07_remove_low70_frac)), CGs_unedited_D28_07_remove_low70_frac, snap=False, alpha=0.5, label='Unedited  day 28')

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for Unedited T cells CGs \n mC threshold 70%; >70% * mean(mC)')
plt.legend()
# Show the plot
plt.show()




# DIFFERENCES
dif_mCthresh_unedited_D6_07 = CGs_D6_unedited_07_remove_low70_frac - CGs_unedited_07_remove_low70_frac
plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(dif_mCthresh_unedited_D6_07)), dif_mCthresh_unedited_D6_07, snap=False, alpha=0.5, label='Unedited Day 6 - Day 28' )
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC difference')
plt.title('Fraction Differences between mC CRISPRoff and Unedited T cells day 6 \n confidence  threshold 70% (<70%*mean(mC) removed)')
plt.legend()




# --------- ALL Together ---------------

plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_CRoff_D6_07_remove_low70_frac)), CGs_CRoff_D6_07_remove_low70_frac, snap=False, alpha=0.5, label='CRISPRoff day 6')
plt.bar(np.arange(len(CGs_CRoff_07_remove_low70_frac)), CGs_CRoff_07_remove_low70_frac, snap=False, alpha=0.5, label='CRISPRoff day 28')

plt.bar(np.arange(len(CGs_D6_unedited_07_remove_low70_frac)), CGs_D6_unedited_07_remove_low70_frac, snap=False, alpha=0.5, label='Unedited day 6')
plt.bar(np.arange(len(CGs_unedited_D28_07_remove_low70_frac)), CGs_unedited_D28_07_remove_low70_frac, snap=False, alpha=0.5, label='Unedited  day 28')

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for Unedited T cells CGs \n mC threshold 70%; >70% * mean(mC)')
plt.legend()
# Show the plot
plt.show()

plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_CRoff_D6_07_remove_low70_frac)), CGs_CRoff_D6_07_remove_low70_frac, snap=False, alpha=0.5, label='CRISPRoff')
plt.bar(np.arange(len(CGs_D6_unedited_07_remove_low70_frac)), CGs_D6_unedited_07_remove_low70_frac, snap=False, alpha=0.5, label='Unedited')

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for Unedited T cells CGs day 6 \n mC; >70% * mean(mC)')
plt.legend()
# Show the plot
plt.show()

# DIFFERENCES
dif_mCthresh_CRoff_unedit_07 = CGs_CRoff_D6_07_remove_low70_frac - CGs_D6_unedited_07_remove_low70_frac

plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(dif_mCthresh_CRoff_unedit_07)), dif_mCthresh_CRoff_unedit_07, snap=False, alpha=0.5, label='CRoff - unedited' )

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC difference')
plt.title('Fraction Differences between mC CRISPRoff and Unedited T cells day 6 \n confidence  threshold 70% (<70%*mean(mC) removed)')
plt.legend()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 12
#      10 plt.figure(figsize=(16, 5))
#      11 plt.bar(np.arange(len(CGs_CRoff_D6_07_remove_low70_frac)), CGs_CRoff_D6_07_remove_low70_frac, snap=False, alpha=0.5, label='CRISPRoff day 6')
# ---> 12 plt.bar(np.arange(len(CGs_CRoff_D28_07_remove_low70_frac)), CGs_CRoffD28_07_remove_low70_frac, snap=False, alpha=0.5, label='CRISPRoff day 28')
#      13 # Add labels and title
#      14 plt.xlabel('CpG units')
#
# NameError: name 'CGs_CRoff_D28_07_remove_low70_frac' is not defined

# %%
CGs_pd = CGs_unedited_D6_mc0995_remove_low70
CGs_D6_unedited_0995_remove_low70_sums = np.nansum(CGs_pd, axis=0) 
CGs_D6_unedited_0995_remove_low70_frac = CGs_D6_unedited_0995_remove_low70_sums  / len(CGs_pd) 


CGs_pd = CGs_CRoff_D6_mc0995_remove_low70
CGs_CRoff_D6_0995_remove_low70_sums = np.nansum(CGs_pd, axis=0) 
CGs_CRoff_D6_0995_remove_low70_frac = CGs_CRoff_D6_0995_remove_low70_sums  / len(CGs_pd) 

CGs_pd = CGs_unedited_D28_mc0995_remove_low70
CGs_unedited_0995_remove_low70_sums = np.nansum(CGs_pd, axis=0) 
CGs_unedited_0995_remove_low70_frac = CGs_unedited_0995_remove_low70_sums  / len(CGs_pd) 


CGs_pd = CGs_CRoff_D6_mc0995_remove_low70
CGs_CRoff_0995_remove_low70_sums = np.nansum(CGs_pd, axis=0) 
CGs_CRoff_0995_remove_low70_frac = CGs_CRoff_0995_remove_low70_sums  / len(CGs_pd) 


plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_CRoff_D6_0995_remove_low70_frac)), CGs_CRoff_D6_0995_remove_low70_frac, snap=False, alpha=0.5, label='CRISPRoff day 6')
plt.bar(np.arange(len(CGs_CRoff_0995_remove_low70_frac)), CGs_CRoff_0995_remove_low70_frac, snap=False, alpha=0.5, label='CRISPRoff day 28')
# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for Unedited T cells CGs \n mC threshold 99.5%; >70% * mean(mC)')
plt.legend()
# Show the plot
plt.show()



# DIFFERENCES
dif_mCthresh_CRoff_D6_0995 = CGs_CRoff_D6_0995_remove_low70_frac - CGs_CRoff_0995_remove_low70_frac
plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(dif_mCthresh_CRoff_D6_0995)), dif_mCthresh_CRoff_D6_0995, snap=False, alpha=0.5, label='CRoff Day 6 - Day 28' )
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC difference')
plt.title('Fraction Differences between mC CRISPRoff and Unedited T cells day 6 \n confidence  threshold 99.5% (<70%*mean(mC) removed)')
plt.legend()

# Show the plot
plt.show()

## =--------- UNEDITED Day 6 vs Day 38

plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_D6_unedited_0995_remove_low70_frac)), CGs_D6_unedited_0995_remove_low70_frac, snap=False, alpha=0.5, label='Unedited day 6')
plt.bar(np.arange(len(CGs_unedited_0995_remove_low70_frac)), CGs_unedited_0995_remove_low70_frac, snap=False, alpha=0.5, label='Unedited  day 28')

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for Unedited T cells CGs \n mC threshold 99.5%; >70% * mean(mC)')
plt.legend()
# Show the plot
plt.show()




# DIFFERENCES
dif_mCthresh_unedited_D6_0995 = CGs_D6_unedited_0995_remove_low70_frac - CGs_unedited_0995_remove_low70_frac
plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(dif_mCthresh_unedited_D6_0995)), dif_mCthresh_unedited_D6_0995, snap=False, alpha=0.5, label='Unedited Day 6 - Day 28' )
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC difference')
plt.title('Fraction Differences between mC CRISPRoff and Unedited T cells day 6 \n confidence  threshold 99.5% (<70%*mean(mC) removed)')
plt.legend()




# --------- ALL Together ---------------

plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_CRoff_D6_0995_remove_low70_frac)), CGs_CRoff_D6_0995_remove_low70_frac, snap=False, alpha=0.5, label='CRISPRoff day 6')
plt.bar(np.arange(len(CGs_CRoff_0995_remove_low70_frac)), CGs_CRoff_0995_remove_low70_frac, snap=False, alpha=0.5, label='CRISPRoff day 28')

plt.bar(np.arange(len(CGs_D6_unedited_0995_remove_low70_frac)), CGs_D6_unedited_0995_remove_low70_frac, snap=False, alpha=0.5, label='Unedited day 6')
plt.bar(np.arange(len(CGs_unedited_0995_remove_low70_frac)), CGs_unedited_0995_remove_low70_frac, snap=False, alpha=0.5, label='Unedited  day 28')

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for Unedited T cells CGs \n mC threshold 99.5%; >70% * mean(mC)')
plt.legend()
# Show the plot
plt.show()

plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(CGs_CRoff_D6_0995_remove_low70_frac)), CGs_CRoff_D6_0995_remove_low70_frac, snap=False, alpha=0.5, label='CRISPRoff')
plt.bar(np.arange(len(CGs_D6_unedited_0995_remove_low70_frac)), CGs_D6_unedited_0995_remove_low70_frac, snap=False, alpha=0.5, label='Unedited')

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC')
plt.title('Fraction of mC for Unedited T cells CGs day 6 \n 99.5% confidence mC; >70% * mean(mC)')
plt.legend()
# Show the plot
plt.show()

# DIFFERENCES
dif_mCthresh_CRoff_unedit_0995 = CGs_CRoff_D6_0995_remove_low70_frac - CGs_D6_unedited_0995_remove_low70_frac

plt.figure(figsize=(16, 5))
plt.bar(np.arange(len(dif_mCthresh_CRoff_unedit_0995)), dif_mCthresh_CRoff_unedit_0995, snap=False, alpha=0.5, label='CRoff - unedited' )

# Add labels and title
plt.xlabel('CpG units')
plt.ylabel('Fraction of mC difference')
plt.title('Fraction Differences between mC CRISPRoff and Unedited T cells day 6 \n confidence  threshold 99.5% (<70%*mean(mC) removed)')
plt.legend()

# Show the plot
plt.show()
