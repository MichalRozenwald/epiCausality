# %% [markdown]
# ### Database creation of Telomere-to-telomere consortium CHM13 Annotations

# %% [markdown]
# ##### Before you begin, please make sure you have the proper files downloaded

# %%
#Download link for CHM13 Annotations: https://github.com/marbl/CHM13?tab=readme-ov-file
##Scroll Down to find the UCSC GENCODEv35 CAT/Liftoff v2 Annotation file, which will be used for this database

# %%
# ! python3 -m pip install gffutils

# %%
import pandas as pd
import numpy as np
import gffutils
import pysam

# %% [markdown]
# ##### If this is your first time importing the gff3 database, run this command

# %%
# This can take a long time, so only run this once (remove the #)
# gene_annotation_gff3_chm13_v2_path ='/home/michalula/code/Ella/data/chm13.draft_v2.0.gene_annotation.gff3'

# db = gffutils.create_db(gene_annotation_gff3_chm13_v2_path,
#                          dbfn='chm13db.db', force=True, keep_order=True, 
# merge_strategy='create_unique', sort_attribute_values=True) 

# replace gff3 with your gff3 file, dbfn can be whichever name you want to store the transposed file as

# %% [markdown]
# ##### Feature the selected database

# %%
gene_annotation_DB_chm13_v2_path = '/home/michalula/code/Ella/data/t2tv2_0_gene_annotation_chm13db.db'  # '/home/michalula/code/Ella/data/chm13db.db'
db = gffutils.FeatureDB(gene_annotation_DB_chm13_v2_path, keep_order=True)
db

# %% [markdown]
# ##### Select the desired range

# %%
slct = db.region(region=('chr1', 206586910, 206587029), completely_within=False)
# t2tv2.0: chr: 206586910 -	206587029
# slct = db.region(region=('chr1', 206560169, 206614236), completely_within=False)
slct
# Out:
# <generator object FeatureDB.region at 0x7453e85c0cc0>

# %% [markdown]
# ##### Iterate through the region and transpose it to a dictionary

# %%
records = []
for gene in slct:
    records.append({
        "seqid": gene.seqid,
        "source": gene.source,
        "featuretype": gene.featuretype,
        "start": gene.start,
        "end": gene.end,
        "strand": gene.strand,
        "score": gene.score,
        "attributes": gene.attributes  # Attributes as a dictionary (will be expanded later)
    })

# %% [markdown]
# ##### Expand out the attributes and format the dictionary as a database, dropping unnecessary columns

# %%
df = pd.DataFrame(records)
attributes_df = df["attributes"].apply(pd.Series)
df = pd.concat([df.drop(columns=["attributes"]), attributes_df], axis=1)

# %%
for col in df.columns:
    df[col] = df[col].apply(lambda x: x[0] if isinstance(x, list) and len(x) == 1 else x)
df.dropna(how='all', axis=1, inplace=True)
df
# Out:
#    seqid source featuretype      start        end strand  score  \
# 0   chr1    CAT        exon  206586828  206587161      +      .
# 1   chr1    CAT  transcript  206586828  206606065      +  10000
# 2   chr1    CAT        gene  206586828  206652117      +      .
# 3   chr1    CAT        exon  206586939  206587161      +      .
# 4   chr1    CAT        exon  206586939  206587161      +      .
# 5   chr1    CAT  transcript  206586939  206625016      +  10000
# 6   chr1    CAT  transcript  206586939  206625639      +  10000
# 7   chr1    CAT        exon  206586974  206587161      +      .
# 8   chr1    CAT  transcript  206586974  206626269      +  10000
# 9   chr1    CAT        exon  206586997  206587161      +      .
# 10  chr1    CAT  transcript  206586997  206625804      +  10000
# 11  chr1    CAT        exon  206587029  206587161      +      .
# 12  chr1    CAT  transcript  206587029  206625070      +   9970
#
#      source_transcript source_transcript_name         source_gene  ...  Name  \
# 0    ENST00000367063.6               CD55-203  ENSG00000196352.16  ...  CD55
# 1    ENST00000367063.6               CD55-203  ENSG00000196352.16  ...  CD55
# 2                  N/A                    NaN  ENSG00000196352.16  ...  CD55
# 3    ENST00000391921.9               CD55-206  ENSG00000196352.16  ...  CD55
# 4    ENST00000645323.1               CD55-214  ENSG00000196352.16  ...  CD55
# 5    ENST00000391921.9               CD55-206  ENSG00000196352.16  ...  CD55
# 6    ENST00000645323.1               CD55-214  ENSG00000196352.16  ...  CD55
# 7    ENST00000367064.9               CD55-204  ENSG00000196352.16  ...  CD55
# 8    ENST00000367064.9               CD55-204  ENSG00000196352.16  ...  CD55
# 9   ENST00000314754.12               CD55-201  ENSG00000196352.16  ...  CD55
# 10  ENST00000314754.12               CD55-201  ENSG00000196352.16  ...  CD55
# 11   ENST00000367067.8               CD55-205  ENSG00000196352.16  ...  CD55
# 12   ENST00000367067.8               CD55-205  ENSG00000196352.16  ...  CD55
#
#    rna_support reference_support gene_name alternative_source_transcripts  \
# 0          N/A              True      CD55                            N/A
# 1          NaN               NaN      CD55                            N/A
# 2          NaN               NaN      CD55                            N/A
# 3          N/A              True      CD55                            N/A
# 4          N/A              True      CD55                            N/A
# 5          NaN               NaN      CD55                            N/A
# 6          NaN               NaN      CD55                            N/A
# 7          N/A              True      CD55                            N/A
# 8          NaN               NaN      CD55                            N/A
# 9          N/A              True      CD55                            N/A
# 10         NaN               NaN      CD55                            N/A
# 11         N/A              True      CD55                            N/A
# 12         NaN               NaN      CD55                            N/A
#
#    collapsed_gene_ids collapsed_gene_names frameshift extra_paralog  \
# 0                 N/A                  N/A        N/A         False
# 1                 N/A                  N/A        nan         False
# 2                 N/A                  N/A        N/A         False
# 3                 N/A                  N/A        N/A         False
# 4                 N/A                  N/A        N/A         False
# 5                 N/A                  N/A        nan         False
# 6                 N/A                  N/A        nan         False
# 7                 N/A                  N/A        N/A         False
# 8                 N/A                  N/A        nan         False
# 9                 N/A                  N/A        N/A         False
# 10                N/A                  N/A        nan         False
# 11                N/A                  N/A        N/A         False
# 12                N/A                  N/A      False         False
#
#    exon_anotation_support
# 0                     NaN
# 1                     NaN
# 2                     N/A
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                     NaN
# 10                    NaN
# 11                    NaN
# 12                    NaN
#
# [13 rows x 48 columns]
